# %%
import requests
import sys
import time
import html
import re
import json
from typing import Dict, Any, List, Tuple
json_path = r"G:\Code\Python\Project\Reader\data\backup\info\2025-09-29.json"

with open(json_path, "r", encoding="utf-8") as f:
    word_list = json.load(f)

word_list
# Out:
# [{'wordUrl': '',
#   'partOfSpeech': [{'type': 'phrase',
#     'wordPrototype': 'burst up to six feet',
#     'definitions': [{'enMeaning': '', 'chMeaning': '(身高)猛增到6英尺'}]}],
#   'sentences': [{'key': 1758082735924,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': ' bursting up to six feet',
#     'cfi': '{"text":"Near the end of the first week, the boys were divided into two groups and told to attack each other. “It was so insane, mind-blowing,” Musk recalls. Every few years, one of the kids would die. The counselors would recount such stories as warnings. “Don’t be stupid like that dumb fuck who died last year,” they would say. “Don’t be the weak dumb fuck.”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"3","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":1076,"end":1100},"backward":false}',
#     'notes': 'He had gotten much bigger, bursting up to six feet with a bearlike frame, and had learned some judo.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/pick-on',
#   'partOfSpeech': [{'type': '',
#     'wordPrototype': 'pick on someone',
#     'pronunciationUK': {'phonetic': '/ pɪk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpia/ukpiano004.mp3'},
#     'pronunciationUS': {'phonetic': '/ pɪk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/pic/pick_/pick.mp3'},
#     'definitions': [{'enMeaning': 'to criticize , punish , or be unkind to the same person often and unfairly',
#       'chMeaning': '找 （ 某人 ）的茬; 对 （ 某人 ）刁难挑剔'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083942312,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'picked on by bullies',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2699,"end":2719},"backward":false}',
#     'notes': 'As a result, he was regularly picked on by bullies, who would come up and punch him in the face.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/ballistic?q=go+ballistic',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'ballistic',
#     'pronunciationUK': {'phonetic': '/ bəˈlɪs.tɪk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukb/ukbal/ukbalal022.mp3'},
#     'pronunciationUS': {'phonetic': '/ bəˈlɪs.tɪk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usb/usbaf/usbaffl025.mp3'},
#     'definitions': [{'enMeaning': 'connected with ballistics',
#       'chMeaning': '弹道（ 学 ）的;弹道（ 运动 ）的; 发射的'}],
#     'phrases': ['go ballistic'],
#     'phraseDefinitions': [{'enMeaning': 'to become extremely angry :',
#       'chMeaning': '如果你爸爸发现你一直在逃学，他会很生气的。'}]}],
#   'sentences': [{'key': 1758084437481,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'went ballistic',
#     'cfi': '{"text":"But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and charismatic fantasist who to this day bedevils Elon. After the school fight, Errol sided with the kid who pummeled Elon’s face. “The boy had just lost his father to suicide, and Elon had called him stupid,” Errol says. “Elon had this tendency to call people stupid. How could I possibly blame that child?”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"9","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":4353,"end":4367},"backward":false}',
#     'notes': 'My father just lost it, went ballistic, as he often did.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': '',
#   'partOfSpeech': [{'type': '',
#     'wordPrototype': 'juvenile prison',
#     'pronunciationUK': {'phonetic': '', 'pronUrl': ''},
#     'pronunciationUS': {'phonetic': '', 'pronUrl': ''},
#     'definitions': [{'enMeaning': '', 'chMeaning': '青少年监狱'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758084501416,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'juvenile prison',
#     'cfi': '{"text":"When Elon finally came home from the hospital, his father berated him. “I had to stand for an hour as he yelled at me and called me an idiot and told me that I was just worthless,” Elon recalls. Kimbal, who had to watch the tirade, says it was the worst memory of his life. “My father just lost it, went ballistic, as he often did. He had zero compassion.”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"10","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":4574,"end":4589},"backward":false}',
#     'notes': 'Both Elon and Kimbal, who no longer speak to their father, say his claim that Elon provoked the attack is unhinged and that the perpetrator ended up being sent to juvenile prison for it.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/dude',
#   'partOfSpeech': [{'type': 'noun [ C ]',
#     'wordPrototype': 'dude',
#     'pronunciationUK': {'phonetic': '/ duːd /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/c/cal/cald4/cald4uk0471.mp3'},
#     'pronunciationUS': {'phonetic': '/ duːd /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/d/dud/dude_/dude.mp3'},
#     'definitions': [{'enMeaning': 'a man', 'chMeaning': '家伙 ， 小子'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082040687,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Epigraph',
#     'chapterIndex': 3,
#     'text': 'dude',
#     'cfi': '{"text":"To anyone I’ve offended, I just want to say, I reinvented electric cars and I’m sending people to Mars in a rocket ship. Did you think I was also going to be a chill, normal dude?","chapterTitle":"Epigraph","chapterDocIndex":"3","chapterHref":"OEBPS/part0003.xhtml","count":"0","percentage":"0.01507537688442211","page":""}',
#     'range': '{"characterRange":{"start":174,"end":178},"backward":false}',
#     'notes': 'Did you think I was also going to be a chill, normal dude?',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/paramilitary',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'paramilitary',
#     'pronunciationUK': {'phonetic': '/ ˌpær.əˈmɪl.ɪ.tri /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˌper.əˈmɪl.ə.ter.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3'},
#     'definitions': [{'enMeaning': 'A paramilitary group is organized like an army but is not official and often not legal .',
#       'chMeaning': '准军事的 ， 非法军事组织的'},
#      {'enMeaning': 'connected with and helping the official armed forces',
#       'chMeaning': '与正规军有联系的 ， 辅助军事的'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C ]',
#     'wordPrototype': 'paramilitary',
#     'pronunciationUK': {'phonetic': '/ ˌpær.əˈmɪl.ɪ.tri /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˌper.əˈmɪl.ə.ter.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3'},
#     'definitions': [{'enMeaning': 'a person who belongs to a paramilitary organization',
#       'chMeaning': '准军事组织成员'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082151531,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'paramilitary',
#     'cfi': '{"text":"The playground","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"0","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":206,"end":218},"backward":false}',
#     'notes': '“It was a paramilitary Lord of the Flies,” he recalls. ',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english/rations',
#   'partOfSpeech': [{'type': 'plural noun',
#     'wordPrototype': 'rations',
#     'pronunciationUK': {'phonetic': '', 'pronUrl': ''},
#     'pronunciationUS': {'phonetic': '/ ˈræʃ·ənz , ˈreɪ·ʃənz /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english/us_pron/r/rat/ratio/rations.mp3'},
#     'definitions': [{'enMeaning': 'the food given to someone at one time , esp . to soldiers :',
#       'chMeaning': ''}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082392456,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'rations',
#     'cfi': '{"text":"The playground","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"0","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":282,"end":289},"backward":false}',
#     'notes': 'The kids were each given small rations of food and water, and they were allowed—indeed encouraged—to fight over them.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/mind-blowing',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'mind-blowing',
#     'pronunciationUK': {'phonetic': '/ ˈmaɪndˌbləʊ.ɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukb/ukb00/ukb00805.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈmaɪndˌbloʊ.ɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usb/usb00/usb00805.mp3'},
#     'definitions': [{'enMeaning': 'extremely exciting or surprising',
#       'chMeaning': '令人印象深刻的 ； 令人惊奇的'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082542100,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'mind-blowing',
#     'cfi': '{"text":"When he was twelve, he was taken by bus to a wilderness survival camp, known as a veldskool. “It was a paramilitary Lord of the Flies,” he recalls. The kids were each given small rations of food and water, and they were allowed—indeed encouraged—to fight over them. “Bullying was considered a virtue,” his younger brother Kimbal says. The big kids quickly learned to punch the little ones in the face and take their stuff. Elon, who was small and emotionally awkward, got beaten up twice. He would end up losing ten pounds.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"2","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":747,"end":759},"backward":true}',
#     'notes': '“It was so insane, mind-blowing,” Musk recalls. ',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/counselors',
#   'partOfSpeech': [{'type': 'noun [ C ]',
#     'wordPrototype': 'guidance counselor',
#     'pronunciationUK': {'phonetic': '/ ˈɡaɪ.d ə ns ˌkaʊn.s ə l.ə r /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/c/cal/cald4/cald4uk0695.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈɡaɪ.d ə ns ˌkaʊn.s ə l.ɚ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usa/usa30/usa30232.mp3'},
#     'definitions': [{'enMeaning': 'someone whose job is to help people choose a job or career',
#       'chMeaning': '就业顾问 ， 工作咨询顾问'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082637263,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'counselors',
#     'cfi': '{"text":"Near the end of the first week, the boys were divided into two groups and told to attack each other. “It was so insane, mind-blowing,” Musk recalls. Every few years, one of the kids would die. The counselors would recount such stories as warnings. “Don’t be stupid like that dumb fuck who died last year,” they would say. “Don’t be the weak dumb fuck.”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"3","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":824,"end":834},"backward":false}',
#     'notes': 'The counselors would recount such stories as warnings. ',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/recount',
#   'partOfSpeech': [{'type': 'verb [ T ]',
#     'wordPrototype': 'recount',
#     'pronunciationUK': {'phonetic': '/ rɪˈkaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/c/cdo/cdo02/cdo0216recouk1617.mp3'},
#     'pronunciationUS': {'phonetic': '/ rɪˈkaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/r/rec/recou/recount_01_00.mp3'},
#     'definitions': [{'enMeaning': 'to describe how something happened , or to tell a story',
#       'chMeaning': '讲述 ； 叙述 ； 描述'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'verb [ T ]',
#     'wordPrototype': 'recount',
#     'pronunciationUK': {'phonetic': '/ ˌriːˈkaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/e/epd/epd32/epd32810.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˌriːˈkaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cdo/cdo03/cdo0318usreco4047.mp3'},
#     'definitions': [{'enMeaning': 'to count something again',
#       'chMeaning': '重数 ; 重新清点'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C ]',
#     'wordPrototype': 'recount',
#     'pronunciationUK': {'phonetic': '/ ˈriː.kaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/e/euk/euk77/euk77043.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈriː.kaʊnt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usb/usb03/usb03198.mp3'},
#     'definitions': [{'enMeaning': 'another count , especially of the number of votes in an election',
#       'chMeaning': '重新计算 ;（尤指大选中） 重新计算选票'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082641404,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'recount',
#     'cfi': '{"text":"Near the end of the first week, the boys were divided into two groups and told to attack each other. “It was so insane, mind-blowing,” Musk recalls. Every few years, one of the kids would die. The counselors would recount such stories as warnings. “Don’t be stupid like that dumb fuck who died last year,” they would say. “Don’t be the weak dumb fuck.”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"3","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":841,"end":848},"backward":false}',
#     'notes': 'The counselors would recount such stories as warnings. ',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/judo',
#   'partOfSpeech': [{'type': 'noun [ U ]',
#     'wordPrototype': 'judo',
#     'pronunciationUK': {'phonetic': '/ ˈdʒuː.dəʊ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukj/ukjud/ukjudic006.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈdʒuː.doʊ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/j/jud/judo_/judo.mp3'},
#     'definitions': [{'enMeaning': 'a sport in which two people fight using their arms and legs and hands and feet , and try to throw each other to the ground',
#       'chMeaning': '柔道'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082738975,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'judo',
#     'cfi': '{"text":"Near the end of the first week, the boys were divided into two groups and told to attack each other. “It was so insane, mind-blowing,” Musk recalls. Every few years, one of the kids would die. The counselors would recount such stories as warnings. “Don’t be stupid like that dumb fuck who died last year,” they would say. “Don’t be the weak dumb fuck.”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"3","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":1145,"end":1149},"backward":false}',
#     'notes': 'He had gotten much bigger, bursting up to six feet with a bearlike frame, and had learned some judo.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/apartheid',
#   'partOfSpeech': [{'type': 'noun [ U ]',
#     'wordPrototype': 'apartheid',
#     'pronunciationUK': {'phonetic': '/ əˈpɑː.taɪt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uka/ukapa/ukapart001.mp3'},
#     'pronunciationUS': {'phonetic': '/ əˈpɑːr.taɪt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/a/apa/apart/apartheid.mp3'},
#     'definitions': [{'enMeaning': 'in the past in South Africa , a system under which people of different races were kept separate by law , and white people were given more political rights and educational and other advantages',
#       'chMeaning': '（旧时南非的） 种族隔离制度'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758082853092,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'apartheid',
#     'cfi': '{"text":"The playground","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"0","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":1590,"end":1599},"backward":false}',
#     'notes': 'Once, when Elon and Kimbal got off a train on their way to an anti-apartheid music concert, they had to wade through a pool of blood next to a dead person with a knife still sticking out of his brain.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/soles',
#   'partOfSpeech': [{'type': 'adjective [ before noun ]',
#     'wordPrototype': 'sole',
#     'pronunciationUK': {'phonetic': '/ səʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksol/uksoldi002.mp3'},
#     'pronunciationUS': {'phonetic': '/ soʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/sol/sole_/sole.mp3'},
#     'definitions': [{'enMeaning': 'being one only; single',
#       'chMeaning': '唯一的， 单 一的'},
#      {'enMeaning': 'not shared with anyone else', 'chMeaning': '专用的 ， 独享的'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C ]',
#     'wordPrototype': 'sole',
#     'pronunciationUK': {'phonetic': '/ səʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksol/uksoldi002.mp3'},
#     'pronunciationUS': {'phonetic': '/ soʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/sol/sole_/sole.mp3'},
#     'definitions': [{'enMeaning': 'the bottom part of the foot that touches the ground when you stand or walk , or the bottom part of a shoe that touches the ground , usually not including the heel',
#       'chMeaning': '脚底 ; 鞋底'},
#      {'enMeaning': 'one of a number of flat , round fish that are eaten as food',
#       'chMeaning': '比目鱼 ， 鲽鱼'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'verb [ T ]',
#     'wordPrototype': 'sole',
#     'pronunciationUK': {'phonetic': '/ səʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksol/uksoldi002.mp3'},
#     'pronunciationUS': {'phonetic': '/ soʊl /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/sol/sole_/sole.mp3'},
#     'definitions': [{'enMeaning': 'to put a new sole on a shoe',
#       'chMeaning': '给 （ 鞋 ）换新底'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083028854,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'soles',
#     'cfi': '{"text":"South Africa in the 1980s was a violent place, with machine-gun attacks and knife killings common. Once, when Elon and Kimbal got off a train on their way to an anti-apartheid music concert, they had to wade through a pool of blood next to a dead person with a knife still sticking out of his brain. For the rest of the evening, the blood on the soles of their sneakers made a sticky sound against the pavement.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"5","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":1770,"end":1775},"backward":false}',
#     'notes': 'For the rest of the evening, the blood on the soles of their sneakers made a sticky sound against the pavement.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/stares',
#   'partOfSpeech': [{'type': 'verb [ I or T ]',
#     'wordPrototype': 'stare',
#     'pronunciationUK': {'phonetic': '/ steə r /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksta/ukstabl029.mp3'},
#     'pronunciationUS': {'phonetic': '/ ster /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/sta/stair/stair.mp3'},
#     'definitions': [{'enMeaning': 'to look for a long time with the eyes wide open , especially when surprised , frightened , or thinking',
#       'chMeaning': '（尤指惊讶、害怕或思考时） 盯着看 ， 凝视 ， 注视'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C ]',
#     'wordPrototype': 'stare',
#     'pronunciationUK': {'phonetic': '/ steə r /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksta/ukstabl029.mp3'},
#     'pronunciationUS': {'phonetic': '/ ster /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/sta/stair/stair.mp3'},
#     'definitions': [{'enMeaning': 'a long look at something or someone with your eyes wide open',
#       'chMeaning': '凝视 ， 注视'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083082547,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'stares',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2335,"end":2341},"backward":false}',
#     'notes': 'In recounting the story, Musk pauses and stares vacantly for a very long time.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/vacantly',
#   'partOfSpeech': [{'type': 'adverb',
#     'wordPrototype': 'vacantly',
#     'pronunciationUK': {'phonetic': '/ ˈveɪ.k ə nt.li /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uku/ukutt/ukutter011.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈveɪ.k ə nt.li /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usv/usvac/usvacan001.mp3'},
#     'definitions': [{'enMeaning': 'showing no interest or mental activity',
#       'chMeaning': '无聊地 ; 茫然地 ; 没精打采地'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083103097,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'vacantly',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2342,"end":2350},"backward":false}',
#     'notes': 'In recounting the story, Musk pauses and stares vacantly for a very long time.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/searing',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'searing',
#     'pronunciationUK': {'phonetic': '/ ˈsɪə.rɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/uksea/uksear_006.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈsɪr.ɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usl/usl30/usl30286.mp3'},
#     'definitions': [{'enMeaning': 'If something, such as a feeling or temperature , is described as searing, it is extreme .',
#       'chMeaning': '（ 感觉 、温度等） 极度的 ， 强烈的'},
#      {'enMeaning': '( especially of a criticism or story ) very powerful and emotional or criticizing someone or something very strongly',
#       'chMeaning': '（尤指批评或故事） 感情强烈的 ； 猛烈批评的'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083877456,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'searing',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2423,"end":2430},"backward":false}',
#     'notes': 'His most searing experiences came at school.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/instinct',
#   'partOfSpeech': [{'type': 'noun [ C or U ]',
#     'wordPrototype': 'instinct',
#     'pronunciationUK': {'phonetic': '/ ˈɪn.stɪŋkt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uki/ukins/ukinspe023.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈɪn.stɪŋkt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/i/ins/insti/instinct.mp3'},
#     'definitions': [{'enMeaning': 'the way people or animals naturally react or behave , without having to think or learn about it',
#       'chMeaning': '本能 ， 直觉'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083914439,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'instinct',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2640,"end":2648},"backward":false}',
#     'notes': 'Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/ingratiating',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'ingratiating',
#     'pronunciationUK': {'phonetic': '/ ɪnˈɡreɪ.ʃiː.eɪ.tɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uki/uking/ukingra002.mp3'},
#     'pronunciationUS': {'phonetic': '/ ɪnˈɡreɪ.ʃiː.eɪ.t̬ɪŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/u/usi/using/usinglo004.mp3'},
#     'definitions': [{'enMeaning': 'Ingratiating behaviour is intended to make people like you.',
#       'chMeaning': '迎合的 ， 奉承的'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083919174,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'ingratiating',
#     'cfi': '{"text":"His most searing experiences came at school. For a long time, he was the youngest and smallest student in his class. He had trouble picking up social cues. Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating. As a result, he was regularly picked on by bullies, who would come up and punch him in the face. “If you have never been punched in the nose, you have no idea how it affects you the rest of your life,” he says.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"7","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2655,"end":2667},"backward":false}',
#     'notes': 'Empathy did not come naturally, and he had neither the desire nor the instinct to be ingratiating.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/horsing around',
#   'partOfSpeech': [{'type': '',
#     'wordPrototype': 'horse around',
#     'pronunciationUK': {'phonetic': '/ hɔːs /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukh/ukhiv/ukhive_017.mp3'},
#     'pronunciationUS': {'phonetic': '/ hɔːrs /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/h/hoa/hoars/hoarse.mp3'},
#     'definitions': [{'enMeaning': 'to behave in a silly and noisy way',
#       'chMeaning': '胡闹 ， 哄闹 ， 捣乱'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083975494,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'horsing around',
#     'cfi': '{"text":"At assembly one morning, a student who was horsing around with a gang of friends bumped into him. Elon pushed him back. Words were exchanged. The boy and his friends hunted Elon down at recess and found him eating a sandwich. They came up from behind, kicked him in the head, and pushed him down a set of concrete steps. “They sat on him and just kept beating the shit out of him and kicking him in the head,” says Kimbal, who had been sitting with him. “When they got finished, I couldn’t even recognize his face. It was such a swollen ball of flesh that you could barely see his eyes.” He was taken to the hospital and was out of school for a week. Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"8","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2923,"end":2937},"backward":false}',
#     'notes': 'At assembly one morning, a student who was horsing around with a gang of friends bumped into him.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/bumped into',
#   'partOfSpeech': [{'type': '',
#     'wordPrototype': 'bump into someone',
#     'pronunciationUK': {'phonetic': '/ bʌmp /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukb/ukbul/ukbulru010.mp3'},
#     'pronunciationUS': {'phonetic': '/ bʌmp /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/b/bum/bump_/bump.mp3'},
#     'definitions': [{'enMeaning': 'to meet someone you know when you have not planned to meet them',
#       'chMeaning': '与 … 不期而遇'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758083989064,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'bumped into',
#     'cfi': '{"text":"At assembly one morning, a student who was horsing around with a gang of friends bumped into him. Elon pushed him back. Words were exchanged. The boy and his friends hunted Elon down at recess and found him eating a sandwich. They came up from behind, kicked him in the head, and pushed him down a set of concrete steps. “They sat on him and just kept beating the shit out of him and kicking him in the head,” says Kimbal, who had been sitting with him. “When they got finished, I couldn’t even recognize his face. It was such a swollen ball of flesh that you could barely see his eyes.” He was taken to the hospital and was out of school for a week. Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"8","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":2961,"end":2972},"backward":false}',
#     'notes': 'At assembly one morning, a student who was horsing around with a gang of friends bumped into him.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/recess',
#   'partOfSpeech': [{'type': 'noun',
#     'wordPrototype': 'recess',
#     'pronunciationUK': {'phonetic': '/ ˈriː.ses /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukr/ukrec/ukrecep002.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈrɪː.ses /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/r/rec/reces/recess.mp3'},
#     'definitions': [{'enMeaning': 'a period of time in the year when the members of a parliament , court of law , or other government organization are not meeting',
#       'chMeaning': '（ 议会 ） 休会期'},
#      {'enMeaning': 'in school , a period of time between classes when children do not study',
#       'chMeaning': '课间休息'},
#      {'enMeaning': 'a small area in a room that is formed by one part of a wall being set back further than other parts',
#       'chMeaning': '壁龛 ;（墙的） 凹进处 ; 凹室'},
#      {'enMeaning': 'a secret or hidden place',
#       'chMeaning': '幽深处 ; 隐秘处 ; 藏身处'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758084021056,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'recess',
#     'cfi': '{"text":"At assembly one morning, a student who was horsing around with a gang of friends bumped into him. Elon pushed him back. Words were exchanged. The boy and his friends hunted Elon down at recess and found him eating a sandwich. They came up from behind, kicked him in the head, and pushed him down a set of concrete steps. “They sat on him and just kept beating the shit out of him and kicking him in the head,” says Kimbal, who had been sitting with him. “When they got finished, I couldn’t even recognize his face. It was such a swollen ball of flesh that you could barely see his eyes.” He was taken to the hospital and was out of school for a week. Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"8","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":3066,"end":3072},"backward":false}',
#     'notes': 'The boy and his friends hunted Elon down at recess and found him eating a sandwich.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/swollen',
#   'partOfSpeech': [{'type': 'verb',
#     'wordPrototype': 'swollen',
#     'pronunciationUK': {'phonetic': '/ ˈswəʊ.lən /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/ukswi/ukswipe018.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈswoʊ.lən /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/swo/swoll/swollen.mp3'},
#     'definitions': [{'enMeaning': 'past participle of swell',
#       'chMeaning': '（swell的过去分词）'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'adjective',
#     'wordPrototype': 'swollen',
#     'pronunciationUK': {'phonetic': '/ ˈswəʊ.lən /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uks/ukswi/ukswipe018.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈswoʊ.lən /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/s/swo/swoll/swollen.mp3'},
#     'definitions': [{'enMeaning': 'larger than usual',
#       'chMeaning': '肿大的 ; 膨胀的 ; 大于正常的'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758084064821,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'swollen',
#     'cfi': '{"text":"At assembly one morning, a student who was horsing around with a gang of friends bumped into him. Elon pushed him back. Words were exchanged. The boy and his friends hunted Elon down at recess and found him eating a sandwich. They came up from behind, kicked him in the head, and pushed him down a set of concrete steps. “They sat on him and just kept beating the shit out of him and kicking him in the head,” says Kimbal, who had been sitting with him. “When they got finished, I couldn’t even recognize his face. It was such a swollen ball of flesh that you could barely see his eyes.” He was taken to the hospital and was out of school for a week. Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"8","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":3409,"end":3416},"backward":false}',
#     'notes': 'It was such a swollen ball of flesh that you could barely see his eyes.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/corrective',
#   'partOfSpeech': [{'type': 'adjective',
#     'wordPrototype': 'corrective',
#     'pronunciationUK': {'phonetic': '/ kəˈrek.tɪv /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukc/ukcor/ukcorps012.mp3'},
#     'pronunciationUS': {'phonetic': '/ kəˈrek.tɪv /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cor/corre/corrective.mp3'},
#     'definitions': [{'enMeaning': 'intended to improve a situation',
#       'chMeaning': '改正的 ， 纠正的'},
#      {'enMeaning': 'used to refer to something that is intended to cure a medical condition',
#       'chMeaning': '（医疗） 矫正的'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C ]',
#     'wordPrototype': 'corrective',
#     'pronunciationUK': {'phonetic': '/ kəˈrek.tɪv /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukc/ukcor/ukcorps012.mp3'},
#     'pronunciationUS': {'phonetic': '/ kəˈrek.tɪv /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cor/corre/corrective.mp3'},
#     'definitions': [{'enMeaning': 'something that improves a situation',
#       'chMeaning': '纠正物 ； 矫正物 ， 起矫正作用的东西'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758084087938,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'corrective',
#     'cfi': '{"text":"At assembly one morning, a student who was horsing around with a gang of friends bumped into him. Elon pushed him back. Words were exchanged. The boy and his friends hunted Elon down at recess and found him eating a sandwich. They came up from behind, kicked him in the head, and pushed him down a set of concrete steps. “They sat on him and just kept beating the shit out of him and kicking him in the head,” says Kimbal, who had been sitting with him. “When they got finished, I couldn’t even recognize his face. It was such a swollen ball of flesh that you could barely see his eyes.” He was taken to the hospital and was out of school for a week. Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"8","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":3567,"end":3577},"backward":false}',
#     'notes': 'Decades later, he was still getting corrective surgery to try to fix the tissues inside his nose.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/inflicted',
#   'partOfSpeech': [{'type': 'verb [ T ]',
#     'wordPrototype': 'inflict',
#     'pronunciationUK': {'phonetic': '/ ɪnˈflɪkt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/uki/ukinf/ukinfir016.mp3'},
#     'pronunciationUS': {'phonetic': '/ ɪnˈflɪkt /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/i/inf/infli/inflict.mp3'},
#     'definitions': [{'enMeaning': 'to force someone to experience something very unpleasant',
#       'chMeaning': '使遭受 ， 使承受'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1758084127458,
#     'bookKey': 1738143464138,
#     'date': '2025-09-17',
#     'chapter': 'Cover',
#     'chapterIndex': 5,
#     'text': 'inflicted',
#     'cfi': '{"text":"But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and charismatic fantasist who to this day bedevils Elon. After the school fight, Errol sided with the kid who pummeled Elon’s face. “The boy had just lost his father to suicide, and Elon had called him stupid,” Errol says. “Elon had this tendency to call people stupid. How could I possibly blame that child?”","chapterTitle":"","chapterDocIndex":"5","chapterHref":"","count":"9","percentage":"0.02512562814070352","page":""}',
#     'range': '{"characterRange":{"start":3687,"end":3696},"backward":false}',
#     'notes': 'But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and charismatic fantasist who to this day bedevils Elon.',
#     'percentage': 0.0,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'Elon Musk',
#     'bookAuthor': 'Walter Isaacson'}]},
# ...
#     'definitions': [{'enMeaning': 'used to refer to a Muslim extremist (= one who has beliefs that most people , including most Muslims , think are unreasonable and unacceptable ) who carries out or supports acts of terrorism (= violent action for political purposes ) against people who they believe are a threat to their religion :',
#       'chMeaning': ''}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'adjective',
#     'wordPrototype': 'jihadist',
#     'pronunciationUK': {'phonetic': '/ dʒɪˈhæd.ɪst /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english/uk_pron/c/cdo/cdo06/cdo0623ukjiha2239.mp3'},
#     'pronunciationUS': {'phonetic': '/ dʒəˈhɑːd.ɪst /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english/us_pron/c/cdo/cdo06/cdo0623usjiha2243.mp3'},
#     'definitions': [{'enMeaning': 'relating to the beliefs held by some Muslim extremists (= those who have beliefs that most people , including most Muslims , think are unreasonable and unacceptable ) who carry out or support acts of terrorism (= violent action for political purposes ) against people who they believe are a threat to their religion :',
#       'chMeaning': ''}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759133895874,
#     'bookKey': 1758640877074,
#     'date': '2025-09-29',
#     'chapter': 'The UN’s grim future',
#     'chapterIndex': 61,
#     'text': 'jihadist',
#     'cfi': '{"text":"MAGAfied","chapterTitle":"The UN’s grim future","chapterDocIndex":"61","chapterHref":"feed_12/article_0/index_u21.html","count":"28","page":"","percentage":"0.6261253706310461"}',
#     'range': '{"characterRange":{"start":9575,"end":9583},"backward":false}',
#     'notes': 'Having backed different sides of the civil war in Syria, America and Russia are supporting the government of the former jihadist, Ahmed al-Sharaa.',
#     'percentage': 0.6261253706310461,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 20th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/whims',
#   'partOfSpeech': [{'type': 'noun [ C ]',
#     'wordPrototype': 'whim',
#     'pronunciationUK': {'phonetic': '/ wɪm /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukw/ukwhi/ukwhich006.mp3'},
#     'pronunciationUS': {'phonetic': '/ wɪm /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/w/whi/whim_/whim.mp3'},
#     'definitions': [{'enMeaning': 'a sudden wish or idea , especially one that cannot be reasonably explained',
#       'chMeaning': '突然的念头 ， 冲动'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759133926703,
#     'bookKey': 1758640877074,
#     'date': '2025-09-29',
#     'chapter': 'The UN’s grim future',
#     'chapterIndex': 61,
#     'text': 'whims',
#     'cfi': '{"text":"Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general. Hustings to replace António Guterres in 2027 begin at the end of this year. Some candidates, such as Rafael Grossi, director-general of the IAEA, are jockeying for position. Until recently, there was talk of having a Latin American woman. Trumpists may find that too woke. Only half in jest, one insider proposes a woman dear to Mr Trump’s heart: his daughter, Ivanka. If that is what it takes to keep Mr Trump engaged, so be it. Desperate times, desperate measures. ■","chapterTitle":"The UN’s grim future","chapterDocIndex":"61","chapterHref":"feed_12/article_0/index_u21.html","count":"30","page":"","percentage":"0.6273490413865986"}',
#     'range': '{"characterRange":{"start":9787,"end":9793},"backward":false}',
#     'notes': 'Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general.',
#     'percentage': 0.6273490413865986,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 20th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/hangs on',
#   'partOfSpeech': [{'type': '',
#     'wordPrototype': 'hang on',
#     'pronunciationUK': {'phonetic': '/ hæŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukh/ukhan/ukhando013.mp3'},
#     'pronunciationUS': {'phonetic': '/ hæŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/h/han/hang_/hang.mp3'},
#     'definitions': [{'enMeaning': 'to wait for a short time',
#       'chMeaning': '稍等一会儿'},
#      {'enMeaning': 'to hold or continue holding onto something',
#       'chMeaning': '紧握 ， 抓住'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': '',
#     'wordPrototype': 'hang something on someone',
#     'pronunciationUK': {'phonetic': '/ hæŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukh/ukhan/ukhando013.mp3'},
#     'pronunciationUS': {'phonetic': '/ hæŋ /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/h/han/hang_/hang.mp3'},
#     'definitions': [{'enMeaning': 'to blame someone for something, especially something they did not do',
#       'chMeaning': '把 （尤指某人没做过的事）怪罪在（ 某人 ）头上'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759133935139,
#     'bookKey': 1758640877074,
#     'date': '2025-09-29',
#     'chapter': 'The UN’s grim future',
#     'chapterIndex': 61,
#     'text': 'hangs on',
#     'cfi': '{"text":"Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general. Hustings to replace António Guterres in 2027 begin at the end of this year. Some candidates, such as Rafael Grossi, director-general of the IAEA, are jockeying for position. Until recently, there was talk of having a Latin American woman. Trumpists may find that too woke. Only half in jest, one insider proposes a woman dear to Mr Trump’s heart: his daughter, Ivanka. If that is what it takes to keep Mr Trump engaged, so be it. Desperate times, desperate measures. ■","chapterTitle":"The UN’s grim future","chapterDocIndex":"61","chapterHref":"feed_12/article_0/index_u21.html","count":"30","page":"","percentage":"0.6273490413865986"}',
#     'range': '{"characterRange":{"start":9774,"end":9782},"backward":false}',
#     'notes': 'Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general.',
#     'percentage': 0.6273490413865986,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 20th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/Hustings',
#   'partOfSpeech': [{'type': 'noun',
#     'wordPrototype': 'hustings',
#     'pronunciationUK': {'phonetic': '/ ˈhʌs.tɪŋz /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukh/ukhur/ukhurly020.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈhʌs.tɪŋz /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cal/cald4/cald4us1188.mp3'},
#     'definitions': [{'enMeaning': 'the political activities and speeches that happen before an election and are intended to win votes',
#       'chMeaning': '竞选演讲拉票活动'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759133955749,
#     'bookKey': 1758640877074,
#     'date': '2025-09-29',
#     'chapter': 'The UN’s grim future',
#     'chapterIndex': 61,
#     'text': 'Hustings',
#     'cfi': '{"text":"Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general. Hustings to replace António Guterres in 2027 begin at the end of this year. Some candidates, such as Rafael Grossi, director-general of the IAEA, are jockeying for position. Until recently, there was talk of having a Latin American woman. Trumpists may find that too woke. Only half in jest, one insider proposes a woman dear to Mr Trump’s heart: his daughter, Ivanka. If that is what it takes to keep Mr Trump engaged, so be it. Desperate times, desperate measures. ■","chapterTitle":"The UN’s grim future","chapterDocIndex":"61","chapterHref":"feed_12/article_0/index_u21.html","count":"30","page":"","percentage":"0.6273490413865986"}',
#     'range': '{"characterRange":{"start":9854,"end":9863},"backward":false}',
#     'notes': 'Hustings to replace António Guterres in 2027 begin at the end of this year.',
#     'percentage': 0.6273490413865986,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 20th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/jockey',
#   'partOfSpeech': [{'type': 'noun [ C ]',
#     'wordPrototype': 'jockey',
#     'pronunciationUK': {'phonetic': '/ ˈdʒɒk.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukj/ukjim/ukjimda024.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈdʒɑː.ki /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/j/joc/jocke/jockey.mp3'},
#     'definitions': [{'enMeaning': 'a person whose job is riding horses in races',
#       'chMeaning': '职业赛马骑师'},
#      {'enMeaning': 'a person whose job involves the use of a particular device , vehicle , object , etc., or who is very interested in a particular thing',
#       'chMeaning': '（ 设备 、 车辆 、物件的） 操作者 ; 对 …非常感兴趣的人'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'verb [ I ]',
#     'wordPrototype': 'jockey',
#     'pronunciationUK': {'phonetic': '/ ˈdʒɒk.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukj/ukjim/ukjimda024.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈdʒɑː.ki /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/j/joc/jocke/jockey.mp3'},
#     'definitions': [{'enMeaning': 'to attempt to get power or get into a better position than other people using any methods you can',
#       'chMeaning': '运用各种手段谋利'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759133969428,
#     'bookKey': 1758640877074,
#     'date': '2025-09-29',
#     'chapter': 'The UN’s grim future',
#     'chapterIndex': 61,
#     'text': 'jockeying',
#     'cfi': '{"text":"Much hangs on the whims of Mr Trump, and the skill of the next UN secretary-general. Hustings to replace António Guterres in 2027 begin at the end of this year. Some candidates, such as Rafael Grossi, director-general of the IAEA, are jockeying for position. Until recently, there was talk of having a Latin American woman. Trumpists may find that too woke. Only half in jest, one insider proposes a woman dear to Mr Trump’s heart: his daughter, Ivanka. If that is what it takes to keep Mr Trump engaged, so be it. Desperate times, desperate measures. ■","chapterTitle":"The UN’s grim future","chapterDocIndex":"61","chapterHref":"feed_12/article_0/index_u21.html","count":"30","page":"","percentage":"0.6273490413865986"}',
#     'range': '{"characterRange":{"start":10004,"end":10014},"backward":false}',
#     'notes': 'Some candidates, such as Rafael Grossi, director-general of the IAEA, are jockeying for position.',
#     'percentage': 0.6273490413865986,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 20th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/tally',
#   'partOfSpeech': [{'type': 'verb [ I ]',
#     'wordPrototype': 'tally',
#     'pronunciationUK': {'phonetic': '/ ˈtæl.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukt/uktaj/uktajik028.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈtæl.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/t/tal/tally/tally.mp3'},
#     'definitions': [{'enMeaning': 'to match or agree with something else',
#       'chMeaning': '符合 ， 吻合'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'noun [ C usually singular ]',
#     'wordPrototype': 'tally',
#     'pronunciationUK': {'phonetic': '/ ˈtæl.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukt/uktaj/uktajik028.mp3'},
#     'pronunciationUS': {'phonetic': '/ ˈtæl.i /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/t/tal/tally/tally.mp3'},
#     'definitions': [{'enMeaning': 'a record or count of a number of things',
#       'chMeaning': '计数 ； 记录 ； 比分'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759136540154,
#     'bookKey': 1758768412594,
#     'date': '2025-09-29',
#     'chapter': 'Xi Jinping’s anti-American party',
#     'chapterIndex': 9,
#     'text': 'tally',
#     'cfi': '{"text":"Xi Jinping’s anti-American party","chapterTitle":"Xi Jinping’s anti-American party","chapterDocIndex":"9","chapterHref":"feed_1/article_2/index_u68.html","count":"3","page":"","percentage":"0.07297537169662172"}',
#     'range': '{"characterRange":{"start":133,"end":138},"backward":false}',
#     'notes': 'To see the cost of Trump’s bullying, tally the world leaders flocking to China',
#     'percentage': 0.0729753716966217,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 6th 2025]',
#     'bookAuthor': 'calibre'}]},
#  {'wordUrl': 'https://dictionary.cambridge.org/dictionary/english-chinese-simplified/flock',
#   'partOfSpeech': [{'type': 'noun',
#     'wordPrototype': 'flock',
#     'pronunciationUK': {'phonetic': '/ flɒk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukf/ukfli/ukflirt007.mp3'},
#     'pronunciationUS': {'phonetic': '/ flɑːk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/f/flo/flock/flock.mp3'},
#     'definitions': [{'enMeaning': 'a group of sheep , goats , or birds',
#       'chMeaning': '羊群 ; 鸟群 ; 人群'},
#      {'enMeaning': 'a large group of people , usually people of a particular type',
#       'chMeaning': '（特定类型的）一群人'},
#      {'enMeaning': 'soft material used for filling objects such as cushions , or soft material that forms a raised pattern on wallpaper or curtains',
#       'chMeaning': '（充填垫子等的） 软填料 ；（在墙纸或窗帘上制作凸起图案用的） 短绒 ， 绒屑'}],
#     'phrases': [],
#     'phraseDefinitions': []},
#    {'type': 'verb',
#     'wordPrototype': 'flock',
#     'pronunciationUK': {'phonetic': '/ flɒk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukf/ukfli/ukflirt007.mp3'},
#     'pronunciationUS': {'phonetic': '/ flɑːk /',
#      'pronUrl': 'https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/f/flo/flock/flock.mp3'},
#     'definitions': [{'enMeaning': 'to move or come together in large numbers',
#       'chMeaning': '聚集 ； 蜂拥'},
#      {'enMeaning': 'to cover a surface with a soft material in order to decorate it',
#       'chMeaning': '用软材料覆盖表面装饰'}],
#     'phrases': [],
#     'phraseDefinitions': []}],
#   'sentences': [{'key': 1759136556241,
#     'bookKey': 1758768412594,
#     'date': '2025-09-29',
#     'chapter': 'Xi Jinping’s anti-American party',
#     'chapterIndex': 9,
#     'text': 'flocking',
#     'cfi': '{"text":"Xi Jinping’s anti-American party","chapterTitle":"Xi Jinping’s anti-American party","chapterDocIndex":"9","chapterHref":"feed_1/article_2/index_u68.html","count":"3","page":"","percentage":"0.07297537169662172"}',
#     'range': '{"characterRange":{"start":157,"end":165},"backward":false}',
#     'notes': 'To see the cost of Trump’s bullying, tally the world leaders flocking to China',
#     'percentage': 0.0729753716966217,
#     'color': '#FBF1D1',
#     'tag': nan,
#     'highlightType': 'background',
#     'bookName': 'The Economist [Sep 6th 2025]',
#     'bookAuthor': 'calibre'}]}]

# %%
def replace_alnum_with_underscores(match_obj: re.Match) -> str:
    """
    接收一个正则表达式匹配对象，
    并将其中的字母和数字替换为下划线。
    """
    word = match_obj.group(0)
    return ''.join(['_' if char.isalnum() else char for char in word])

def build_html_from_word_info(word_info: Dict[str, Any]) -> Dict[str, str]:
    """
    根据 word_info 构建笔记中各个字段的 HTML 内容。
    """
    # ... (此函数的其他部分与您原脚本类似，为了简洁此处省略了定义和短语部分)
    pos_html_parts: List[str] = []
    pronunciation_parts: List[str] = []
    definition_parts: List[str] = []
    examples_parts: List[str] = []
    blanked_examples_parts: List[str] = []
    
    word_to_highlight = word_info.get("word", "")

    # 处理发音、释义等
    for pos in word_info.get("partOfSpeech", []):
        pos_type = pos.get("type", "")
        pos_title_html = f"<div class='pos-title'>{html.escape(str(pos_type)).capitalize()}</div>" if pos_type else ""
        
        # 发音
        # 发音
        uk = pos.get("pronunciationUK") or {}
        us = pos.get("pronunciationUS") or {}
        audio_lines: List[str] = []
        if uk.get("phonetic") or uk.get("pronUrl"):
            aud = f"UK: {html.escape(uk.get('phonetic',''))}"
            if uk.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(uk.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if us.get("phonetic") or us.get("pronUrl"):
            aud = f"US: {html.escape(us.get('phonetic',''))}"
            if us.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(us.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if audio_lines:
            pronunciation_parts.extend(audio_lines)
        
        # 释义
        defs = pos.get("definitions") or []
        if defs:
            def_block = [pos_title_html, "<ul>"]
            for d in defs:
                en = (d.get("enMeaning") or "").strip()
                ch = (d.get("chMeaning") or "").strip()
                def_block.append(f"<li><div class='definition-en'>{html.escape(en)}</div><div class='definition-ch'>{html.escape(ch)}</div></li>")
            def_block.append("</ul>")
            definition_parts.append("".join(def_block))
        # 处理词性/定义/短语
    
    for pos in word_info.get("partOfSpeech", []):
        pos_type = pos.get("type", "")
        part_lines: List[str] = []
        part_lines.append(f"<div class='pos-title'>{html.escape(str(pos_type)).capitalize()}</div>")

        # 发音
        uk = pos.get("pronunciationUK") or {}
        us = pos.get("pronunciationUS") or {}
        audio_lines: List[str] = []
        if uk.get("phonetic") or uk.get("pronUrl"):
            aud = f"UK: {html.escape(uk.get('phonetic',''))}"
            if uk.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(uk.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if us.get("phonetic") or us.get("pronUrl"):
            aud = f"US: {html.escape(us.get('phonetic',''))}"
            if us.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(us.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if audio_lines:
            part_lines.extend(audio_lines)

        # 定义
        defs = pos.get("definitions") or []
        if defs:
            part_lines.append("<ul>")
            for d in defs:
                en = (d.get("enMeaning") or d.get("en") or "").strip()
                ch = (d.get("chMeaning") or d.get("ch") or "").strip()
                part_lines.append(
                    "<li>"
                    f"<div class='definition-en'>{html.escape(en)}</div>"
                    f"<div class='definition-ch'>{html.escape(ch)}</div>"
                    "</li>"
                )
            part_lines.append("</ul>")

        # 短语
        phrases = pos.get("phrases") or []
        phrase_defs = pos.get("phraseDefinitions") or []
        if phrases:
            part_lines.append("<div><b>Phrases:</b><ul>")
            for i, ph in enumerate(phrases):
                pd = phrase_defs[i] if i < len(phrase_defs) else {}
                en = (pd.get("enMeaning") or pd.get("en") or "").strip()
                ch = (pd.get("chMeaning") or pd.get("ch") or "").strip()
                part_lines.append(
                    "<li>"
                    f"<span class='phrase'>{html.escape(ph)}</span> — <span class='definition-en'>{html.escape(en)}</span>"
                    f"<div class='definition-ch'>{html.escape(ch)}</div>"
                    "</li>"
                )
            part_lines.append("</ul></div>")

        pos_html_parts.append("<div>" + "\n".join(part_lines) + "</div>")

    # 处理例句
    for s in word_info.get("sentences", []):
        sentence_text = s.get("notes").strip()
        if not sentence_text:
            continue
        
        # 1. 'Examples' 字段: 目标词加粗
        escaped_sentence = html.escape(sentence_text)
        highlighted = escaped_sentence
        target_word = s.get("text") or word_to_highlight # 用于加粗的目标词
        if target_word:
            try:
                pattern = re.compile(r'\b' + re.escape(html.escape(target_word.strip())) + r'\b', re.IGNORECASE)

                highlighted = pattern.sub(lambda m: f"<strong>{m.group(0)}</strong>", escaped_sentence)
            except re.error:
                pass # 忽略正则错误
        escaped_target = html.escape(target_word.strip())
        if " " in target_word:
            # 多词短语，不加 \b
            pattern_for_blanking = re.compile(re.escape(escaped_target), re.IGNORECASE)
        else:
            # 单词，加边界防止误匹配
            pattern_for_blanking = re.compile(r'\b' + re.escape(escaped_target) + r'\b', re.IGNORECASE)
        # pattern_for_blanking = re.compile(r'\b' + re.escape(target_word) + r'\b', re.IGNORECASE)
        # 2. 'Blanked_Examples' 字段: 所有单词字母替换为下划线
        blanked_sentence = pattern_for_blanking.sub(replace_alnum_with_underscores, sentence_text)
        escaped_blanked = html.escape(blanked_sentence)

        # 来源信息
        book = s.get("bookName") or ""
        meta = f" — 《{html.escape(book)}》" if book else ""

        examples_parts.append(f"<div class='example'><div class='example-text'>{highlighted}</div><div class='example-meta'>{meta}</div></div>")
        blanked_examples_parts.append(f"<div class='example'><div class='example-text'>{escaped_blanked}</div><div class='example-meta'>{meta}</div></div>")

    return {
        "POS_Definitions": "\n".join(pos_html_parts),
        "Pronunciation": "\n".join(pronunciation_parts),
        "Definition": "\n".join(definition_parts),
        "Examples": "\n".join(examples_parts),
        "Blanked_Examples": "\n".join(blanked_examples_parts)
    }

# %%
build_html_from_word_info(word_list[5])
# Out:
# {'POS_Definitions': '<div><div class=\'pos-title\'>Adjective</div>\n<div class=\'audio-row\'>UK: / ˌpær.əˈmɪl.ɪ.tri / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3"></audio></div>\n<div class=\'audio-row\'>US: / ˌper.əˈmɪl.ə.ter.i / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3"></audio></div>\n<ul>\n<li><div class=\'definition-en\'>A paramilitary group is organized like an army but is not official and often not legal .</div><div class=\'definition-ch\'>准军事的 ， 非法军事组织的</div></li>\n<li><div class=\'definition-en\'>connected with and helping the official armed forces</div><div class=\'definition-ch\'>与正规军有联系的 ， 辅助军事的</div></li>\n</ul></div>\n<div><div class=\'pos-title\'>Noun [ c ]</div>\n<div class=\'audio-row\'>UK: / ˌpær.əˈmɪl.ɪ.tri / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3"></audio></div>\n<div class=\'audio-row\'>US: / ˌper.əˈmɪl.ə.ter.i / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3"></audio></div>\n<ul>\n<li><div class=\'definition-en\'>a person who belongs to a paramilitary organization</div><div class=\'definition-ch\'>准军事组织成员</div></li>\n</ul></div>',
#  'Pronunciation': '<div class=\'audio-row\'>UK: / ˌpær.əˈmɪl.ɪ.tri / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3"></audio></div>\n<div class=\'audio-row\'>US: / ˌper.əˈmɪl.ə.ter.i / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3"></audio></div>\n<div class=\'audio-row\'>UK: / ˌpær.əˈmɪl.ɪ.tri / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/uk_pron/u/ukp/ukpar/ukparag014.mp3"></audio></div>\n<div class=\'audio-row\'>US: / ˌper.əˈmɪl.ə.ter.i / <audio controls src="https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/p/par/param/paramilitary.mp3"></audio></div>',
#  'Definition': "<div class='pos-title'>Adjective</div><ul><li><div class='definition-en'>A paramilitary group is organized like an army but is not official and often not legal .</div><div class='definition-ch'>准军事的 ， 非法军事组织的</div></li><li><div class='definition-en'>connected with and helping the official armed forces</div><div class='definition-ch'>与正规军有联系的 ， 辅助军事的</div></li></ul>\n<div class='pos-title'>Noun [ c ]</div><ul><li><div class='definition-en'>a person who belongs to a paramilitary organization</div><div class='definition-ch'>准军事组织成员</div></li></ul>",
#  'Examples': "<div class='example'><div class='example-text'>“It was a <strong>paramilitary</strong> Lord of the Flies,” he recalls.</div><div class='example-meta'> — 《Elon Musk》</div></div>",
#  'Blanked_Examples': "<div class='example'><div class='example-text'>“It was a ____________ Lord of the Flies,” he recalls.</div><div class='example-meta'> — 《Elon Musk》</div></div>"}

# %%
ANKI_CONNECT_URL = "http://localhost:8765"
MODEL_NAME = "WordType"
REQUEST_TIMEOUT = 10.0

def invoke(action: str, **params):
    try:
        r = requests.post(
            ANKI_CONNECT_URL,
            json={"action": action, "version": 6, "params": params},
            timeout=REQUEST_TIMEOUT
        )
        r.raise_for_status()
        return r.json()
    except requests.RequestException as e:
        print(f"[错误] 无法连接 AnkiConnect（{ANKI_CONNECT_URL}）：{e}")
        sys.exit(1)

# %%
deck_name = "CambridgeDeck"
# word_list_sub = word_list[1:2]
for word_info in word_list:
    result = {"created": False, "created_note_result": None, "updated": [], "skipped": [], "errors": []}
    word = word_prototype = word_info.get("partOfSpeech")[0].get("wordPrototype", "")
    print(word)
    query = f'deck:"{deck_name}" "Word:{word}"'
    try:
        find_res = invoke("findNotes", query=query)
    except Exception as e:
        result["errors"].append(f"findNotes 调用异常: {e}")

    note_ids = find_res.get("result", []) or []
    if note_ids:
        res = build_html_from_word_info(word_info)
        blanked_sentences = res["Blanked_Examples"]
        pronunciation = res["Pronunciation"]
        definition = res["Definition"]

        r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Blanked_Examples": blanked_sentences}})
        # print(r)

        r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Definition": definition}})
        # print(r)

        r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Pronunciation": pronunciation}})
        print(r)

        note_id = note_ids[0]
        invoke("updateNoteFields", note={"id": note_id, "fields": {"Blanked_Examples": blanked_sentences}})

        # 验证是否真的更新了
        info = invoke("notesInfo", notes=[note_id])
        print(info["result"][0]["fields"]["Blanked_Examples"]["value"])
# Out:
# burst up to six feet
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He had gotten much bigger, ________ __ __ ___ ____ with a bearlike frame, and had learned some judo.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# pick on someone
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>As a result, he was regularly ______ __ __ _______, who would come up and punch him in the face.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ballistic
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>My father just lost it, ____ _________, as he often did.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# juvenile prison
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Both Elon and Kimbal, who no longer speak to their father, say his claim that Elon provoked the attack is unhinged and that the perpetrator ended up being sent to ________ ______ for it.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# dude
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Did you think I was also going to be a chill, normal ____?</div><div class='example-meta'> — 《Elon Musk》</div></div>
# paramilitary
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>“It was a ____________ Lord of the Flies,” he recalls.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# rations
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The kids were each given small _______ of food and water, and they were allowed—indeed encouraged—to fight over them.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# mind-blowing
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>“It was so insane, ____-_______,” Musk recalls.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# guidance counselor
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The __________ would recount such stories as warnings.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# recount
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The counselors would _______ such stories as warnings.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# judo
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He had gotten much bigger, bursting up to six feet with a bearlike frame, and had learned some ____.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# apartheid
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Once, when Elon and Kimbal got off a train on their way to an anti-_________ music concert, they had to wade through a pool of blood next to a dead person with a knife still sticking out of his brain.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# sole
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>For the rest of the evening, the blood on the _____ of their sneakers made a sticky sound against the pavement.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# stare
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In recounting the story, Musk pauses and ______ vacantly for a very long time.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# vacantly
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In recounting the story, Musk pauses and stares ________ for a very long time.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# searing
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>His most _______ experiences came at school.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# instinct
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Empathy did not come naturally, and he had neither the desire nor the ________ to be ingratiating.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ingratiating
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Empathy did not come naturally, and he had neither the desire nor the instinct to be ____________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# horse around
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At assembly one morning, a student who was _______ ______ with a gang of friends bumped into him.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# bump into someone
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At assembly one morning, a student who was horsing around with a gang of friends ______ ____ him.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# recess
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The boy and his friends hunted Elon down at ______ and found him eating a sandwich.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# swollen
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It was such a _______ ball of flesh that you could barely see his eyes.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# corrective
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Decades later, he was still getting __________ surgery to try to fix the tissues inside his nose.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# inflict
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But those scars were minor compared to the emotional ones _________ by his father, Errol Musk, an engineer, rogue, and charismatic fantasist who to this day bedevils Elon.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# rogue
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, _____, and charismatic fantasist who to this day bedevils Elon.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# charismatic
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and ___________ fantasist who to this day bedevils Elon.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fantasist
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and charismatic _________ who to this day bedevils Elon.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# bedevil
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But those scars were minor compared to the emotional ones inflicted by his father, Errol Musk, an engineer, rogue, and charismatic fantasist who to this day ________ Elon.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# pummel
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>After the school fight, Errol sided with the kid who ________ Elon’s face.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# berate
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When Elon finally came home from the hospital, his father _______ him.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# tirade
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Kimbal, who had to watch the ______, says it was the worst memory of his life.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# provoke
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Both Elon and Kimbal, who no longer speak to their father, say his claim that Elon ________ the attack is unhinged and that the perpetrator ended up being sent to juvenile prison for it.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# unhinged
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Both Elon and Kimbal, who no longer speak to their father, say his claim that Elon provoked the attack is ________ and that the perpetrator ended up being sent to juvenile prison for it.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# perpetrator
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Both Elon and Kimbal, who no longer speak to their father, say his claim that Elon provoked the attack is unhinged and that the ___________ ended up being sent to juvenile prison for it.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# spin
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They say their father is a volatile fabulist, regularly ________ _____ that are larded with fantasies, sometimes calculated and at other times delusional.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# get conditioned in
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>I think he ___ ___________ __ childhood that life is pain.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# volatile
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They say their father is a ________ fabulist, regularly spinning tales that are larded with fantasies, sometimes calculated and at other times delusional.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# lard something with something
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They say their father is a volatile fabulist, regularly spinning tales that are ______ ____ fantasies, sometimes calculated and at other times delusional.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# delusional
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They say their father is a volatile fabulist, regularly spinning tales that are larded with fantasies, sometimes calculated and at other times __________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Jekyll and Hyde
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He has a ______-___-____ nature, they say.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# unrelenting
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>One minute he would be friendly, the next he would launch into an hour or more of ___________ abuse.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Rolls-Royce
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At one point he drove a _____-_____, built a wilderness lodge with his boys, and got raw emeralds from a mine owner in Zambia, until that business collapsed.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# lodge
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At one point he drove a Rolls-Royce, built a wilderness _____ with his boys, and got raw emeralds from a mine owner in Zambia, until that business collapsed.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# emerald
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At one point he drove a Rolls-Royce, built a wilderness lodge with his boys, and got raw ________ from a mine owner in Zambia, until that business collapsed.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# tame
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Their experiences with me would have made veldskool quite ____</div><div class='example-meta'> — 《Elon Musk》</div></div>
# thug
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>New boys were forced to fight the school ____ on their first day at a new school.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# concede
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He proudly ________ that he exercised “an extremely stern streetwise autocracy” with his boys.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# stern
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He proudly concedes that he exercised “an extremely _____ streetwise autocracy” with his boys.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# streetwise
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He proudly concedes that he exercised “an extremely stern __________ autocracy” with his boys.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# adversity
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>_________ shaped me</div><div class='example-meta'> — 《Elon Musk》</div></div>
# malady
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>and I suppose that may explain my particular ______.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# psyche
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In Elon Musk’s case, his father’s impact on his ______ would linger, despite many attempts to banish him, both physically and psychologically.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# linger
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In Elon Musk’s case, his father’s impact on his psyche would ______, despite many attempts to banish him, both physically and psychologically.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# banish
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In Elon Musk’s case, his father’s impact on his psyche would linger, despite many attempts to ______ him, both physically and psychologically.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# intense
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Elon’s moods would cycle through light and dark, _______ and goofy, detached and emotional, with occasional plunges into what those around him dreaded as “demon mode.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# goofy
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Elon’s moods would cycle through light and dark, intense and _____, detached and emotional, with occasional plunges into what those around him dreaded as “demon mode.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# detached
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Elon’s moods would cycle through light and dark, intense and goofy, ________ and emotional, with occasional plunges into what those around him dreaded as “demon mode.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# dreaded
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Elon’s moods would cycle through light and dark, intense and goofy, detached and emotional, with occasional plunges into what those around him _______ as “demon mode.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# specter
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Unlike his father, he would be caring with his kids, but in other ways, his behavior would hint at a danger that needed to be constantly battled: the _______ that, as his mother put it, “he might become his father.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# resonant
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It’s one of the most ________ tropes in mythology.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# trope
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It’s one of the most resonant ______ in mythology.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# mythology
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It’s one of the most resonant tropes in _________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# exorcise
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>To what extent does the epic quest of the Star Wars hero require __________ demons bequeathed by Darth Vader and wrestling with the dark side of the Force?</div><div class='example-meta'> — 《Elon Musk》</div></div>
# bequeath
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>To what extent does the epic quest of the Star Wars hero require exorcising demons __________ by Darth Vader and wrestling with the dark side of the Force?</div><div class='example-meta'> — 《Elon Musk》</div></div>
# moron
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>If your father is always calling you a _____ and idiot, maybe the only response is to turn off anything inside that would’ve opened up an emotional dimension that he didn’t have tools to deal with.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# valve
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>This emotional shutoff _____ could make him callous, but it also made him a risk-seeking innovator.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# callous
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>This emotional shutoff valve could make him _______, but it also made him a risk-seeking innovator.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# aversion
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The PTSD from his childhood also instilled in him an ________ to contentment.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# thrashing
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>During a particularly hellish period of his life in 2008, after the first three launches of his SpaceX rockets exploded and Tesla was about to go bankrupt, he would wake up _________ and recount to Talulah Riley, who became his second wife, the horrendous things his father had once said.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# horrendous
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>During a particularly hellish period of his life in 2008, after the first three launches of his SpaceX rockets exploded and Tesla was about to go bankrupt, he would wake up thrashing and recount to Talulah Riley, who became his second wife, the __________ things his father had once said.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# zone out
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When he recalled these memories, he would ____ ___ and seem to disappear behind his steel-colored eyes.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# stunted
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But he’s retained a childlike, almost _______ side.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# cauldron
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Out of this ________, Musk developed an aura that made him seem, at times, like an alien, as if his Mars mission were an aspiration to return home and his desire to build humanoid robots were a quest for kinship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# aura
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Out of this cauldron, Musk developed an ____ that made him seem, at times, like an alien, as if his Mars mission were an aspiration to return home and his desire to build humanoid robots were a quest for kinship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# humanoid
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Out of this cauldron, Musk developed an aura that made him seem, at times, like an alien, as if his Mars mission were an aspiration to return home and his desire to build ________ robots were a quest for kinship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# navel
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>You’d not be totally shocked if he ripped off his shirt and you discovered that he had no _____ and was not of this planet born.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fervour
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He developed a ______ that cloaked his goofiness, and a goofiness that cloaked his ______.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# cloak
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He developed a fervor that _______ his goofiness, and a goofiness that _______ his fervor.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# board seat
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He had been offered a _____ ____ at Twitter, but over the weekend he concluded that wasn’t enough.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# pull the trigger on his plan
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Right after he finished, he ______ ___ _______ __ ___ ____ and went on Twitter.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# jig
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>lightly uncomfortable in his own body, like a big man who was never an athlete, he would walk with the stride of a mission-driven bear and dance ____ that seemed taught by a robot.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# conviction
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With the __________ of a prophet, he would speak about the need to nurture the flame of human consciousness, fathom the universe, and save our planet.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# prophet
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With the conviction of a _______, he would speak about the need to nurture the flame of human consciousness, fathom the universe, and save our planet.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# consciousness
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With the conviction of a prophet, he would speak about the need to nurture the flame of human _____________, fathom the universe, and save our planet.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fathom
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With the conviction of a prophet, he would speak about the need to nurture the flame of human consciousness, ______ the universe, and save our planet.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# boost
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At first I thought this was mainly role-playing, the team-________ pep talks and podcast fantasies of a man-child who had read The Hitchhiker’s Guide to the Galaxy once too often.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# hitchhiker
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At first I thought this was mainly role-playing, the team-boosting pep talks and podcast fantasies of a man-child who had read The __________’s Guide to the Galaxy once too often.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# pep
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At first I thought this was mainly role-playing, the team-boosting ___ talks and podcast fantasies of a man-child who had read The Hitchhiker’s Guide to the Galaxy once too often.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# feverishly
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He could calculate it coldly and also embrace it __________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# craving
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He developed a siege mentality that included an attraction, sometimes a _______, for storm and drama, both at work and in the romantic relationships he struggled and failed to maintain.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# thrive
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He _______ on crises, deadlines, and wild surges of work.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# surge
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He thrived on crises, deadlines, and wild ______ of work.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# tortuous
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When he faced ________ challenges, the strain would often keep him awake at night and make him vomit.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# vomit
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When he faced tortuous challenges, the strain would often keep him awake at night and make him _____.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# compulsion
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>That’s his __________, the theme of his life.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# summarily
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He would have treated everyone there like family and not _________ fired people.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ruefully
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Tesla selling close to a million cars, and him becoming the richest man on Earth—Musk spoke ________ about his compulsion to stir up dramas.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# mindset
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>I need to shift my _______ away from being in crisis mode,” he told me</div><div class='example-meta'> — 《Elon Musk》</div></div>
# wistful
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It was a _______ comment, not a New Year’s resolution.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# pledge
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Even as he made the ______, he was secretly buying up shares of Twitter, the world’s ultimate playground.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# snuck
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>That April, he _____ away to the Hawaiian house of his mentor Larry Ellison, founder of Oracle, accompanied by the actress Natasha Bassett, an occasional girlfriend.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# mentor
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>That April, he snuck away to the Hawaiian house of his ______ Larry Ellison, founder of Oracle, accompanied by the actress Natasha Bassett, an occasional girlfriend.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# outright
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>So he decided he would make a hostile bid to buy the company ________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# construction hand
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>For the next few years, he worked as a cowboy, rodeo performer, and ____________ ____.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# lit out
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>So she ___ ___ by train to Chicago and then New York City.</div><div class='example-meta'> — 《Elon Musk》</div></div>
#
# Kalahari Desert
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When Joshua and Winnifred were young, a charlatan named William Hunt, known (at least to himself) as “the Great Farini,” came to Moose Jaw and told tales of an ancient “lost city” he had seen when crossing the ________ ______ in South Africa.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# tie for first place
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They embarked on long-distance flights to places such as Norway, ____ ___ _____ _____ in the twelve-thousand-mile Cape Town–to-Algiers motor rally, and became the first to fly a single-engine plane from Africa to Australia.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# motor rally
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They embarked on long-distance flights to places such as Norway, tied for first place in the twelve-thousand-mile Cape Town–to-Algiers _____ _____, and became the first to fly a single-engine plane from Africa to Australia.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# regard
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>__ ____ ______, he took after his maternal grandfather, Joshua Haldeman, a daredevil adventurer with strongly held opinions who was raised on a farm on the barren plains of central Canada.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# maternal
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In that regard, he took after his ________ grandfather, Joshua Haldeman, a daredevil adventurer with strongly held opinions who was raised on a farm on the barren plains of central Canada.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# daredevil
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In that regard, he took after his maternal grandfather, Joshua Haldeman, a _________ adventurer with strongly held opinions who was raised on a farm on the barren plains of central Canada.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# barren
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In that regard, he took after his maternal grandfather, Joshua Haldeman, a daredevil adventurer with strongly held opinions who was raised on a farm on the ______ plains of central Canada.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# chiropractic
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He studied ____________ techniques in Iowa, then returned to his hometown near Moose Jaw, where he broke in horses and gave ____________ adjustments in exchange for food and lodging.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# break someone in
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He studied chiropractic techniques in Iowa, then returned to his hometown near Moose Jaw, where he _____ __ horses and gave chiropractic adjustments in exchange for food and lodging.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# rodeo
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>For the next few years, he worked as a cowboy, _____ performer, and construction hand.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# hobo
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He married and divorced, traveled as a ____ on freight trains, and was a stowaway on an oceangoing ship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# stowaway
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He married and divorced, traveled as a hobo on freight trains, and was a ________ on an oceangoing ship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ocean-going
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He married and divorced, traveled as a hobo on freight trains, and was a stowaway on an __________ ship.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# populism
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The loss of his farm instilled in him a ________, and he became active in a movement known as the Social Credit Party, which advocated giving citizens free credit notes they could use like currency.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fundamentalist
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The movement had a conservative ______________ streak tinged with anti-Semitism.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# antisemitism
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The movement had a conservative fundamentalist streak tinged with anti-________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# decry
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Its first leader in Canada _______ a “perversion of cultural ideals” because “a disproportionate number of Jews occupy positions of control.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# perversion
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Its first leader in Canada decried a “__________ of cultural ideals” because “a disproportionate number of Jews occupy positions of control.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# disproportionate
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Its first leader in Canada decried a “perversion of cultural ideals” because “a ________________ number of Jews occupy positions of control.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# enlisted
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He also ________ in a movement called Technocracy, which believed that government should be run by technocrats rather than politicians.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# defy
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Haldeman ______ the ban by taking out a newspaper ad supporting the movement.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ballroom
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At one point he wanted to learn ________ dancing, which is how he met Winnifred Fletcher, whose adventurous streak was equal to his.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# streak
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At one point he wanted to learn ballroom dancing, which is how he met Winnifred Fletcher, whose adventurous ______ was equal to his.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# impetuous
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It was rather _________, since Haldeman did not know how to fly.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# chiropractor
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The family came to be known as The Flying Haldemans, and he was described by a chiropractic trade journal as “perhaps the most remarkable figure in the history of flying _____________,” a rather narrow, albeit accurate, accolade.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# accolade
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The family came to be known as The Flying Haldemans, and he was described by a chiropractic trade journal as “perhaps the most remarkable figure in the history of flying chiropractors,” a rather narrow, albeit accurate, ________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# toddler
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They bought a larger single-engine plane, a Bellanca, when Maye and Kaye were three months old, and the ________ became known as “the flying twins.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# populist
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With his quirky conservative ________ views, Haldeman came to believe that the Canadian government was usurping too much control over the lives of individuals and that the country had gone soft.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# quirky
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With his ______ conservative populist views, Haldeman came to believe that the Canadian government was usurping too much control over the lives of individuals and that the country had gone soft.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# usurp
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>With his quirky conservative populist views, Haldeman came to believe that the Canadian government was ________ too much control over the lives of individuals and that the country had gone soft.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# take something apart
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They ____ _____ the Bellanca, crated it, and boarded a freighter for Cape Town.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# crate
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They took apart the Bellanca, ______ it, and boarded a freighter for Cape Town.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# freighter
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They took apart the Bellanca, crated it, and boarded a _________ for Cape Town.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Afrikaans
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Haldeman decided he wanted to live inland, so they took off toward Johannesburg, where most of the white citizens spoke English rather than _________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Pretoria
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But as they flew over nearby ________, the lavender jacaranda flowers were in bloom, and Haldeman announced, “This is where we’ll stay.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# lavender
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But as they flew over nearby Pretoria, the ________ jacaranda flowers were in bloom, and Haldeman announced, “This is where we’ll stay.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# jacaranda
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But as they flew over nearby Pretoria, the lavender _________ flowers were in bloom, and Haldeman announced, “This is where we’ll stay.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# charlatan
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When Joshua and Winnifred were young, a _________ named William Hunt, known (at least to himself) as “the Great Farini,” came to Moose Jaw and told tales of an ancient “lost city” he had seen when crossing the Kalahari Desert in South Africa.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# trek
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Once in Africa, the Haldemans made a monthlong ____ into the Kalahari every year to search for this legendary city.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fend someone off
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They hunted for their own food and slept with their guns so they could ____ ___ lions.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# motto
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The family adopted a _____: “Live dangerously—carefully.”</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Algiers
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They embarked on long-distance flights to places such as Norway, tied for first place in the twelve-thousand-mile Cape Town–to-_______ motor rally, and became the first to fly a single-engine plane from Africa to Australia.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# goofiness
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He developed a fervor that cloaked his _________, and a _________ that cloaked his fervor.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# runway show
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Tall and blue-eyed, with high cheekbones and sculpted chin, she began working at age fifteen as a model, doing department store ______ _____ on Saturday mornings.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# caddish
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Around that time, she met a boy in her neighborhood who was also strikingly good-looking, albeit in a smooth and _______ way.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# fighter-bomber
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>His mother, Cora, was from England, where she finished school at fourteen, worked at a factory making skins for _______-_______, then took a refugee ship to South Africa.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# cryptographer
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>There she met Walter Musk, a _____________ and military intelligence officer who worked in Egypt on schemes to fool the Germans by deploying fake weapons and searchlights.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Buick
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>So Cora left him, went back to England with their two sons, bought a _____, and then returned to Pretoria.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# wind up with
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>If you registered it, you would ____ __ ____ nothing, because the Blacks would take everything from you,” Errol says.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# ownership stake
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Errol, who never had an _________ _____ in the mine, expanded his trade by importing raw emeralds and having them cut in Johannesburg.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# freak out
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When his mother saw him coming down the road, she _______ ___.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# awe
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Kimbal remembers standing beneath the tree and staring at his older brother __ ___.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# make his case
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He would stand next to his father’s chair and ____ ___ ____, over and over.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Yamaha
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>His father finally caved and got Elon a blue-and-gold 50cc ______.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# wander
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Elon also had a tendency to be spacey and ______ ___ on his own, oblivious to what others were doing.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# stay put
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It was not in his nature to ____ ___, so he started wandering the streets.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# solar roof construction site
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Years later, I watched him at a _____ ____ ____________ ____ with his two-year-old boy, known as X.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# cast big shadows
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It was 10 p.m., and there were forklifts and other moving equipment lit by two spotlights that ____ ___ _______.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# Durban
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Maye and the children moved to a house on the coast near ______, about 380 miles south of the Pretoria-Johannesburg area, where she juggled jobs as a model and dietician.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# impulsive
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>His heritage and breeding, along with the hardwiring of his brain, made him at times callous and _________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# siege mentality
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>He developed a _____ _________ that included an attraction, sometimes a craving, for storm and drama, both at work and in the romantic relationships he struggled and failed to maintain.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# strain
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>When he faced tortuous challenges, the ______ would often keep him awake at night and make him vomit.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# imprint
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Haldeman _________ that spirit onto one of his twin girls, Elon’s mother, Maye.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# strikingly
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>She was also __________ good-looking.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# cheekbone
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Tall and blue-eyed, with high __________ and sculpted chin, she began working at age fifteen as a model, doing department store runway shows on Saturday mornings.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# smooth
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Around that time, she met a boy in her neighborhood who was also strikingly good-looking, albeit in a ______ and caddish way.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# wheeler-dealer
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Errol Musk was an adventurer and _______-______, always on the lookout for the next opportunity.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# lookout
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Errol Musk was an adventurer and wheeler-dealer, always __ ___ _______ ___ the next opportunity.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# refugee
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>His mother, Cora, was from England, where she finished school at fourteen, worked at a factory making skins for fighter-bombers, then took a _______ ship to South Africa.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# searchlight
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>There she met Walter Musk, a cryptographer and military intelligence officer who worked in Egypt on schemes to fool the Germans by deploying fake weapons and ____________.</div><div class='example-meta'> — 《Elon Musk》</div></div>
# armchair
# {'result': None, 'error': None}
# ...
# arrears
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>An outright rupture with America could come in 2027 if its budget _______ reach two years’ worth of contributions, the level at which a country stands to lose its vote in the General Assembly.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# deliberative
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>This ____________ body makes mostly non-binding pronouncements, and America could veto any attempt to force it off the Security Council.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# non-binding
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>This deliberative body makes mostly ___-_______ pronouncements, and America could veto any attempt to force it off the Security Council.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# pronouncement
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>This deliberative body makes mostly non-binding ______________, and America could veto any attempt to force it off the Security Council.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# retaliation
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>But the humiliation might provoke ___________, if not America’s exit.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# catalyst
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Palestine is the another potential ________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# steep something/someone in something
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>In turn, Israel and the Trump administration think the UN is _______ __ antisemitism.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# escalate
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The latest movement to recognise Palestinian statehood, led by France and Saudi Arabia, could ________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# Saudi Arabia
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The latest movement to recognise Palestinian statehood, led by France and _____ ______, could escalate.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# visa
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The Trump administration has denied _____ for the Palestinian delegation to attend next week’s meeting.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# Palestinian
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The Trump administration has denied visas for the ___________ delegation to attend next week’s meeting.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# sprawling
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The administration now objects to the Sustainable Development Goals (SDGs), a set of 17 objectives—from eliminating extreme poverty to promoting health—that are both utopian and _________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# utopian
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The administration now objects to the Sustainable Development Goals (SDGs), a set of 17 objectives—from eliminating extreme poverty to promoting health—that are both _______ and sprawling.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# creep
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>America regards these as ________ world government, reeking of woke gender and climate ideology, and an endorsement of Chinese ideas.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# reek
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>America regards these as creeping world government, _______ of woke gender and climate ideology, and an endorsement of Chinese ideas.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# endorsement
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>America regards these as creeping world government, reeking of woke gender and climate ideology, and an ___________ of Chinese ideas.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# staffing
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Other countries could seek to fill the vacuum with money and diplomatic efforts, altering the balance of funding and ________ within the UN system.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# uphold
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Europe might try to ______ liberal values, but other countries would not.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# genuine
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Middle powers like Turkey and the Gulf states are already said to be influencing the delivery of aid in conflict zones on the basis of their political objectives as well as _______ need.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# undo
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>when many of the newly decolonised countries used it to push for a “new economic order” to ____ Western capitalism and free trade.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# reparations
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It could for instance, start to adopt demands that rich countries pay climate ___________, or share taxes more equitably.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# equitably
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>It could for instance, start to adopt demands that rich countries pay climate reparations, or share taxes more _________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# galvanize
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Even if America retained its Security Council veto, the UN would become a body for ___________ resistance towards it.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# resistance
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Even if America retained its Security Council veto, the UN would become a body for galvanising __________ towards it.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# Eurasian
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>They are already promoting other bodies in parallel, notably the BRICS economic club and the Shanghai Co-operation Organisation (SCO), a ________ security forum.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# hegemonism
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At an SCO summit earlier this month, attended by India, China’s leader, Xi Jinping, spoke of the need “to take a clear stand against __________ and power politics, and practise true multilateralism”.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# multilateralism
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>At an SCO summit earlier this month, attended by India, China’s leader, Xi Jinping, spoke of the need “to take a clear stand against hegemonism and power politics, and practise true _______________”.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# spite
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The UN is moving forward without the US, and not in _____ of the US or to _____ the US,</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# fragmented
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>A second scenario is that the UN survives—America stays in and countries avoid antagonising Mr Trump—but the system becomes __________ and enters decay.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# antagonize
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>A second scenario is that the UN survives—America stays in and countries avoid ____________ Mr Trump—but the system becomes fragmented and enters decay.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# tangle
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The OECD, a club of mostly rich countries, projects that its members will cut aid by 9-17% this year, on top of a 9% cut last year. Bureaucratic resistance, and the conflicting interests of members, may leave the ______ of 140-odd UN bodies broadly untouched, though underfunded.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# untouched
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The OECD, a club of mostly rich countries, projects that its members will cut aid by 9-17% this year, on top of a 9% cut last year. Bureaucratic resistance, and the conflicting interests of members, may leave the tangle of 140-odd UN bodies broadly _________, though underfunded.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# plead
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Tom Fletcher, the UN’s humanitarian-affairs chief, says the UN has received just 19% of the aid funds it has _______ for in 2025.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# spasm
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Richard Gowan of the International Crisis Group, a think-tank, argues that the Security Council, in particular, could become half-dead, with just the odd reflexive _____, for example, to renew the mandate of UN peacekeepers in Cyprus.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# reflexive
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Richard Gowan of the International Crisis Group, a think-tank, argues that the Security Council, in particular, could become half-dead, with just the odd _________ spasm, for example, to renew the mandate of UN peacekeepers in Cyprus.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# the Security Council
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Richard Gowan of the International Crisis Group, a think-tank, argues that ___ ________ _______, in particular, could become half-dead, with just the odd reflexive spasm, for example, to renew the mandate of UN peacekeepers in Cyprus.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# mandate
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Richard Gowan of the International Crisis Group, a think-tank, argues that the Security Council, in particular, could become half-dead, with just the odd reflexive spasm, for example, to renew the _______ of UN peacekeepers in Cyprus.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# Cyprus
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Richard Gowan of the International Crisis Group, a think-tank, argues that the Security Council, in particular, could become half-dead, with just the odd reflexive spasm, for example, to renew the mandate of UN peacekeepers in ______.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# reinvention
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>The final scenario is a Trumpian ___________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# asylum
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>America is pushing to restrict ______ rights under the 1951 UN refugee convention</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# ravage
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>it also wants the UN to help strengthen the mission, led by Kenya, in gang-_______ Haiti;</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# snapback
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>and it has pushed Europe to “____ ____” UN sanctions on Iran.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# showy
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Mr Trump likes pomp, and might look for _____ agreements.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# pomp
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Mr Trump likes ____, and might look for showy agreements.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# marginal
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Duplicative or ________ bodies could be abolished.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# abolish
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Duplicative or marginal bodies could be _________.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# jihadist
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Having backed different sides of the civil war in Syria, America and Russia are supporting the government of the former ________, Ahmed al-Sharaa.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# whim
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Much hangs on the _____ of Mr Trump, and the skill of the next UN secretary-general.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# hang on
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Much _____ __ the whims of Mr Trump, and the skill of the next UN secretary-general.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# hustings
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>________ to replace António Guterres in 2027 begin at the end of this year.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# jockey
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>Some candidates, such as Rafael Grossi, director-general of the IAEA, are _________ for position.</div><div class='example-meta'> — 《The Economist [Sep 20th 2025]》</div></div>
# tally
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>To see the cost of Trump’s bullying, _____ the world leaders flocking to China</div><div class='example-meta'> — 《The Economist [Sep 6th 2025]》</div></div>
# flock
# {'result': None, 'error': None}
# <div class='example'><div class='example-text'>To see the cost of Trump’s bullying, tally the world leaders ________ to China</div><div class='example-meta'> — 《The Economist [Sep 6th 2025]》</div></div>
