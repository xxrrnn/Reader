# %%
import requests
import sys
import time
import html
import re
import json
from typing import Dict, Any, List, Tuple
from bs4 import BeautifulSoup
json_path = r"G:\Code\Python\Project\Reader\data\backup\info\2025-10-09.json"
deck_name = "CambridgeDeck"
with open(json_path, "r", encoding="utf-8") as f:
    word_list = json.load(f)

# %%
def replace_alnum_with_underscores(match_obj: re.Match) -> str:
    """
    接收一个正则表达式匹配对象，
    并将其中的字母和数字替换为下划线。
    """
    word = match_obj.group(0)
    return ''.join(['_' if char.isalnum() else char for char in word])

def build_html_from_word_info(word_info: Dict[str, Any]) -> Dict[str, str]:
    """
    根据 word_info 构建笔记中各个字段的 HTML 内容。
    """
    # ... (此函数的其他部分与您原脚本类似，为了简洁此处省略了定义和短语部分)
    pos_html_parts: List[str] = []
    pronunciation_parts: List[str] = []
    definition_parts: List[str] = []
    examples_parts: List[str] = []
    blanked_examples_parts: List[str] = []
    
    word_to_highlight = word_info.get("word", "")

    # 处理发音、释义等
    for pos in word_info.get("partOfSpeech", []):
        pos_type = pos.get("type", "")
        pos_title_html = f"<div class='pos-title'>{html.escape(str(pos_type)).capitalize()}</div>" if pos_type else ""
        
        # 发音
        # 发音
        uk = pos.get("pronunciationUK") or {}
        us = pos.get("pronunciationUS") or {}
        audio_lines: List[str] = []
        if uk.get("phonetic") or uk.get("pronUrl"):
            aud = f"UK: {html.escape(uk.get('phonetic',''))}"
            if uk.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(uk.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if us.get("phonetic") or us.get("pronUrl"):
            aud = f"US: {html.escape(us.get('phonetic',''))}"
            if us.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(us.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if audio_lines:
            pronunciation_parts.extend(audio_lines)
        
        # 释义
        defs = pos.get("definitions") or []
        if defs:
            def_block = [pos_title_html, "<ul>"]
            for d in defs:
                en = (d.get("enMeaning") or "").strip()
                ch = (d.get("chMeaning") or "").strip()
                def_block.append(f"<li><div class='definition-en'>{html.escape(en)}</div><div class='definition-ch'>{html.escape(ch)}</div></li>")
            def_block.append("</ul>")
            definition_parts.append("".join(def_block))
        # 处理词性/定义/短语
    
    for pos in word_info.get("partOfSpeech", []):
        pos_type = pos.get("type", "")
        part_lines: List[str] = []
        part_lines.append(f"<div class='pos-title'>{html.escape(str(pos_type)).capitalize()}</div>")

        # 发音
        uk = pos.get("pronunciationUK") or {}
        us = pos.get("pronunciationUS") or {}
        audio_lines: List[str] = []
        if uk.get("phonetic") or uk.get("pronUrl"):
            aud = f"UK: {html.escape(uk.get('phonetic',''))}"
            if uk.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(uk.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if us.get("phonetic") or us.get("pronUrl"):
            aud = f"US: {html.escape(us.get('phonetic',''))}"
            if us.get("pronUrl"):
                aud += f" <audio controls src=\"{html.escape(us.get('pronUrl'))}\"></audio>"
            audio_lines.append(f"<div class='audio-row'>{aud}</div>")
        if audio_lines:
            part_lines.extend(audio_lines)

        # 定义
        defs = pos.get("definitions") or []
        if defs:
            part_lines.append("<ul>")
            for d in defs:
                en = (d.get("enMeaning") or d.get("en") or "").strip()
                ch = (d.get("chMeaning") or d.get("ch") or "").strip()
                part_lines.append(
                    "<li>"
                    f"<div class='definition-en'>{html.escape(en)}</div>"
                    f"<div class='definition-ch'>{html.escape(ch)}</div>"
                    "</li>"
                )
            part_lines.append("</ul>")

        # 短语
        phrases = pos.get("phrases") or []
        phrase_defs = pos.get("phraseDefinitions") or []
        if phrases:
            part_lines.append("<div><b>Phrases:</b><ul>")
            for i, ph in enumerate(phrases):
                pd = phrase_defs[i] if i < len(phrase_defs) else {}
                en = (pd.get("enMeaning") or pd.get("en") or "").strip()
                ch = (pd.get("chMeaning") or pd.get("ch") or "").strip()
                part_lines.append(
                    "<li>"
                    f"<span class='phrase'>{html.escape(ph)}</span> — <span class='definition-en'>{html.escape(en)}</span>"
                    f"<div class='definition-ch'>{html.escape(ch)}</div>"
                    "</li>"
                )
            part_lines.append("</ul></div>")

        pos_html_parts.append("<div>" + "\n".join(part_lines) + "</div>")

    # 处理例句
    for s in word_info.get("sentences", []):
        sentence_text = s.get("notes").strip()
        if not sentence_text:
            continue
        
        # 1. 'Examples' 字段: 目标词加粗
        escaped_sentence = html.escape(sentence_text)
        highlighted = escaped_sentence
        target_word = s.get("text") or word_to_highlight # 用于加粗的目标词
        if target_word:
            try:
                pattern = re.compile(r'\b' + re.escape(html.escape(target_word.strip())) + r'\b', re.IGNORECASE)

                highlighted = pattern.sub(lambda m: f"<strong>{m.group(0)}</strong>", escaped_sentence)
            except re.error:
                pass # 忽略正则错误
        escaped_target = html.escape(target_word.strip())
        if " " in target_word:
            # 多词短语，不加 \b
            pattern_for_blanking = re.compile(re.escape(escaped_target), re.IGNORECASE)
        else:
            # 单词，加边界防止误匹配
            pattern_for_blanking = re.compile(r'\b' + re.escape(escaped_target) + r'\b', re.IGNORECASE)
        # pattern_for_blanking = re.compile(r'\b' + re.escape(target_word) + r'\b', re.IGNORECASE)
        # 2. 'Blanked_Examples' 字段: 所有单词字母替换为下划线
        blanked_sentence = pattern_for_blanking.sub(replace_alnum_with_underscores, sentence_text)
        escaped_blanked = html.escape(blanked_sentence)

        # 来源信息
        book = s.get("bookName") or ""
        meta = f" — 《{html.escape(book)}》" if book else ""

        examples_parts.append(f"<div class='example'><div class='example-text'>{highlighted}</div><div class='example-meta'>{meta}</div></div>")
        blanked_examples_parts.append(f"<div class='example'><div class='example-text'>{escaped_blanked}</div><div class='example-meta'>{meta}</div></div>")

    return {
        "POS_Definitions": "\n".join(pos_html_parts),
        "Pronunciation": "\n".join(pronunciation_parts),
        "Definition": "\n".join(definition_parts),
        "Examples": "\n".join(examples_parts),
        "Blanked_Examples": "\n".join(blanked_examples_parts)
    }

# %%
build_html_from_word_info(word_list[5])

# %%
ANKI_CONNECT_URL = "http://localhost:8765"
MODEL_NAME = "WordType"
REQUEST_TIMEOUT = 2.0

def invoke(action: str, **params):
    try:
        r = requests.post(
            ANKI_CONNECT_URL,
            json={"action": action, "version": 6, "params": params},
            timeout=REQUEST_TIMEOUT
        )
        r.raise_for_status()
        return r.json()
    except requests.RequestException as e:
        print(f"[错误] 无法连接 AnkiConnect（{ANKI_CONNECT_URL}）：{e}")
        sys.exit(1)

# %%
# word_list_sub = word_list[0:2]
for word_info in word_list:
    result = {"created": False, "created_note_result": None, "updated": [], "skipped": [], "errors": []}
    word = word_info.get("partOfSpeech")[0].get("wordPrototype", "")
    if " " in word:
        tags = "phrase"
    else:
        tags = "word"
    print(word)
    query = f'deck:"{deck_name}" "Word:{word}"'
    try:
        find_res = invoke("findNotes", query=query)
    except Exception as e:
        result["errors"].append(f"findNotes 调用异常: {e}")

    note_ids = find_res.get("result", []) or []
    if note_ids:
        # res = build_html_from_word_info(word_info)
        # blanked_sentences = res["Blanked_Examples"]
        # pronunciation = res["Pronunciation"]
        # definition = res["Definition"]

        # r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Blanked_Examples": blanked_sentences}})
        # print(r)

        # r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Definition": definition}})
        # print(r)

        # r = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Pronunciation": pronunciation}})
        # print(r)

        note_id = note_ids[0]
        # invoke("updateNoteFields", note={"id": note_id, "fields": {"Blanked_Examples": blanked_sentences}})

        res = invoke("updateNoteFields", note={"id": note_id, "fields": {"Tags": tags}})

        # print(res)

        # 验证是否真的更新了
        # info = invoke("notesInfo", notes=[note_id])
        # print(info["result"][0]["fields"]["Blanked_Examples"]["value"])

# %%
# word_list_sub = word_list[0:2]
for word_info in reversed(word_list):
    result = {"created": False, "created_note_result": None, "updated": [], "skipped": [], "errors": []}
    word = word_info.get("partOfSpeech")[0].get("wordPrototype", "")
    if " " in word:
        tags = "phrase"
    else:
        tags = "word"
    print(word)
    query = f'deck:"{deck_name}" "Word:{word}"'
    try:
        find_res = invoke("findNotes", query=query)
    except Exception as e:
        result["errors"].append(f"findNotes 调用异常: {e}")

    note_ids = find_res.get("result", []) or []
    if note_ids:
        info_res = invoke("notesInfo", notes=[note_ids[0]])
        blanked_example_sentence_html = info_res.get("result")[0].get("fields").get("Blanked_Examples").get("value") or ""
        if len(blanked_example_sentence_html) == 0:
            example_sentence_html = info_res.get("result")[0].get("fields").get("Examples").get("value") or ""
            # 替换 <strong> 内字母数字为 _ 并去掉标签
            blanked = re.sub(
                r'<strong>(.*?)</strong>',           # 匹配 <strong>...</strong>，非贪婪
                lambda m: re.sub(r'[A-Za-z0-9]', '_', m.group(1)),  # 替换内容
                example_sentence_html,
                flags=re.DOTALL
            )
            upd = invoke(
                "updateNoteFields",
                note={"id": note_ids[0], "fields": {"Blanked_Examples": blanked}}
            )
            print(f"update blank of {word}")


        definition = info_res.get("result")[0].get("fields").get("Definition").get("value") or ""
        if len(definition) == 0:
            pos_definitions = info_res.get("result")[0].get("fields").get("POS_Definitions").get("value") or ""
            soup = BeautifulSoup(pos_definitions, "html.parser")
            for el in soup.select(".audio-row"):
                el.decompose()
            definition = str(soup)
            upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Definition": definition}})
            print(f"update definition of {word}")

# %%
def extract_raw_sentence(existing_examples_html: str) -> List[str]:
    """
    从已有 Examples 字段的 HTML 中提取所有 <div class='example-text'>...</div> 的纯文本（去标签、unescape）。
    返回文本列表（顺序与出现顺序一致）。
    """
    if not existing_examples_html:
        return []
    # 找到所有 example-text 段落
    matches = re.findall(r"<div\s+class=['\"]example-text['\"]\s*>(.*?)</div>", existing_examples_html, flags=re.S | re.I)
    plain_texts = []
    for m in matches:
        # 去掉 HTML 标签（如 <strong> 等）
        no_tags = re.sub(r"<[^>]+>", "", m)
        unescaped = html.unescape(no_tags).strip()
        if unescaped:
            plain_texts.append(unescaped)
    return plain_texts

# %%
for word_info in word_list:
    result = {"created": False, "created_note_result": None, "updated": [], "skipped": [], "errors": []}
    word = word_prototype = word_info.get("partOfSpeech")[0].get("wordPrototype", "")
    print(word)
    query = f'deck:"{deck_name}" "Word:{word}"'
    try:
        find_res = invoke("findNotes", query=query)
    except Exception as e:
        result["errors"].append(f"findNotes 调用异常: {e}")

    note_ids = find_res.get("result", []) or []
    info_res = invoke("notesInfo", notes=[note_ids[0]])
    example_sentence_html = info_res.get("result")[0].get("fields").get("Examples").get("value") or ""
    example_blanked_sentence_html = info_res.get("result")[0].get("fields").get("Blanked_Examples").get("value")
    new_sentence_html = example_sentence_html + example_sentence_html
    new_blanked_sentence_html = example_blanked_sentence_html + example_blanked_sentence_html

    upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Examples": new_sentence_html}})
    upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Blanked_Examples": new_blanked_sentence_html}})
    break

# %% [markdown]
# 解决很多例句没有chapter，只有bookname的问题

# %%
import re

def fix_meta(html, bookName, chapter):
    need_update = False

    def repl(m):
        nonlocal need_update
        inner = m.group(1)
        cleaned = re.sub(r'《.*?》', '', inner)
        cleaned = re.sub(r'^[\s\-\u2013\u2014:—–]+|[\s\-\u2013\u2014:—–]+$', '', cleaned)
        if not re.search(r'\w', cleaned, flags=re.UNICODE):
            need_update = True
            return f"<div class='example-meta'>——《{bookName}》: {chapter}</div>"
        else:
            return f"<div class='example-meta'>{inner}</div>"

    new_html = re.sub(r'<div\s+class=[\'"]example-meta[\'"]>(.*?)</div>', repl, html, flags=re.DOTALL)
    return new_html, need_update

html = """<div class="example"><div class="example-text">gave unemployed artists stipends, studios and ___________ ______, in effect serving as a scouting network.</div><div class="example-meta"> — 《The Economist [Sep 27th 2025]》</div></div>"""
chapter = "A restaurant scandal sticks in China’s throat"
bookName = "The Economist [Sep 27th 2025]"
new_html, need_update = fix_meta(html, bookName, chapter)
print(new_html)
print(need_update)

# %%
from tqdm import tqdm
import math
# word_list_sub = word_list[0:2]
for word_info in tqdm(reversed(word_list), total=len(word_list), desc="Processing words"):
    result = {"created": False, "created_note_result": None, "updated": [], "skipped": [], "errors": []}
    word = word_info.get("partOfSpeech")[0].get("wordPrototype", "")
    query = f'deck:"{deck_name}" "Word:{word}"'
    print(word)
    try:
        find_res = invoke("findNotes", query=query)
    except Exception as e:
        result["errors"].append(f"findNotes 调用异常: {e}")
    note_ids = find_res.get("result", []) or []
    if note_ids:
        chapter = word_info.get("sentences")[0].get("chapter")
        # 如果 chapter 是 None、NaN 或空字符串，就跳过
        if chapter is None or (isinstance(chapter, float) and math.isnan(chapter)) or str(chapter).strip() == "":
            continue

        bookName = word_info.get("sentences")[0].get("bookName")
        info_res = invoke("notesInfo", notes=[note_ids[0]])
        blanked_example_sentence_html = info_res.get("result")[0].get("fields").get("Blanked_Examples").get("value") or ""
        example_sentence_html = info_res.get("result")[0].get("fields").get("Examples").get("value") or ""
        need_update = False
        example_sentence_html, need_update = fix_meta(example_sentence_html, bookName, chapter)
        if need_update :
            print(example_sentence_html)
            upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Examples": example_sentence_html}})
        blanked_example_sentence_html, need_update  = fix_meta(blanked_example_sentence_html, bookName, chapter)
        if need_update:
            print(blanked_example_sentence_html)
            upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Blanked_Examples": blanked_example_sentence_html}})

# %%
query = f'deck:"{deck_name}" "Word:{"performance venue"}"'
find_res = invoke("findNotes", query=query)
find_res

blanked_example_sentence_html = info_res.get("result")[0].get("fields").get("Blanked_Examples").get("value") or ""
print(blanked_example_sentence_html)
blanked_example_sentence_html, need_update = fix_meta(blanked_example_sentence_html, bookName, chapter)
print(blanked_example_sentence_html)

note_ids = find_res.get("result", []) or []
print(note_ids)
upd = invoke("updateNoteFields", note={"id": note_ids[0], "fields": {"Blanked_Examples": blanked_example_sentence_html}})
upd

# %% [markdown]
# 上传文章音频到anki中，用于周期性复习和听力
#
# 1. 遍历notes.json，获得所有文章标题
# 2. 输入音频所在地址，以及输入拷贝截屏
# 3. 基于文章标题、音频和截屏，产生anki页面，上传到anki中，并将已有的以json的形式保存。json里面保存音频路径，截屏路径。音频和截屏要保存到json所在的文件夹中，同时做重命名为文章标题。

# %%
import os
import datetime
from datetime import date,datetime
import json
from pathlib import Path
import re

# === 配置 ===
AUDIO_BASE_DIR = Path(r"G:\Book\Economist")  # Economist 文件夹根目录
AUDIO_PREFIX = "TEco-"                 # 音频文件夹前缀
AUDIO_SUFFIX = "音频"                   # 音频文件夹后缀

# %%
def load_latest_dict_list(folder="./saved"):
    """读取文件夹中日期最接近今天的 json 文件"""
    if not os.path.exists(folder):
        return []

    # 找出所有文件名形如 YYYY-MM-DD.json
    files = [
        f for f in os.listdir(folder)
        if f.endswith(".json") and len(f) == len("2025-09-18.json")
    ]

    if not files:
        return []

    # 解析文件名中的日期，找到距离今天最近的
    today = date.today()
    closest_file = None
    closest_diff = None

    for f in files:
        try:
            file_date = datetime.strptime(f[:-5], "%Y-%m-%d").date()
        except ValueError:
            continue
        diff = abs((today - file_date).days)
        if closest_diff is None or diff < closest_diff:
            closest_diff = diff
            closest_file = f

    if closest_file is None:
        return []

    filepath = os.path.join(folder, closest_file)
    with open(filepath, "r", encoding="utf-8") as f:
        return json.load(f)

def extract_date(s):
    import re
    # 提取括号中的日期部分
    m = re.search(r'\[(.*?)\]', s)
    if not m:
        return datetime.max  # 没找到则放在最后
    date_str = m.group(1)
    # 尝试解析日期
    try:
        return datetime.strptime(date_str, "%b %dth %Y")
    except ValueError:
        # 兼容其他可能的后缀（st, nd, rd, th）
        for suf in ["st", "nd", "rd", "th"]:
            try:
                return datetime.strptime(date_str.replace(suf, ""), "%b %d %Y")
            except ValueError:
                continue
        return datetime.max
    
def list_mp3_files(base_dir: Path):
    mp3_files = []
    for root, _, files in os.walk(base_dir):
        for f in files:
            if f.lower().endswith(".mp3"):
                mp3_files.append(Path(root) / f)
    return mp3_files

# %%
cur_notes = load_latest_dict_list(r"G:\Code\Python\Project\Reader\data\backup\notes")

passage = set()
for note in cur_notes:
    if "Economist" in note["bookName"]:
        passage.add((note["bookName"], note["chapter"]))

sorted_passage = sorted(passage, key=lambda x: extract_date(x[0]))
for p in sorted_passage:
    print(p[0], p[1])

# %% [markdown]
# 将发音下载下来，导入到anki中，让单次发音不再需要鼠标执行！
# 目前只导入美音。

# %%
import re
from bs4 import BeautifulSoup

html = """
<div><div class="pos-title">Noun [ u ]</div>
<div class="audio-row">UK: / ɡɪlt / <audio controls="" src="https://dictionary.cambridge.org/zhs/media/%E8%8B%B1%E8%AF%AD-%E6%B1%89%E8%AF%AD-%E7%AE%80%E4%BD%93/uk_pron/u/ukg/ukgig/ukgigan012.mp3"></audio></div>
<div class="audio-row">US: / ɡɪlt / <audio controls="" src="https://dictionary.cambridge.org/zhs/media/%E8%8B%B1%E8%AF%AD-%E6%B1%89%E8%AF%AD-%E7%AE%80%E4%BD%93/us_pron/g/gil/gilt_/gilt.mp3"></audio></div>
<ul>
<li><div class="definition-en">a feeling of worry or unhappiness that you have because you have done something wrong , such as causing harm to another person</div><div class="definition-ch">内疚 ， 愧疚 ， 自责</div></li>
<li><div class="definition-en">the fact of having done something wrong or committed a crime</div><div class="definition-ch">过失 ， 犯罪 ， 罪责</div></li>
</ul></div>
"""

# AUDIO_PATTERN = r"https?://dictionary\.cambridge\.org/media/(?:english(?:-[a-z\-]+)?)/us_pron/[^\s\"']+?\.mp3"
HAS_US_AUDIO_PATTERN = r"\[sound:[^\]]*-us-[0-9a-f]{8}\.mp3\]"



def extract_audio_url(pos_def_html: str) -> str:
    """
    从 Cambridge HTML 中提取发音音频 URL。
    优先提取美音 (US)，若无则回退到英音 (UK)。
    """
    soup = BeautifulSoup(pos_def_html, "html.parser")

    # 1️⃣ 先尝试找美音
    for div in soup.find_all("div", class_="audio-row"):
        if "US:" in div.get_text(strip=True):
            audio = div.find("audio")
            if audio and audio.has_attr("src"):
                return audio["src"]

    # 2️⃣ 若无美音，则尝试找英音
    for div in soup.find_all("div", class_="audio-row"):
        if "UK:" in div.get_text(strip=True):
            audio = div.find("audio")
            if audio and audio.has_attr("src"):
                return audio["src"]

    return ""

extract_audio_url(html)

# %%
from typing import Iterable
from anki import get_audio
import time
import random
import tqdm

# 默认延迟：每个 note 等待 20 - 30 秒（你可以修改）
DEFAULT_MIN_DELAY = 10.0
DEFAULT_MAX_DELAY = 20.0

# ----------------------------- 工具函数 -----------------------------
def chunk(iterable: Iterable[int], size: int):
    items = list(iterable)
    for start in range(0, len(items), size):
        yield items[start:start + size]

def _sleep_with_jitter(min_delay: float, max_delay: float):
    """睡眠一个随机时间（含抖动），并打印提示"""
    if min_delay <= 0 and max_delay <= 0:
        return
    delay = random.uniform(min_delay, max_delay)
    print(f"⏱ 等待 {delay:.1f} 秒以降低请求速率...")
    time.sleep(delay)

# ----------------------------- 主逻辑 -----------------------------
def iter_notes_in_deck(deck_name: str, min_delay: float = DEFAULT_MIN_DELAY, max_delay: float = DEFAULT_MAX_DELAY):
    """
    遍历牌组并处理笔记：提取美音 URL、通过 get_audio 下载并上传到 Anki。
    为降低法律/滥用风险，在处理每个 note 后等待随机间隔（min_delay ~ max_delay 秒）。
    """
    print(f"开始处理牌组: {deck_name}（每 note 等待 {min_delay:.1f}–{max_delay:.1f}s）")
    try:
        search = invoke("findNotes", query=f'deck:"{deck_name}"')
    except Exception as e:
        print(f"❌ 查询牌组失败: {e}")
        return

    note_ids = search.get("result", [])
    if not note_ids:
        print(f"⚠️ 牌组 {deck_name} 当前没有笔记")
        return

    total = len(note_ids)
    processed = 0
    try:
        for batch in chunk(note_ids, 200):
            try:
                res = invoke("notesInfo", notes=batch)
            except Exception as e:
                print(f"❌ 批量获取 notesInfo 失败: {e}，跳过该批次")
                # 即便失败也休眠以避免快速重试
                continue

            for note in res.get("result", []):
                processed += 1
                note_id = note.get("noteId")
                fields = {k: v["value"] for k, v in note["fields"].items()}
                word = fields.get("Word", "")
                pos_def_html = fields.get("POS_Definitions", "")

                # 无内容就跳过，但仍遵守节流
                if not pos_def_html:
                    print(f"跳过 {word}（无 POS_Definitions）  [{processed}/{total}]")
                    continue

                # 若已有美音则跳过（避免重复导入）
                if (
                    re.search(HAS_US_AUDIO_PATTERN, fields.get("Pronunciation", ""))
                    or re.search(HAS_US_AUDIO_PATTERN, fields.get("POS_Definitions", ""))
                ):
                    print(f"⏩ 跳过 {word}（已存在美音音频）  [{processed}/{total}]")
                    continue

                # 提取美音 URL
                audio_url = extract_audio_url(pos_def_html)
                print(audio_url)
                if not audio_url:
                    print(f"❌ 未找到美音: {word}  [{processed}/{total}]")
                    continue

                try:
                    audio_markup = get_audio(audio_url, suffix="-us", base_word=word)
                except Exception as e:
                    print(f"❌ get_audio 失败: {word} -> {e}  [{processed}/{total}]")
                    # 失败也要等待，避免短时间重试
                    continue

                # 准备写回字段
                pronunciation_field = fields.get("Pronunciation", "")
                pos_def_field = fields.get("POS_Definitions", "")

                new_pronunciation = f"{audio_markup}\n{pronunciation_field}" if pronunciation_field else audio_markup
                new_pos_def = f"{audio_markup}\n{pos_def_field}" if pos_def_field else audio_markup

                update_payload = {
                    "note": {
                        "id": note_id,
                        "fields": {
                            "Pronunciation": new_pronunciation,
                            "POS_Definitions": new_pos_def,
                        },
                    }
                }

                try:
                    update_result = invoke("updateNoteFields", **update_payload)
                    if update_result.get("error"):
                        print(f"⚠️ 更新失败 {word} ({note_id}): {update_result['error']}  [{processed}/{total}]")
                    else:
                        print(f"✅ 已更新 {word} ({note_id})  [{processed}/{total}]")
                except Exception as e:
                    print(f"❌ 调用 updateNoteFields 失败: {e}  [{processed}/{total}]")
                _sleep_with_jitter(min_delay, max_delay)

                

    except KeyboardInterrupt:
        print("已中断（Ctrl+C），退出并保存已完成的操作。")
        return

    print(f"完成：已处理 {processed}/{total} 个笔记（每 note 间隔 {min_delay:.1f}–{max_delay:.1f} 秒）")

# ----------------------------- 执行 -----------------------------
if __name__ == "__main__":
    # 直接使用默认 20-30s 延迟。如果想改成 25-35s，调用时传参：iter_notes_in_deck("Word", 25, 35)
    iter_notes_in_deck("Word")
# Out:
# 开始处理牌组: Word（每 note 等待 10.0–20.0s）
#
# ❌ 未找到美音: burst up to six feet  [1/1877]
# ⏩ 跳过 pick on someone（已存在美音音频）  [2/1877]
# ⏩ 跳过 ballistic（已存在美音音频）  [3/1877]
# ⏩ 跳过 dude（已存在美音音频）  [4/1877]
# ⏩ 跳过 paramilitary（已存在美音音频）  [5/1877]
# ⏩ 跳过 rations（已存在美音音频）  [6/1877]
# ⏩ 跳过 mind-blowing（已存在美音音频）  [7/1877]
# ⏩ 跳过 guidance counselor（已存在美音音频）  [8/1877]
# ⏩ 跳过 recount（已存在美音音频）  [9/1877]
# ⏩ 跳过 judo（已存在美音音频）  [10/1877]
# ⏩ 跳过 apartheid（已存在美音音频）  [11/1877]
# ⏩ 跳过 sole（已存在美音音频）  [12/1877]
# ⏩ 跳过 stare（已存在美音音频）  [13/1877]
# ⏩ 跳过 vacantly（已存在美音音频）  [14/1877]
# ⏩ 跳过 searing（已存在美音音频）  [15/1877]
# ⏩ 跳过 instinct（已存在美音音频）  [16/1877]
# ⏩ 跳过 ingratiating（已存在美音音频）  [17/1877]
# ⏩ 跳过 horse around（已存在美音音频）  [18/1877]
# ⏩ 跳过 bump into someone（已存在美音音频）  [19/1877]
# ⏩ 跳过 recess（已存在美音音频）  [20/1877]
# ⏩ 跳过 swollen（已存在美音音频）  [21/1877]
# ⏩ 跳过 corrective（已存在美音音频）  [22/1877]
# ⏩ 跳过 inflict（已存在美音音频）  [23/1877]
# ⏩ 跳过 rogue（已存在美音音频）  [24/1877]
# ⏩ 跳过 charismatic（已存在美音音频）  [25/1877]
# ⏩ 跳过 fantasist（已存在美音音频）  [26/1877]
# ⏩ 跳过 bedevil（已存在美音音频）  [27/1877]
# ⏩ 跳过 pummel（已存在美音音频）  [28/1877]
# ⏩ 跳过 berate（已存在美音音频）  [29/1877]
# ⏩ 跳过 tirade（已存在美音音频）  [30/1877]
# ⏩ 跳过 provoke（已存在美音音频）  [31/1877]
# ⏩ 跳过 unhinged（已存在美音音频）  [32/1877]
# ⏩ 跳过 perpetrator（已存在美音音频）  [33/1877]
#
# ❌ 未找到美音: juvenile prison  [34/1877]
# ⏩ 跳过 spin（已存在美音音频）  [35/1877]
#
# ❌ 未找到美音: get conditioned in  [36/1877]
# ⏩ 跳过 volatile（已存在美音音频）  [37/1877]
# ⏩ 跳过 lard something with something（已存在美音音频）  [38/1877]
# ⏩ 跳过 delusional（已存在美音音频）  [39/1877]
# ⏩ 跳过 Jekyll and Hyde（已存在美音音频）  [40/1877]
# ⏩ 跳过 unrelenting（已存在美音音频）  [41/1877]
# ⏩ 跳过 Rolls-Royce（已存在美音音频）  [42/1877]
# ⏩ 跳过 lodge（已存在美音音频）  [43/1877]
# ⏩ 跳过 emerald（已存在美音音频）  [44/1877]
# ⏩ 跳过 tame（已存在美音音频）  [45/1877]
# ⏩ 跳过 thug（已存在美音音频）  [46/1877]
# ⏩ 跳过 concede（已存在美音音频）  [47/1877]
# ⏩ 跳过 stern（已存在美音音频）  [48/1877]
# ⏩ 跳过 streetwise（已存在美音音频）  [49/1877]
# ⏩ 跳过 adversity（已存在美音音频）  [50/1877]
# ⏩ 跳过 malady（已存在美音音频）  [51/1877]
# ⏩ 跳过 psyche（已存在美音音频）  [52/1877]
# ⏩ 跳过 linger（已存在美音音频）  [53/1877]
# ⏩ 跳过 banish（已存在美音音频）  [54/1877]
# ⏩ 跳过 intense（已存在美音音频）  [55/1877]
# ⏩ 跳过 goofy（已存在美音音频）  [56/1877]
# ⏩ 跳过 detached（已存在美音音频）  [57/1877]
# ⏩ 跳过 dreaded（已存在美音音频）  [58/1877]
# ⏩ 跳过 specter（已存在美音音频）  [59/1877]
# ⏩ 跳过 resonant（已存在美音音频）  [60/1877]
# ⏩ 跳过 trope（已存在美音音频）  [61/1877]
# ⏩ 跳过 mythology（已存在美音音频）  [62/1877]
# ⏩ 跳过 exorcise（已存在美音音频）  [63/1877]
# ⏩ 跳过 bequeath（已存在美音音频）  [64/1877]
# ⏩ 跳过 moron（已存在美音音频）  [65/1877]
# ⏩ 跳过 valve（已存在美音音频）  [66/1877]
# ⏩ 跳过 callous（已存在美音音频）  [67/1877]
# ⏩ 跳过 aversion（已存在美音音频）  [68/1877]
# ⏩ 跳过 thrashing（已存在美音音频）  [69/1877]
# ⏩ 跳过 horrendous（已存在美音音频）  [70/1877]
# ⏩ 跳过 zone out（已存在美音音频）  [71/1877]
# ⏩ 跳过 stunted（已存在美音音频）  [72/1877]
# ⏩ 跳过 cauldron（已存在美音音频）  [73/1877]
# ⏩ 跳过 aura（已存在美音音频）  [74/1877]
# ⏩ 跳过 humanoid（已存在美音音频）  [75/1877]
# ⏩ 跳过 navel（已存在美音音频）  [76/1877]
# ⏩ 跳过 fervour（已存在美音音频）  [77/1877]
# ⏩ 跳过 cloak（已存在美音音频）  [78/1877]
#
# ❌ 未找到美音: board seat  [79/1877]
#
# ❌ 未找到美音: pull the trigger on his plan  [80/1877]
# ⏩ 跳过 jig（已存在美音音频）  [81/1877]
# ⏩ 跳过 conviction（已存在美音音频）  [82/1877]
# ⏩ 跳过 prophet（已存在美音音频）  [83/1877]
# ⏩ 跳过 consciousness（已存在美音音频）  [84/1877]
# ⏩ 跳过 fathom（已存在美音音频）  [85/1877]
# ⏩ 跳过 boost（已存在美音音频）  [86/1877]
# ⏩ 跳过 hitchhiker（已存在美音音频）  [87/1877]
# ⏩ 跳过 pep（已存在美音音频）  [88/1877]
# ⏩ 跳过 feverishly（已存在美音音频）  [89/1877]
# ⏩ 跳过 craving（已存在美音音频）  [90/1877]
# ⏩ 跳过 thrive（已存在美音音频）  [91/1877]
# ⏩ 跳过 surge（已存在美音音频）  [92/1877]
# ⏩ 跳过 tortuous（已存在美音音频）  [93/1877]
# ⏩ 跳过 vomit（已存在美音音频）  [94/1877]
# ⏩ 跳过 compulsion（已存在美音音频）  [95/1877]
# ⏩ 跳过 summarily（已存在美音音频）  [96/1877]
# ⏩ 跳过 ruefully（已存在美音音频）  [97/1877]
# ⏩ 跳过 mindset（已存在美音音频）  [98/1877]
# ⏩ 跳过 wistful（已存在美音音频）  [99/1877]
# ⏩ 跳过 pledge（已存在美音音频）  [100/1877]
# ⏩ 跳过 snuck（已存在美音音频）  [101/1877]
# ⏩ 跳过 mentor（已存在美音音频）  [102/1877]
# ⏩ 跳过 outright（已存在美音音频）  [103/1877]
#
# ❌ 未找到美音: construction hand  [104/1877]
#
# ❌ 未找到美音: lit out  [105/1877]
#
# ❌ 未找到美音: Kalahari Desert  [106/1877]
#
# ❌ 未找到美音: tie for first place  [107/1877]
#
# ❌ 未找到美音: motor rally  [108/1877]
# ⏩ 跳过 regard（已存在美音音频）  [109/1877]
# ⏩ 跳过 maternal（已存在美音音频）  [110/1877]
# ⏩ 跳过 daredevil（已存在美音音频）  [111/1877]
# ⏩ 跳过 barren（已存在美音音频）  [112/1877]
# ⏩ 跳过 chiropractic（已存在美音音频）  [113/1877]
# ⏩ 跳过 break someone in（已存在美音音频）  [114/1877]
# ⏩ 跳过 rodeo（已存在美音音频）  [115/1877]
# ⏩ 跳过 hobo（已存在美音音频）  [116/1877]
# ⏩ 跳过 stowaway（已存在美音音频）  [117/1877]
# ⏩ 跳过 ocean-going（已存在美音音频）  [118/1877]
# ⏩ 跳过 populism（已存在美音音频）  [119/1877]
# ⏩ 跳过 fundamentalist（已存在美音音频）  [120/1877]
# ⏩ 跳过 antisemitism（已存在美音音频）  [121/1877]
# ⏩ 跳过 decry（已存在美音音频）  [122/1877]
# ⏩ 跳过 perversion（已存在美音音频）  [123/1877]
# ⏩ 跳过 disproportionate（已存在美音音频）  [124/1877]
# ⏩ 跳过 enlisted（已存在美音音频）  [125/1877]
# ⏩ 跳过 defy（已存在美音音频）  [126/1877]
# ⏩ 跳过 ballroom（已存在美音音频）  [127/1877]
# ⏩ 跳过 streak（已存在美音音频）  [128/1877]
# ⏩ 跳过 impetuous（已存在美音音频）  [129/1877]
# ⏩ 跳过 chiropractor（已存在美音音频）  [130/1877]
# ⏩ 跳过 accolade（已存在美音音频）  [131/1877]
# ⏩ 跳过 toddler（已存在美音音频）  [132/1877]
# ⏩ 跳过 populist（已存在美音音频）  [133/1877]
# ⏩ 跳过 quirky（已存在美音音频）  [134/1877]
# ⏩ 跳过 usurp（已存在美音音频）  [135/1877]
# ⏩ 跳过 take something apart（已存在美音音频）  [136/1877]
# ⏩ 跳过 crate（已存在美音音频）  [137/1877]
# ⏩ 跳过 freighter（已存在美音音频）  [138/1877]
# ⏩ 跳过 Afrikaans（已存在美音音频）  [139/1877]
# ⏩ 跳过 Pretoria（已存在美音音频）  [140/1877]
# ⏩ 跳过 lavender（已存在美音音频）  [141/1877]
# ⏩ 跳过 jacaranda（已存在美音音频）  [142/1877]
# ⏩ 跳过 charlatan（已存在美音音频）  [143/1877]
# ⏩ 跳过 trek（已存在美音音频）  [144/1877]
# ⏩ 跳过 fend someone off（已存在美音音频）  [145/1877]
# ⏩ 跳过 motto（已存在美音音频）  [146/1877]
# ⏩ 跳过 Algiers（已存在美音音频）  [147/1877]
#
# ❌ 未找到美音: goofiness  [148/1877]
#
# ❌ 未找到美音: runway show  [149/1877]
#
# ❌ 未找到美音: caddish  [150/1877]
#
# ❌ 未找到美音: fighter-bomber  [151/1877]
#
# ❌ 未找到美音: cryptographer  [152/1877]
#
# ❌ 未找到美音: Buick  [153/1877]
#
# ❌ 未找到美音: wind up with  [154/1877]
#
# ❌ 未找到美音: ownership stake  [155/1877]
#
# ❌ 未找到美音: freak out  [156/1877]
# ⏩ 跳过 awe（已存在美音音频）  [157/1877]
#
# ❌ 未找到美音: make his case  [158/1877]
#
# ❌ 未找到美音: Yamaha  [159/1877]
# ⏩ 跳过 wander（已存在美音音频）  [160/1877]
#
# ❌ 未找到美音: stay put  [161/1877]
#
# ❌ 未找到美音: solar roof construction site  [162/1877]
#
# ❌ 未找到美音: cast big shadows  [163/1877]
#
# ❌ 未找到美音: Durban  [164/1877]
# ⏩ 跳过 impulsive（已存在美音音频）  [165/1877]
# ⏩ 跳过 siege mentality（已存在美音音频）  [166/1877]
# ⏩ 跳过 strain（已存在美音音频）  [167/1877]
# ⏩ 跳过 imprint（已存在美音音频）  [168/1877]
# ⏩ 跳过 strikingly（已存在美音音频）  [169/1877]
# ⏩ 跳过 cheekbone（已存在美音音频）  [170/1877]
# ⏩ 跳过 smooth（已存在美音音频）  [171/1877]
# ⏩ 跳过 wheeler-dealer（已存在美音音频）  [172/1877]
# ⏩ 跳过 lookout（已存在美音音频）  [173/1877]
# ⏩ 跳过 refugee（已存在美音音频）  [174/1877]
# ⏩ 跳过 searchlight（已存在美音音频）  [175/1877]
# ⏩ 跳过 armchair（已存在美音音频）  [176/1877]
# ⏩ 跳过 dabble（已存在美音音频）  [177/1877]
# ⏩ 跳过 Afrikaner（已存在美音音频）  [178/1877]
# ⏩ 跳过 establishment（已存在美音音频）  [179/1877]
# ⏩ 跳过 ferry（已存在美音音频）  [180/1877]
# ⏩ 跳过 airstrip（已存在美音音频）  [181/1877]
# ⏩ 跳过 Panamanian（已存在美音音频）  [182/1877]
# ⏩ 跳过 postcolonial（已存在美音音频）  [183/1877]
# ⏩ 跳过 bureaucracy（已存在美音音频）  [184/1877]
# ⏩ 跳过 rambling（已存在美音音频）  [185/1877]
# ⏩ 跳过 discourse（已存在美音音频）  [186/1877]
# ⏩ 跳过 import（已存在美音音频）  [187/1877]
# ⏩ 跳过 Johannesburg（已存在美音音频）  [188/1877]
# ⏩ 跳过 parcel（已存在美音音频）  [189/1877]
# ⏩ 跳过 cloak-and-dagger（已存在美音音频）  [190/1877]
#
# ❌ 未找到美音: propose to  [191/1877]
# ⏩ 跳过 grief（已存在美音音频）  [192/1877]
# ⏩ 跳过 finalist（已存在美音音频）  [193/1877]
# ⏩ 跳过 bowling alley（已存在美音音频）  [194/1877]
# ⏩ 跳过 faithful（已存在美音音频）  [195/1877]
# ⏩ 跳过 unfaithful（已存在美音音频）  [196/1877]
# ⏩ 跳过 break (something) off（已存在美音音频）  [197/1877]
# ⏩ 跳过 honeymoon（已存在美音音频）  [198/1877]
# ⏩ 跳过 annoyance（已存在美音音频）  [199/1877]
# ⏩ 跳过 nauseate（已存在美音音频）  [200/1877]
#
# ❌ 未找到美音: Nice  [201/1877]
# ⏩ 跳过 conceive（已存在美音音频）  [202/1877]
# ⏩ 跳过 amused（已存在美音音频）  [203/1877]
# ⏩ 跳过 maiden（已存在美音音频）  [204/1877]
# ⏩ 跳过 biblical（已存在美音音频）  [205/1877]
# ⏩ 跳过 prescient（已存在美音音频）  [206/1877]
# ⏩ 跳过 coddle（已存在美音音频）  [207/1877]
# ⏩ 跳过 roam（已存在美音音频）  [208/1877]
# ⏩ 跳过 nanny（已存在美音音频）  [209/1877]
# ⏩ 跳过 housekeeper（已存在美音音频）  [210/1877]
# ⏩ 跳过 intact（已存在美音音频）  [211/1877]
# ⏩ 跳过 nursery（已存在美音音频）  [212/1877]
# ⏩ 跳过 dissuade（已存在美音音频）  [213/1877]
# ⏩ 跳过 principal（已存在美音音频）  [214/1877]
# ⏩ 跳过 prevail（已存在美音音频）  [215/1877]
# ⏩ 跳过 tune (someone/something) out（已存在美音音频）  [216/1877]
# ⏩ 跳过 retarded（已存在美音音频）  [217/1877]
# ⏩ 跳过 trance（已存在美音音频）  [218/1877]
# ⏩ 跳过 impasse（已存在美音音频）  [219/1877]
# ⏩ 跳过 adenoid（已存在美音音频）  [220/1877]
# ⏩ 跳过 retreat（已存在美音音频）  [221/1877]
# ⏩ 跳过 sensory（已存在美音音频）  [222/1877]
# ⏩ 跳过 incoming（已存在美音音频）  [223/1877]
# ⏩ 跳过 summon（已存在美音音频）  [224/1877]
# ⏩ 跳过 compound（已存在美音音频）  [225/1877]
# ⏩ 跳过 tumultuous（已存在美音音频）  [226/1877]
# ⏩ 跳过 maple（已存在美音音频）  [227/1877]
# ⏩ 跳过 fierce（已存在美音音频）  [228/1877]
# ⏩ 跳过 motorcycle（已存在美音音频）  [229/1877]
# ⏩ 跳过 resume（已存在美音音频）  [230/1877]
# ⏩ 跳过 cave（已存在美音音频）  [231/1877]
# ⏩ 跳过 spacey（已存在美音音频）  [232/1877]
# ⏩ 跳过 oblivious（已存在美音音频）  [233/1877]
# ⏩ 跳过 amiss（已存在美音音频）  [234/1877]
# ⏩ 跳过 police（已存在美音音频）  [235/1877]
# ⏩ 跳过 overprotective（已存在美音音频）  [236/1877]
# ⏩ 跳过 forklift truck（已存在美音音频）  [237/1877]
# ⏩ 跳过 poke（已存在美音音频）  [238/1877]
# ⏩ 跳过 refrain（已存在美音音频）  [239/1877]
# ⏩ 跳过 squirm（已存在美音音频）  [240/1877]
# ⏩ 跳过 squeal（已存在美音音频）  [241/1877]
# ⏩ 跳过 Asperger's syndrome（已存在美音音频）  [242/1877]
# ⏩ 跳过 autism（已存在美音音频）  [243/1877]
# ⏩ 跳过 spectrum（已存在美音音频）  [244/1877]
# ⏩ 跳过 self-regulation（已存在美音音频）  [245/1877]
# ⏩ 跳过 trauma（已存在美音音频）  [246/1877]
# ⏩ 跳过 limbic（已存在美音音频）  [247/1877]
# ⏩ 跳过 hijack（已存在美音音频）  [248/1877]
# ⏩ 跳过 individualized（已存在美音音频）  [249/1877]
# ⏩ 跳过 acutely（已存在美音音频）  [250/1877]
# ⏩ 跳过 receptor（已存在美音音频）  [251/1877]
#
# ❌ 未找到美音: Oktoberfest  [252/1877]
# ⏩ 跳过 lunge（已存在美音音频）  [253/1877]
# ⏩ 跳过 fled（已存在美音音频）  [254/1877]
# ⏩ 跳过 accusation（已存在美音音频）  [255/1877]
# ⏩ 跳过 adore（已存在美音音频）  [256/1877]
# ⏩ 跳过 altercation（已存在美音音频）  [257/1877]
# ⏩ 跳过 verbal（已存在美音音频）  [258/1877]
# ⏩ 跳过 screw up（已存在美音音频）  [259/1877]
# ⏩ 跳过 dietitian（已存在美音音频）  [260/1877]
# ⏩ 跳过 poverty（已存在美音音频）  [261/1877]
# ⏩ 跳过 stricken（已存在美音音频）  [262/1877]
# ⏩ 跳过 self-reliant（已存在美音音频）  [263/1877]
# ⏩ 跳过 stock（已存在美音音频）  [264/1877]
# ⏩ 跳过 cuddly（已存在美音音频）  [265/1877]
# ⏩ 跳过 custody（已存在美音音频）  [266/1877]
# ⏩ 跳过 subpoena（已存在美音音频）  [267/1877]
# ⏩ 跳过 issue（已存在美音音频）  [268/1877]
# ⏩ 跳过 trial（已存在美音音频）  [269/1877]
# ⏩ 跳过 sob（已存在美音音频）  [270/1877]
# ⏩ 跳过 drawn（已存在美音音频）  [271/1877]
# ⏩ 跳过 domestic（已存在美音音频）  [272/1877]
# ⏩ 跳过 bliss（已存在美音音频）  [273/1877]
# ⏩ 跳过 abusive（已存在美音音频）  [274/1877]
# ⏩ 跳过 firecracker（已存在美音音频）  [275/1877]
# ⏩ 跳过 fateful（已存在美音音频）  [276/1877]
#
# ❌ 未找到美音: morning sickness  [277/1877]
#
# ❌ 未找到美音: beaming with delight  [278/1877]
#
# ❌ 未找到美音: feeling flush  [279/1877]
# ⏩ 跳过 guilt（已存在美音音频）  [280/1877]
#
# ❌ 未找到美音: Timbavati Game Reserve  [281/1877]
#
# ❌ 未找到美音: Browning rifle  [282/1877]
#
# ❌ 未找到美音: thermal insulator  [283/1877]
# https://dictionary.cambridge.org/zhs/media/%E8%8B%B1%E8%AF%AD-%E6%B1%89%E8%AF%AD-%E7%AE%80%E4%BD%93/us_pron/p/pip/pipe_/pipe.mp3
# [音频] 下载失败: https://dictionary.cambridge.org/zhs/media/%E8%8B%B1%E8%AF%AD-%E6%B1%89%E8%AF%AD-%E7%AE%80%E4%BD%93/us_pron/p/pip/pipe_/pipe.mp3 (403 Client Error: Forbidden for url: https://dictionary.cambridge.org/zhs/media/%E8%8B%B1%E8%AF%AD-%E6%B1%89%E8%AF%AD-%E7%AE%80%E4%BD%93/us_pron/p/pip/pipe_/pipe.mp3)
# ✅ 已更新 pipe (1758557387093)  [284/1877]
# ⏱ 等待 11.0 秒以降低请求速率...
#
# ❌ 未找到美音: skeet  [285/1877]
#
# ❌ 未找到美音: coin-operated video game  [286/1877]
#
# ❌ 未找到美音: hooked on  [287/1877]
# ⏩ 跳过 lobby（已存在美音音频）  [288/1877]
#
# ❌ 未找到美音: Thunderbird  [289/1877]
#
# ❌ 未找到美音: budget inn  [290/1877]
#
# ❌ 未找到美音: hucksterism  [291/1877]
# ⏩ 跳过 samurai（已存在美音音频）  [292/1877]
#
# ❌ 未找到美音: drop us off  [293/1877]
#
# ❌ 未找到美音: country fair  [294/1877]
#
# ❌ 未找到美音: kick the other guy in the balls  [295/1877]
#
# ❌ 未找到美音: senior certificate exam  [296/1877]
#
# ❌ 未找到美音: brake fluid  [297/1877]
#
# ❌ 未找到美音: psychological retreat  [298/1877]
# ⏩ 跳过 comic（已存在美音音频）  [299/1877]
#
# ❌ 未找到美音: side room  [300/1877]
# ⏩ 跳过 wiles（已存在美音音频）  [301/1877]
# ⏩ 跳过 loving（已存在美音音频）  [302/1877]
# ⏩ 跳过 overworked（已存在美音音频）  [303/1877]
# ⏩ 跳过 distracted（已存在美音音频）  [304/1877]
# ⏩ 跳过 swagger（已存在美音音频）  [305/1877]
# ⏩ 跳过 manly（已存在美音音频）  [306/1877]
# ⏩ 跳过 convertible（已存在美音音频）  [307/1877]
# ⏩ 跳过 encyclopedia（已存在美音音频）  [308/1877]
# ⏩ 跳过 pristine（已存在美音音频）  [309/1877]
# ⏩ 跳过 mica（已存在美音音频）  [310/1877]
# ⏩ 跳过 uproot（已存在美音音频）  [311/1877]
# ⏩ 跳过 pavilion（已存在美音音频）  [312/1877]
# ⏩ 跳过 pooped（已存在美音音频）  [313/1877]
# ⏩ 跳过 calibre（已存在美音音频）  [314/1877]
# ⏩ 跳过 whisky（已存在美音音频）  [315/1877]
# ⏩ 跳过 flamboyance（已存在美音音频）  [316/1877]
# ⏩ 跳过 frugality（已存在美音音频）  [317/1877]
# ⏩ 跳过 legitimate（已存在美音音频）  [318/1877]
# ⏩ 跳过 grungy（已存在美音音频）  [319/1877]
# ⏩ 跳过 wondrous（已存在美音音频）  [320/1877]
# ⏩ 跳过 confederacy（已存在美音音频）  [321/1877]
# ⏩ 跳过 suburban（已存在美音音频）  [322/1877]
# ⏩ 跳过 indomitable（已存在美音音频）  [323/1877]
# ⏩ 跳过 contentious（已存在美音音频）  [324/1877]
# ⏩ 跳过 bevy（已存在美音音频）  [325/1877]
# ⏩ 跳过 buck（已存在美音音频）  [326/1877]
# ⏩ 跳过 indulgent（已存在美音音频）  [327/1877]
# ⏩ 跳过 conspire（已存在美音音频）  [328/1877]
# ⏩ 跳过 mischief（已存在美音音频）  [329/1877]
# ⏩ 跳过 rampage（已存在美音音频）  [330/1877]
# ⏩ 跳过 brawl（已存在美音音频）  [331/1877]
# ⏩ 跳过 reputation（已存在美音音频）  [332/1877]
# ⏩ 跳过 pedal（已存在美音音频）  [333/1877]
# ⏩ 跳过 pull over（已存在美音音频）  [334/1877]
# ⏩ 跳过 vicious（已存在美音音频）  [335/1877]
# ⏩ 跳过 crunch（已存在美音音频）  [336/1877]
# ⏩ 跳过 caning（已存在美音音频）  [337/1877]
# ⏩ 跳过 chapel（已存在美音音频）  [338/1877]
# ⏩ 跳过 chlorine（已存在美音音频）  [339/1877]
# ⏩ 跳过 hypnotize（已存在美音音频）  [340/1877]
# ⏩ 跳过 entrepreneurial（已存在美音音频）  [341/1877]
# ⏩ 跳过 foil（已存在美音音频）  [342/1877]
# ⏩ 跳过 ingenious（已存在美音音频）  [343/1877]
# ⏩ 跳过 balk（已存在美音音频）  [344/1877]
# ⏩ 跳过 stretch（已存在美音音频）  [345/1877]
# ⏩ 跳过 single-minded（已存在美音音频）  [346/1877]
# ⏩ 跳过 orbit（已存在美音音频）  [347/1877]
# ⏩ 跳过 propel（已存在美音音频）  [348/1877]
#
# ❌ 未找到美音: thruster  [349/1877]
# ⏩ 跳过 particle（已存在美音音频）  [350/1877]
# ⏩ 跳过 thrust（已存在美音音频）  [351/1877]
#
# ❌ 未找到美音: casual worker  [352/1877]
#
# ❌ 未找到美音: the Roman alphabet  [353/1877]
#
# ❌ 未找到美音: the shifting winds of geopolitics  [354/1877]
#
# ❌ 未找到美音: set too much store  [355/1877]
#
# ❌ 未找到美音: de-skilled  [356/1877]
#
# ❌ 未找到美音: hard right  [357/1877]
#
# ❌ 未找到美音: cultivate ties with  [358/1877]
#
# ❌ 未找到美音: a Medal of Honor winner  [359/1877]
# ⏩ 跳过 armistice（已存在美音音频）  [360/1877]
#
# ❌ 未找到美音: Executive Mansion  [361/1877]
#
# ❌ 未找到美音: bend upon  [362/1877]
#
# ❌ 未找到美音: an exercise in endurance  [363/1877]
#
# ❌ 未找到美音: arouse sb's wrath  [364/1877]
#
# ❌ 未找到美音: international scene  [365/1877]
#
# ❌ 未找到美音: Union Jack flew serenely over one-fourth of the earth’s arable surface  [366/1877]
#
# ❌ 未找到美音: The sun literally never sank upon it.  [367/1877]
#
# ❌ 未找到美音: the Rock of Gibraltar  [368/1877]
# ⏩ 跳过 motel（已存在美音音频）  [369/1877]
# ⏩ 跳过 existential（已存在美音音频）  [370/1877]
# ⏩ 跳过 Anglican（已存在美音音频）  [371/1877]
# ⏩ 跳过 loaf（已存在美音音频）  [372/1877]
# ⏩ 跳过 counter（已存在美音音频）  [373/1877]
# ⏩ 跳过 baptize（已存在美音音频）  [374/1877]
# ⏩ 跳过 metaphor（已存在美音音频）  [375/1877]
# ⏩ 跳过 cannibalism（已存在美音音频）  [376/1877]
# ⏩ 跳过 proletariat（已存在美音音频）  [377/1877]
# ⏩ 跳过 the precariat（已存在美音音频）  [378/1877]
# ⏩ 跳过 gig（已存在美音音频）  [379/1877]
# ⏩ 跳过 precarious（已存在美音音频）  [380/1877]
# ⏩ 跳过 fleeting（已存在美音音频）  [381/1877]
# ⏩ 跳过 fortune（已存在美音音频）  [382/1877]
# ⏩ 跳过 facet（已存在美音音频）  [383/1877]
# ⏩ 跳过 employment（已存在美音音频）  [384/1877]
# ⏩ 跳过 vaunted（已存在美音音频）  [385/1877]
# ⏩ 跳过 regimented（已存在美音音频）  [386/1877]
# ⏩ 跳过 flit（已存在美音音频）  [387/1877]
# ⏩ 跳过 recruitment（已存在美音音频）  [388/1877]
# ⏩ 跳过 vagaries（已存在美音音频）  [389/1877]
# ⏩ 跳过 adept（已存在美音音频）  [390/1877]
# ⏩ 跳过 dedicated（已存在美音音频）  [391/1877]
# ⏩ 跳过 migrant（已存在美音音频）  [392/1877]
# ⏩ 跳过 drudgery（已存在美音音频）  [393/1877]
# ⏩ 跳过 promiscuously（已存在美音音频）  [394/1877]
# ⏩ 跳过 cohort（已存在美音音频）  [395/1877]
# ⏩ 跳过 squander（已存在美音音频）  [396/1877]
# ⏩ 跳过 self-dealing（已存在美音音频）  [397/1877]
# ⏩ 跳过 armoured（已存在美音音频）  [398/1877]
# ⏩ 跳过 futile（已存在美音音频）  [399/1877]
# ⏩ 跳过 stamp something out（已存在美音音频）  [400/1877]
# ⏩ 跳过 taskmaster（已存在美音音频）  [401/1877]
# ⏩ 跳过 recklessly（已存在美音音频）  [402/1877]
# ⏩ 跳过 huddle（已存在美音音频）  [403/1877]
# ⏩ 跳过 nudge（已存在美音音频）  [404/1877]
# ⏩ 跳过 ambitious（已存在美音音频）  [405/1877]
# ⏩ 跳过 shoehorn（已存在美音音频）  [406/1877]
# ⏩ 跳过 onerous（已存在美音音频）  [407/1877]
# ⏩ 跳过 incentive（已存在美音音频）  [408/1877]
# ⏩ 跳过 revolt（已存在美音音频）  [409/1877]
# ⏩ 跳过 Islam（已存在美音音频）  [410/1877]
# ⏩ 跳过 rally（已存在美音音频）  [411/1877]
# ⏩ 跳过 bigotry（已存在美音音频）  [412/1877]
# ⏩ 跳过 preach（已存在美音音频）  [413/1877]
# ⏩ 跳过 insurgent（已存在美音音频）  [414/1877]
# ⏩ 跳过 overrun（已存在美音音频）  [415/1877]
# ⏩ 跳过 demographic（已存在美音音频）  [416/1877]
# ⏩ 跳过 oppression（已存在美音音频）  [417/1877]
# ⏩ 跳过 lump（已存在美音音频）  [418/1877]
# ⏩ 跳过 wokery（已存在美音音频）  [419/1877]
# ⏩ 跳过 immigration（已存在美音音频）  [420/1877]
# ⏩ 跳过 conspiracy（已存在美音音频）  [421/1877]
# ⏩ 跳过 pugnacity（已存在美音音频）  [422/1877]
# ⏩ 跳过 moderate（已存在美音音频）  [423/1877]
# ⏩ 跳过 radicalize（已存在美音音频）  [424/1877]
# ⏩ 跳过 flux（已存在美音音频）  [425/1877]
# ⏩ 跳过 normalize（已存在美音音频）  [426/1877]
# ⏩ 跳过 prologue（已存在美音音频）  [427/1877]
# ⏩ 跳过 rock bottom（已存在美音音频）  [428/1877]
# ⏩ 跳过 obscure（已存在美音音频）  [429/1877]
# ⏩ 跳过 penniless（已存在美音音频）  [430/1877]
# ⏩ 跳过 encamp（已存在美音音频）  [431/1877]
# ⏩ 跳过 dump（已存在美音音频）  [432/1877]
# ⏩ 跳过 drill（已存在美音音频）  [433/1877]
# ⏩ 跳过 faded（已存在美音音频）  [434/1877]
# ⏩ 跳过 cotton（已存在美音音频）  [435/1877]
# ⏩ 跳过 brood（已存在美音音频）  [436/1877]
# ⏩ 跳过 relief（已存在美音音频）  [437/1877]
# ⏩ 跳过 christen（已存在美音音频）  [438/1877]
# ⏩ 跳过 marcher（已存在美音音频）  [439/1877]
# ⏩ 跳过 expeditionary（已存在美音音频）  [440/1877]
# ⏩ 跳过 congressional（已存在美音音频）  [441/1877]
# ⏩ 跳过 patrol（已存在美音音频）  [442/1877]
# ⏩ 跳过 picketing（已存在美音音频）  [443/1877]
# ⏩ 跳过 soundly（已存在美音音频）  [444/1877]
# ⏩ 跳过 retrospect（已存在美音音频）  [445/1877]
# ⏩ 跳过 panoply（已存在美音音频）  [446/1877]
# ⏩ 跳过 frustrated（已存在美音音频）  [447/1877]
# ⏩ 跳过 panhandle（已存在美音音频）  [448/1877]
# ⏩ 跳过 menace（已存在美音音频）  [449/1877]
# ⏩ 跳过 ragged（已存在美音音频）  [450/1877]
# ⏩ 跳过 weary（已存在美音音频）  [451/1877]
# ⏩ 跳过 apathetic（已存在美音音频）  [452/1877]
# ⏩ 跳过 vigil（已存在美音音频）  [453/1877]
# ⏩ 跳过 makeshift（已存在美音音频）  [454/1877]
# ⏩ 跳过 commissary（已存在美音音频）  [455/1877]
# ⏩ 跳过 truckload（已存在美音音频）  [456/1877]
# ⏩ 跳过 haphazard（已存在美音音频）  [457/1877]
# ⏩ 跳过 stew（已存在美音音频）  [458/1877]
# ⏩ 跳过 loathe（已存在美音音频）  [459/1877]
# ⏩ 跳过 wilt（已存在美音音频）  [460/1877]
# ⏩ 跳过 humidity（已存在美音音频）  [461/1877]
# ⏩ 跳过 refrigerated（已存在美音音频）  [462/1877]
# ⏩ 跳过 awning（已存在美音音频）  [463/1877]
# ⏩ 跳过 porch（已存在美音音频）  [464/1877]
# ⏩ 跳过 wagon（已存在美音音频）  [465/1877]
# ⏩ 跳过 rug（已存在美音音频）  [466/1877]
# ⏩ 跳过 the vanguard（已存在美音音频）  [467/1877]
# ⏩ 跳过 springtime（已存在美音音频）  [468/1877]
# ⏩ 跳过 magnolia（已存在美音音频）  [469/1877]
# ⏩ 跳过 azalea（已存在美音音频）  [470/1877]
# ⏩ 跳过 pitiless（已存在美音音频）  [471/1877]
# ⏩ 跳过 down-at-heel（已存在美音音频）  [472/1877]
# ⏩ 跳过 obscurity（已存在美音音频）  [473/1877]
# ⏩ 跳过 substantive（已存在美音音频）  [474/1877]
# ⏩ 跳过 arable（已存在美音音频）  [475/1877]
# ⏩ 跳过 Oceania（已存在美音音频）  [476/1877]
# ⏩ 跳过 the West Indies（已存在美音音频）  [477/1877]
# ⏩ 跳过 allegiance（已存在美音音频）  [478/1877]
# ⏩ 跳过 sterling（已存在美音音频）  [479/1877]
#
# ❌ 未找到美音: ride-hailing driver  [480/1877]
#
# ❌ 未找到美音: food-delivery rider  [481/1877]
# ⏩ 跳过 bond（已存在美音音频）  [482/1877]
#
# ❌ 未找到美音: honour that promise  [483/1877]
#
# ❌ 未找到美音: It is polling at around 30%  [484/1877]
#
# ❌ 未找到美音: first-past-the-post system  [485/1877]
#
# ❌ 未找到美音: rail against  [486/1877]
#
# ❌ 未找到美音: off track with  [487/1877]
#
# ❌ 未找到美音: be nowhere near as high as these figures  [488/1877]
#
# ❌ 未找到美音: stick out its neck  [489/1877]
#
# ❌ 未找到美音: overdeliver  [490/1877]
#
# ❌ 未找到美音: fade into irrelevance  [491/1877]
#
# ❌ 未找到美音: neo-colonialism  [492/1877]
#
# ❌ 未找到美音: spill over to  [493/1877]
#
# ❌ 未找到美音: Sparta  [494/1877]
#
# ❌ 未找到美音: autarkic  [495/1877]
#
# ❌ 未找到美音: immediate neighbourhood  [496/1877]
#
# ❌ 未找到美音: pile pressure on  [497/1877]
#
# ❌ 未找到美音: come out of the blue  [498/1877]
#
# ❌ 未找到美音: reform-minded  [499/1877]
#
# ❌ 未找到美音: pitch themselves as steady hands  [500/1877]
#
# ❌ 未找到美音: conflict-ridden  [501/1877]
#
# ❌ 未找到美音: ascendance  [502/1877]
#
# ❌ 未找到美音: a source of comfort  [503/1877]
#
# ❌ 未找到美音: low-ball  [504/1877]
#
# ❌ 未找到美音: anything but  [505/1877]
#
# ❌ 未找到美音: grow sick of  [506/1877]
#
# ❌ 未找到美音: set down roots in the cities  [507/1877]
# ⏩ 跳过 xenophobic（已存在美音音频）  [508/1877]
# ⏩ 跳过 wage（已存在美音音频）  [509/1877]
# ⏩ 跳过 surrogacy（已存在美音音频）  [510/1877]
# ⏩ 跳过 cleave to something（已存在美音音频）  [511/1877]
# ⏩ 跳过 largesse（已存在美音音频）  [512/1877]
# ⏩ 跳过 tilt（已存在美音音频）  [513/1877]
# ⏩ 跳过 reassure（已存在美音音频）  [514/1877]
# ⏩ 跳过 woo（已存在美音音频）  [515/1877]
# ⏩ 跳过 disaffection（已存在美音音频）  [516/1877]
# ⏩ 跳过 rhetoric（已存在美音音频）  [517/1877]
# ⏩ 跳过 coalition（已存在美音音频）  [518/1877]
# ⏩ 跳过 deportation（已存在美音音频）  [519/1877]
# ⏩ 跳过 bristle（已存在美音音频）  [520/1877]
# ⏩ 跳过 wrecker（已存在美音音频）  [521/1877]
#
# ❌ 未找到美音: fret about something  [522/1877]
# ⏩ 跳过 lining（已存在美音音频）  [523/1877]
# ⏩ 跳过 humdrum（已存在美音音频）  [524/1877]
# ⏩ 跳过 steel mill（已存在美音音频）  [525/1877]
# ⏩ 跳过 dip（已存在美音音频）  [526/1877]
# ⏩ 跳过 ratify（已存在美音音频）  [527/1877]
# ⏩ 跳过 overachieve（已存在美音音频）  [528/1877]
# ⏩ 跳过 methane（已存在美音音频）  [529/1877]
# ⏩ 跳过 paddy（已存在美音音频）  [530/1877]
# ⏩ 跳过 clue（已存在美音音频）  [531/1877]
# ⏩ 跳过 plug (something/someone) into something（已存在美音音频）  [532/1877]
# ⏩ 跳过 inevitably（已存在美音音频）  [533/1877]
# ⏩ 跳过 venture（已存在美音音频）  [534/1877]
# ⏩ 跳过 appetite（已存在美音音频）  [535/1877]
#
# ❌ 未找到美音: blast  [536/1877]
# ⏩ 跳过 smattering（已存在美音音频）  [537/1877]
# ⏩ 跳过 phase something out（已存在美音音频）  [538/1877]
# ⏩ 跳过 drought（已存在美音音频）  [539/1877]
# ⏩ 跳过 breakneck（已存在美音音频）  [540/1877]
# ⏩ 跳过 outstrip（已存在美音音频）  [541/1877]
# ⏩ 跳过 Jerusalem（已存在美音音频）  [542/1877]
# ⏩ 跳过 statehood（已存在美音音频）  [543/1877]
# ⏩ 跳过 pariah（已存在美音音频）  [544/1877]
# ⏩ 跳过 dire（已存在美音音频）  [545/1877]
# ⏩ 跳过 blithe（已存在美音音频）  [546/1877]
# ⏩ 跳过 riled（已存在美音音频）  [547/1877]
# ⏩ 跳过 drift（已存在美音音频）  [548/1877]
# ⏩ 跳过 indulge（已存在美音音频）  [549/1877]
# ⏩ 跳过 startling（已存在美音音频）  [550/1877]
# ⏩ 跳过 evangelical（已存在美音音频）  [551/1877]
# ⏩ 跳过 amalgam（已存在美音音频）  [552/1877]
# ⏩ 跳过 refuge（已存在美音音频）  [553/1877]
# ⏩ 跳过 persecution（已存在美音音频）  [554/1877]
# ⏩ 跳过 unto（已存在美音音频）  [555/1877]
# ⏩ 跳过 bulwark（已存在美音音频）  [556/1877]
# ⏩ 跳过 falling-out（已存在美音音频）  [557/1877]
# ⏩ 跳过 dismay（已存在美音音频）  [558/1877]
# ⏩ 跳过 strained（已存在美音音频）  [559/1877]
# ⏩ 跳过 divergent（已存在美音音频）  [560/1877]
# ⏩ 跳过 taxpayer（已存在美音音频）  [561/1877]
# ⏩ 跳过 undermine（已存在美音音频）  [562/1877]
# ⏩ 跳过 gravitate towards/to something/someone（已存在美音音频）  [563/1877]
# ⏩ 跳过 monarchy（已存在美音音频）  [564/1877]
# ⏩ 跳过 shudder（已存在美音音频）  [565/1877]
# ⏩ 跳过 hurl（已存在美音音频）  [566/1877]
# ⏩ 跳过 heinous（已存在美音音频）  [567/1877]
# ⏩ 跳过 sting（已存在美音音频）  [568/1877]
# ⏩ 跳过 scaremongering（已存在美音音频）  [569/1877]
# ⏩ 跳过 fall out（已存在美音音频）  [570/1877]
# ⏩ 跳过 assert（已存在美音音频）  [571/1877]
# ⏩ 跳过 ascendancy（已存在美音音频）  [572/1877]
# ⏩ 跳过 complacent（已存在美音音频）  [573/1877]
# ⏩ 跳过 row（已存在美音音频）  [574/1877]
# ⏩ 跳过 momentum（已存在美音音频）  [575/1877]
# ⏩ 跳过 taboo（已存在美音音频）  [576/1877]
# ⏩ 跳过 crumble（已存在美音音频）  [577/1877]
# ⏩ 跳过 instinctively（已存在美音音频）  [578/1877]
# ⏩ 跳过 Zionist（已存在美音音频）  [579/1877]
# ⏩ 跳过 underpin（已存在美音音频）  [580/1877]
# ⏩ 跳过 annex（已存在美音音频）  [581/1877]
# ⏩ 跳过 muscle-bound（已存在美音音频）  [582/1877]
# ⏩ 跳过 tragic（已存在美音音频）  [583/1877]
# ⏩ 跳过 misconception（已存在美音音频）  [584/1877]
# ⏩ 跳过 irreplaceable（已存在美音音频）  [585/1877]
# ⏩ 跳过 blunder（已存在美音音频）  [586/1877]
# ⏩ 跳过 turmoil（已存在美音音频）  [587/1877]
# ⏩ 跳过 step aside/down（已存在美音音频）  [588/1877]
# ⏩ 跳过 herald（已存在美音音频）  [589/1877]
# ⏩ 跳过 harried（已存在美音音频）  [590/1877]
# ⏩ 跳过 upstart（已存在美音音频）  [591/1877]
# ⏩ 跳过 racked（已存在美音音频）  [592/1877]
# ⏩ 跳过 centrist（已存在美音音频）  [593/1877]
# ⏩ 跳过 juncture（已存在美音音频）  [594/1877]
# ⏩ 跳过 lower house（已存在美音音频）  [595/1877]
# ⏩ 跳过 snap（已存在美音音频）  [596/1877]
# ⏩ 跳过 upper house（已存在美音音频）  [597/1877]
# ⏩ 跳过 woe（已存在美音音频）  [598/1877]
# ⏩ 跳过 precede（已存在美音音频）  [599/1877]
# ⏩ 跳过 flurry（已存在美音音频）  [600/1877]
# ⏩ 跳过 reckoning（已存在美音音频）  [601/1877]
# ⏩ 跳过 withering（已存在美音音频）  [602/1877]
# ⏩ 跳过 pre-empted（已存在美音音频）  [603/1877]
# ⏩ 跳过 campaign（已存在美音音频）  [604/1877]
# ⏩ 跳过 fundraising（已存在美音音频）  [605/1877]
# ⏩ 跳过 fork（已存在美音音频）  [606/1877]
# ⏩ 跳过 swathe（已存在美音音频）  [607/1877]
# ⏩ 跳过 prospective（已存在美音音频）  [608/1877]
# ⏩ 跳过 internal affairs（已存在美音音频）  [609/1877]
# ⏩ 跳过 standard-bearer（已存在美音音频）  [610/1877]
# ⏩ 跳过 lawmaker（已存在美音音频）  [611/1877]
# ⏩ 跳过 dues-paying（已存在美音音频）  [612/1877]
# ⏩ 跳过 burnish（已存在美音音频）  [613/1877]
# ⏩ 跳过 credentials（已存在美音音频）  [614/1877]
# ⏩ 跳过 stem（已存在美音音频）  [615/1877]
# ⏩ 跳过 fray（已存在美音音频）  [616/1877]
# ⏩ 跳过 grandee（已存在美音音频）  [617/1877]
# ⏩ 跳过 the status quo（已存在美音音频）  [618/1877]
# ⏩ 跳过 cement（已存在美音音频）  [619/1877]
# ⏩ 跳过 high-minded（已存在美音音频）  [620/1877]
# ⏩ 跳过 compelling（已存在美音音频）  [621/1877]
# ⏩ 跳过 duly（已存在美音音频）  [622/1877]
# ⏩ 跳过 prowess（已存在美音音频）  [623/1877]
# ⏩ 跳过 pandemic（已存在美音音频）  [624/1877]
# ⏩ 跳过 electrician（已存在美音音频）  [625/1877]
# ⏩ 跳过 discrepancy（已存在美音音频）  [626/1877]
# ⏩ 跳过 repression（已存在美音音频）  [627/1877]
# ⏩ 跳过 disgusted（已存在美音音频）  [628/1877]
# ⏩ 跳过 projector（已存在美音音频）  [629/1877]
# ⏩ 跳过 tower block（已存在美音音频）  [630/1877]
# ⏩ 跳过 daring（已存在美音音频）  [631/1877]
# ⏩ 跳过 gangmaster（已存在美音音频）  [632/1877]
# ⏩ 跳过 attain（已存在美音音频）  [633/1877]
# ⏩ 跳过 prosper（已存在美音音频）  [634/1877]
# ⏩ 跳过 throng（已存在美音音频）  [635/1877]
# ⏩ 跳过 pressing（已存在美音音频）  [636/1877]
# ⏩ 跳过 obsessed（已存在美音音频）  [637/1877]
#
# ❌ 未找到美音: air grievances  [638/1877]
#
# ❌ 未找到美音: legislative authority  [639/1877]
#
# ❌ 未找到美音: group organising  [640/1877]
#
# ❌ 未找到美音: routed through voluntary contributions  [641/1877]
# ⏩ 跳过 deadlocked（已存在美音音频）  [642/1877]
#
# ❌ 未找到美音: crippled at birth  [643/1877]
# ⏩ 跳过 decline（已存在美音音频）  [644/1877]
#
# ❌ 未找到美音: parts of the high seas  [645/1877]
#
# ❌ 未找到美音: to take a clear stand against hegemonism and power politics  [646/1877]
# ⏩ 跳过 wary（已存在美音音频）  [647/1877]
# ⏩ 跳过 underfunded（已存在美音音频）  [648/1877]
#
# ❌ 未找到美音: pick-and-mix  [649/1877]
#
# ❌ 未找到美音: duplicative  [650/1877]
#
# ❌ 未找到美音: Desperate times, desperate measures.  [651/1877]
# ⏩ 跳过 sentence（已存在美音音频）  [652/1877]
# ⏩ 跳过 interrogation（已存在美音音频）  [653/1877]
# ⏩ 跳过 dissent（已存在美音音频）  [654/1877]
# ⏩ 跳过 surveillance（已存在美音音频）  [655/1877]
# ⏩ 跳过 appeal（已存在美音音频）  [656/1877]
# ⏩ 跳过 sluggish（已存在美音音频）  [657/1877]
# ⏩ 跳过 contractor（已存在美音音频）  [658/1877]
# ⏩ 跳过 undercount（已存在美音音频）  [659/1877]
# ⏩ 跳过 demonstrator（已存在美音音频）  [660/1877]
# ⏩ 跳过 kowtow（已存在美音音频）  [661/1877]
# ⏩ 跳过 petition（已存在美音音频）  [662/1877]
# ⏩ 跳过 heavy-handed（已存在美音音频）  [663/1877]
# ⏩ 跳过 bubble（已存在美音音频）  [664/1877]
# ⏩ 跳过 shareholder（已存在美音音频）  [665/1877]
# ⏩ 跳过 liability（已存在美音音频）  [666/1877]
# ⏩ 跳过 spark（已存在美音音频）  [667/1877]
# ⏩ 跳过 rabble-rouser（已存在美音音频）  [668/1877]
# ⏩ 跳过 suppress（已存在美音音频）  [669/1877]
# ⏩ 跳过 scrub（已存在美音音频）  [670/1877]
# ⏩ 跳过 curate（已存在美音音频）  [671/1877]
# ⏩ 跳过 archive（已存在美音音频）  [672/1877]
# ⏩ 跳过 copycat（已存在美音音频）  [673/1877]
# ⏩ 跳过 grassroots（已存在美音音频）  [674/1877]
# ⏩ 跳过 resolve（已存在美音音频）  [675/1877]
# ⏩ 跳过 grievance（已存在美音音频）  [676/1877]
# ⏩ 跳过 afterlife（已存在美音音频）  [677/1877]
# ⏩ 跳过 Congo（已存在美音音频）  [678/1877]
# ⏩ 跳过 massacre（已存在美音音频）  [679/1877]
# ⏩ 跳过 calamitous（已存在美音音频）  [680/1877]
# ⏩ 跳过 duel（已存在美音音频）  [681/1877]
# ⏩ 跳过 bête noire（已存在美音音频）  [682/1877]
# ⏩ 跳过 budgetary（已存在美音音频）  [683/1877]
# ⏩ 跳过 unveil（已存在美音音频）  [684/1877]
# ⏩ 跳过 delinquent（已存在美音音频）  [685/1877]
# ⏩ 跳过 habitually（已存在美音音频）  [686/1877]
# ⏩ 跳过 obligatory（已存在美音音频）  [687/1877]
# ⏩ 跳过 dues（已存在美音音频）  [688/1877]
# ⏩ 跳过 humanitarian（已存在美音音频）  [689/1877]
# ⏩ 跳过 slash（已存在美音音频）  [690/1877]
# ⏩ 跳过 batter（已存在美音音频）  [691/1877]
# ⏩ 跳过 dry something up（已存在美音音频）  [692/1877]
# ⏩ 跳过 peacekeeping（已存在美音音频）  [693/1877]
# ⏩ 跳过 fashion（已存在美音音频）  [694/1877]
# ⏩ 跳过 mock（已存在美音音频）  [695/1877]
# ⏩ 跳过 brazenly（已存在美音音频）  [696/1877]
# ⏩ 跳过 airy（已存在美音音频）  [697/1877]
# ⏩ 跳过 polarize（已存在美音音频）  [698/1877]
# ⏩ 跳过 secretariat（已存在美音音频）  [699/1877]
# ⏩ 跳过 adversary（已存在美音音频）  [700/1877]
# ⏩ 跳过 radicalism（已存在美音音频）  [701/1877]
# ⏩ 跳过 rupture（已存在美音音频）  [702/1877]
# ⏩ 跳过 arrears（已存在美音音频）  [703/1877]
# ⏩ 跳过 deliberative（已存在美音音频）  [704/1877]
# https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cdo/cdo11/cdo1119usnonb0833.mp3
# [音频] 下载失败: https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cdo/cdo11/cdo1119usnonb0833.mp3 (403 Client Error: Forbidden for url: https://dictionary.cambridge.org/media/english-chinese-simplified/us_pron/c/cdo/cdo11/cdo1119usnonb0833.mp3)
# ✅ 已更新 non-binding (1759154292684)  [705/1877]
# ⏱ 等待 12.4 秒以降低请求速率...
# ⏩ 跳过 pronouncement（已存在美音音频）  [706/1877]
# ⏩ 跳过 retaliation（已存在美音音频）  [707/1877]
# ⏩ 跳过 catalyst（已存在美音音频）  [708/1877]
# ⏩ 跳过 steep something/someone in something（已存在美音音频）  [709/1877]
# ⏩ 跳过 escalate（已存在美音音频）  [710/1877]
# ⏩ 跳过 Saudi Arabia（已存在美音音频）  [711/1877]
# ⏩ 跳过 visa（已存在美音音频）  [712/1877]
# ⏩ 跳过 Palestinian（已存在美音音频）  [713/1877]
# ⏩ 跳过 sprawling（已存在美音音频）  [714/1877]
# ⏩ 跳过 utopian（已存在美音音频）  [715/1877]
# ⏩ 跳过 creep（已存在美音音频）  [716/1877]
# ⏩ 跳过 reek（已存在美音音频）  [717/1877]
# ⏩ 跳过 endorsement（已存在美音音频）  [718/1877]
# ⏩ 跳过 staffing（已存在美音音频）  [719/1877]
# ⏩ 跳过 uphold（已存在美音音频）  [720/1877]
# ⏩ 跳过 genuine（已存在美音音频）  [721/1877]
# ⏩ 跳过 undo（已存在美音音频）  [722/1877]
#
# ❌ 未找到美音: reparations  [723/1877]
# ⏩ 跳过 equitably（已存在美音音频）  [724/1877]
# ⏩ 跳过 galvanize（已存在美音音频）  [725/1877]
# ⏩ 跳过 resistance（已存在美音音频）  [726/1877]
# ⏩ 跳过 Eurasian（已存在美音音频）  [727/1877]
# ⏩ 跳过 hegemonism（已存在美音音频）  [728/1877]
# ⏩ 跳过 multilateralism（已存在美音音频）  [729/1877]
# ⏩ 跳过 spite（已存在美音音频）  [730/1877]
# ⏩ 跳过 fragmented（已存在美音音频）  [731/1877]
# ⏩ 跳过 antagonize（已存在美音音频）  [732/1877]
# ⏩ 跳过 tangle（已存在美音音频）  [733/1877]
# ⏩ 跳过 untouched（已存在美音音频）  [734/1877]
# ⏩ 跳过 plead（已存在美音音频）  [735/1877]
# ⏩ 跳过 spasm（已存在美音音频）  [736/1877]
# ⏩ 跳过 reflexive（已存在美音音频）  [737/1877]
# ⏩ 跳过 the Security Council（已存在美音音频）  [738/1877]
# ⏩ 跳过 mandate（已存在美音音频）  [739/1877]
# ⏩ 跳过 Cyprus（已存在美音音频）  [740/1877]
# ⏩ 跳过 reinvention（已存在美音音频）  [741/1877]
# ⏩ 跳过 asylum（已存在美音音频）  [742/1877]
# ⏩ 跳过 ravage（已存在美音音频）  [743/1877]
# ⏩ 跳过 snapback（已存在美音音频）  [744/1877]
# ⏩ 跳过 showy（已存在美音音频）  [745/1877]
# ⏩ 跳过 pomp（已存在美音音频）  [746/1877]
# ⏩ 跳过 marginal（已存在美音音频）  [747/1877]
# ⏩ 跳过 abolish（已存在美音音频）  [748/1877]
# ⏩ 跳过 jihadist（已存在美音音频）  [749/1877]
# ⏩ 跳过 whim（已存在美音音频）  [750/1877]
# ⏩ 跳过 hang on（已存在美音音频）  [751/1877]
# ⏩ 跳过 hustings（已存在美音音频）  [752/1877]
# ⏩ 跳过 jockey（已存在美音音频）  [753/1877]
# ⏩ 跳过 tally（已存在美音音频）  [754/1877]
# ⏩ 跳过 flock（已存在美音音频）  [755/1877]
#
# ❌ 未找到美音: Yasukuni Shrine  [756/1877]
#
# ❌ 未找到美音: nerve-jangling  [757/1877]
#
# ❌ 未找到美音: tap for cash  [758/1877]
#
# ❌ 未找到美音: knot a necktie  [759/1877]
# ⏩ 跳过 cause（已存在美音音频）  [760/1877]
# ⏩ 跳过 libtard（已存在美音音频）  [761/1877]
#
# ❌ 未找到美音: margin of victory  [762/1877]
#
# ❌ 未找到美音: get-out-the vote campaign  [763/1877]
#
# ❌ 未找到美音: wokism  [764/1877]
#
# ❌ 未找到美音: rip the blinkers off liberal students’ eyes  [765/1877]
#
# ❌ 未找到美音: the then speaker of the House of Representatives  [766/1877]
#
# ❌ 未找到美音: light-skinned  [767/1877]
#
# ❌ 未找到美音: fast-casual restaurant chain  [768/1877]
#
# ❌ 未找到美音: pre-made dish  [769/1877]
#
# ❌ 未找到美音: entrepreneur-cum-influencer  [770/1877]
# ⏩ 跳过 bound（已存在美音音频）  [771/1877]
#
# ❌ 未找到美音: field-fresh  [772/1877]
#
# ❌ 未找到美音: A Bite of China  [773/1877]
#
# ❌ 未找到美音: Buddha jumps over the wall  [774/1877]
# ⏩ 跳过 stand（已存在美音音频）  [775/1877]
# ⏩ 跳过 pragmatist（已存在美音音频）  [776/1877]
# ⏩ 跳过 unevenly（已存在美音音频）  [777/1877]
# ⏩ 跳过 catastrophically（已存在美音音频）  [778/1877]
# ⏩ 跳过 front-runner（已存在美音音频）  [779/1877]
# ⏩ 跳过 crucially（已存在美音音频）  [780/1877]
# ⏩ 跳过 hazily（已存在美音音频）  [781/1877]
# ⏩ 跳过 shrine（已存在美音音频）  [782/1877]
# ⏩ 跳过 controversial（已存在美音音频）  [783/1877]
# ⏩ 跳过 falter（已存在美音音频）  [784/1877]
# ⏩ 跳过 beef something up（已存在美音音频）  [785/1877]
# ⏩ 跳过 jolt（已存在美音音频）  [786/1877]
# ⏩ 跳过 bumpy（已存在美音音频）  [787/1877]
# ⏩ 跳过 contend（已存在美音音频）  [788/1877]
# ⏩ 跳过 swallow（已存在美音音频）  [789/1877]
# ⏩ 跳过 acclaim（已存在美音音频）  [790/1877]
# ⏩ 跳过 spate（已存在美音音频）  [791/1877]
# ⏩ 跳过 take someone aback（已存在美音音频）  [792/1877]
# ⏩ 跳过 gangly（已存在美音音频）  [793/1877]
# ⏩ 跳过 bulldog（已存在美音音频）  [794/1877]
# ⏩ 跳过 tenacity（已存在美音音频）  [795/1877]
# ⏩ 跳过 formidable（已存在美音音频）  [796/1877]
# ⏩ 跳过 juggernaut（已存在美音音频）  [797/1877]
# ⏩ 跳过 chapter（已存在美音音频）  [798/1877]
# ⏩ 跳过 buzzy（已存在美音音频）  [799/1877]
# ⏩ 跳过 tribune（已存在美音音频）  [800/1877]
# ⏩ 跳过 horde（已存在美音音频）  [801/1877]
# ⏩ 跳过 blinker（已存在美音音频）  [802/1877]
# ⏩ 跳过 swing（已存在美音音频）  [803/1877]
# ⏩ 跳过 springboard（已存在美音音频）  [804/1877]
# ⏩ 跳过 demonstrate（已存在美音音频）  [805/1877]
# ⏩ 跳过 force-out（已存在美音音频）  [806/1877]
# ⏩ 跳过 vet（已存在美音音频）  [807/1877]
# ⏩ 跳过 appointee（已存在美音音频）  [808/1877]
# ⏩ 跳过 power broker（已存在美音音频）  [809/1877]
# ⏩ 跳过 consequent（已存在美音音频）  [810/1877]
# ⏩ 跳过 ballot box（已存在美音音频）  [811/1877]
# ⏩ 跳过 crucible（已存在美音音频）  [812/1877]
# ⏩ 跳过 forge（已存在美音音频）  [813/1877]
# ⏩ 跳过 reclaim（已存在美音音频）  [814/1877]
# ⏩ 跳过 bellicose（已存在美音音频）  [815/1877]
# ⏩ 跳过 fiery（已存在美音音频）  [816/1877]
# ⏩ 跳过 on the stump（已存在美音音频）  [817/1877]
# ⏩ 跳过 rancour（已存在美音音频）  [818/1877]
# ⏩ 跳过 near miss（已存在美音音频）  [819/1877]
# ⏩ 跳过 arson（已存在美音音频）  [820/1877]
# ⏩ 跳过 thwart（已存在美音音频）  [821/1877]
# ⏩ 跳过 bludgeon（已存在美音音频）  [822/1877]
# ⏩ 跳过 overwhelmingly（已存在美音音频）  [823/1877]
# ⏩ 跳过 endorse（已存在美音音频）  [824/1877]
# ⏩ 跳过 awash（已存在美音音频）  [825/1877]
# ⏩ 跳过 claim（已存在美音音频）  [826/1877]
# ⏩ 跳过 laud（已存在美音音频）  [827/1877]
# ⏩ 跳过 perception（已存在美音音频）  [828/1877]
# ⏩ 跳过 abhor（已存在美音音频）  [829/1877]
# ⏩ 跳过 misperception（已存在美音音频）  [830/1877]
# ⏩ 跳过 frostily（已存在美音音频）  [831/1877]
# ⏩ 跳过 hoop（已存在美音音频）  [832/1877]
# ⏩ 跳过 hoopla（已存在美音音频）  [833/1877]
#
# ❌ 未找到美音: Macau  [834/1877]
# ⏩ 跳过 stake（已存在美音音频）  [835/1877]
# ⏩ 跳过 tread（已存在美音音频）  [836/1877]
# ⏩ 跳过 remark（已存在美音音频）  [837/1877]
# ⏩ 跳过 episode（已存在美音音频）  [838/1877]
# ⏩ 跳过 backlash（已存在美音音频）  [839/1877]
# ⏩ 跳过 patch something up（已存在美音音频）  [840/1877]
# ⏩ 跳过 prelude（已存在美音音频）  [841/1877]
# ⏩ 跳过 sportswear（已存在美音音频）  [842/1877]
# ⏩ 跳过 wares（已存在美音音频）  [843/1877]
# ⏩ 跳过 justified（已存在美音音频）  [844/1877]
# ⏩ 跳过 culinary（已存在美音音频）  [845/1877]
# ⏩ 跳过 sunburned（已存在美音音频）  [846/1877]
# ⏩ 跳过 equinox（已存在美音音频）  [847/1877]
# ⏩ 跳过 gloomy（已存在美音音频）  [848/1877]
# ⏩ 跳过 Caribbean（已存在美音音频）  [849/1877]
# ⏩ 跳过 scramble（已存在美音音频）  [850/1877]
# ⏩ 跳过 denizen（已存在美音音频）  [851/1877]
# ⏩ 跳过 autoimmune（已存在美音音频）  [852/1877]
# ⏩ 跳过 Brit（已存在美音音频）  [853/1877]
# ⏩ 跳过 distil（已存在美音音频）  [854/1877]
# ⏩ 跳过 furore（已存在美音音频）  [855/1877]
# ⏩ 跳过 erupt（已存在美音音频）  [856/1877]
# ⏩ 跳过 bill（已存在美音音频）  [857/1877]
# ⏩ 跳过 scrumptious（已存在美音音频）  [858/1877]
# ⏩ 跳过 whip something up（已存在美音音频）  [859/1877]
# ⏩ 跳过 authenticity（已存在美音音频）  [860/1877]
# ⏩ 跳过 innocuously（已存在美音音频）  [861/1877]
# ⏩ 跳过 acerbic（已存在美音音频）  [862/1877]
# ⏩ 跳过 disgusting（已存在美音音频）  [863/1877]
# ⏩ 跳过 fume（已存在美音音频）  [864/1877]
# ⏩ 跳过 defamation（已存在美音音频）  [865/1877]
# ⏩ 跳过 spirited（已存在美音音频）  [866/1877]
# ⏩ 跳过 broccoli（已存在美音音频）  [867/1877]
# ⏩ 跳过 toss（已存在美音音频）  [868/1877]
# ⏩ 跳过 bouillon（已存在美音音频）  [869/1877]
# ⏩ 跳过 indulgence（已存在美音音频）  [870/1877]
# ⏩ 跳过 hypocrisy（已存在美音音频）  [871/1877]
# ⏩ 跳过 outlet（已存在美音音频）  [872/1877]
# ⏩ 跳过 metropolitan（已存在美音音频）  [873/1877]
# ⏩ 跳过 nourishment（已存在美音音频）  [874/1877]
# ⏩ 跳过 trade on something（已存在美音音频）  [875/1877]
# ⏩ 跳过 interior（已存在美音音频）  [876/1877]
# ⏩ 跳过 gingham（已存在美音音频）  [877/1877]
# ⏩ 跳过 knead（已存在美音音频）  [878/1877]
# ⏩ 跳过 crisp（已存在美音音频）  [879/1877]
# ⏩ 跳过 gastronomic（已存在美音音频）  [880/1877]
# ⏩ 跳过 rubbernecker（已存在美音音频）  [881/1877]
# ⏩ 跳过 peeve（已存在美音音频）  [882/1877]
# ⏩ 跳过 boycott（已存在美音音频）  [883/1877]
# ⏩ 跳过 humbling（已存在美音音频）  [884/1877]
# ⏩ 跳过 utterly（已存在美音音频）  [885/1877]
# ⏩ 跳过 inescapable（已存在美音音频）  [886/1877]
# ⏩ 跳过 exquisite（已存在美音音频）  [887/1877]
# ⏩ 跳过 heavenly（已存在美音音频）  [888/1877]
# ⏩ 跳过 idyllic（已存在美音音频）  [889/1877]
# ⏩ 跳过 fare（已存在美音音频）  [890/1877]
# ⏩ 跳过 corridor（已存在美音音频）  [891/1877]
# ⏩ 跳过 glossy（已存在美音音频）  [892/1877]
# ⏩ 跳过 gruelling（已存在美音音频）  [893/1877]
# ⏩ 跳过 tremendous（已存在美音音频）  [894/1877]
# ⏩ 跳过 hinterland（已存在美音音频）  [895/1877]
# ⏩ 跳过 underserved（已存在美音音频）  [896/1877]
# ⏩ 跳过 preservative（已存在美音音频）  [897/1877]
# ⏩ 跳过 perversely（已存在美音音频）  [898/1877]
# ⏩ 跳过 two-tier（已存在美音音频）  [899/1877]
# ⏩ 跳过 decent（已存在美音音频）  [900/1877]
# ⏩ 跳过 leveller（已存在美音音频）  [901/1877]
# ⏩ 跳过 posh（已存在美音音频）  [902/1877]
# ⏩ 跳过 foodie（已存在美音音频）  [903/1877]
# ⏩ 跳过 gall（已存在美音音频）  [904/1877]
# ⏩ 跳过 epidemiologist（已存在美音音频）  [905/1877]
# ⏩ 跳过 dermatologist（已存在美音音频）  [906/1877]
# ⏩ 跳过 melanin（已存在美音音频）  [907/1877]
# ⏩ 跳过 pigment（已存在美音音频）  [908/1877]
# ⏩ 跳过 deformity（已存在美音音频）  [909/1877]
# ⏩ 跳过 shortage（已存在美音音频）  [910/1877]
# ⏩ 跳过 vessel（已存在美音音频）  [911/1877]
# ⏩ 跳过 grudgingly（已存在美音音频）  [912/1877]
# ⏩ 跳过 buzz（已存在美音音频）  [913/1877]
# ⏩ 跳过 crane（已存在美音音频）  [914/1877]
# ⏩ 跳过 customs（已存在美音音频）  [915/1877]
# ⏩ 跳过 endeavour（已存在美音音频）  [916/1877]
# ⏩ 跳过 curb（已存在美音音频）  [917/1877]
# ⏩ 跳过 apace（已存在美音音频）  [918/1877]
# ⏩ 跳过 flank（已存在美音音频）  [919/1877]
# ⏩ 跳过 vie（已存在美音音频）  [920/1877]
# ⏩ 跳过 hellscape（已存在美音音频）  [921/1877]
# ⏩ 跳过 plough（已存在美音音频）  [922/1877]
# ⏩ 跳过 brew（已存在美音音频）  [923/1877]
# ⏩ 跳过 grapple（已存在美音音频）  [924/1877]
# ⏩ 跳过 supreme（已存在美音音频）  [925/1877]
# ⏩ 跳过 envoy（已存在美音音频）  [926/1877]
# ⏩ 跳过 confidant（已存在美音音频）  [927/1877]
# ⏩ 跳过 distinct（已存在美音音频）  [928/1877]
# ⏩ 跳过 tout（已存在美音音频）  [929/1877]
# ⏩ 跳过 riviera（已存在美音音频）  [930/1877]
# ⏩ 跳过 provincial（已存在美音音频）  [931/1877]
# ⏩ 跳过 stopover（已存在美音音频）  [932/1877]
# ⏩ 跳过 precursor（已存在美音音频）  [933/1877]
# ⏩ 跳过 endear someone to someone（已存在美音音频）  [934/1877]
# ⏩ 跳过 thump（已存在美音音频）  [935/1877]
# ⏩ 跳过 see someone off（已存在美音音频）  [936/1877]
# ⏩ 跳过 occupation（已存在美音音频）  [937/1877]
# ⏩ 跳过 beckon（已存在美音音频）  [938/1877]
# ⏩ 跳过 administer（已存在美音音频）  [939/1877]
# ⏩ 跳过 mediator（已存在美音音频）  [940/1877]
# ⏩ 跳过 messianic（已存在美音音频）  [941/1877]
# ⏩ 跳过 bonanza（已存在美音音频）  [942/1877]
# ⏩ 跳过 estate（已存在美音音频）  [943/1877]
# ⏩ 跳过 incestuous（已存在美音音频）  [944/1877]
# ⏩ 跳过 beleaguered（已存在美音音频）  [945/1877]
# ⏩ 跳过 eye-popping（已存在美音音频）  [946/1877]
# ⏩ 跳过 intertwine（已存在美音音频）  [947/1877]
# ⏩ 跳过 entangle（已存在美音音频）  [948/1877]
# ⏩ 跳过 buoy（已存在美音音频）  [949/1877]
# ⏩ 跳过 expedient（已存在美音音频）  [950/1877]
# ⏩ 跳过 bull（已存在美音音频）  [951/1877]
# ⏩ 跳过 blowout（已存在美音音频）  [952/1877]
# ⏩ 跳过 projection（已存在美音音频）  [953/1877]
# ⏩ 跳过 bumper（已存在美音音频）  [954/1877]
# ⏩ 跳过 underwhelming（已存在美音音频）  [955/1877]
# ⏩ 跳过 dwarf（已存在美音音频）  [956/1877]
# ⏩ 跳过 lax（已存在美音音频）  [957/1877]
# ⏩ 跳过 bullish（已存在美音音频）  [958/1877]
# ⏩ 跳过 windswept（已存在美音音频）  [959/1877]
# ⏩ 跳过 entice（已存在美音音频）  [960/1877]
# ⏩ 跳过 well heeled（已存在美音音频）  [961/1877]
# ⏩ 跳过 despondent（已存在美音音频）  [962/1877]
# ⏩ 跳过 prodigy（已存在美音音频）  [963/1877]
# ⏩ 跳过 Bosnian（已存在美音音频）  [964/1877]
# ⏩ 跳过 transformative（已存在美音音频）  [965/1877]
# ⏩ 跳过 cadre（已存在美音音频）  [966/1877]
# ⏩ 跳过 scarcity（已存在美音音频）  [967/1877]
# ⏩ 跳过 lavish（已存在美音音频）  [968/1877]
# ⏩ 跳过 procurement（已存在美音音频）  [969/1877]
# ⏩ 跳过 lore（已存在美音音频）  [970/1877]
# ⏩ 跳过 outsize（已存在美音音频）  [971/1877]
# ⏩ 跳过 laureate（已存在美音音频）  [972/1877]
# ⏩ 跳过 disparity（已存在美音音频）  [973/1877]
# ⏩ 跳过 quadruple（已存在美音音频）  [974/1877]
# ⏩ 跳过 funnel（已存在美音音频）  [975/1877]
# ⏩ 跳过 adolescence（已存在美音音频）  [976/1877]
# ⏩ 跳过 doctorate（已存在美音音频）  [977/1877]
# ⏩ 跳过 conscription（已存在美音音频）  [978/1877]
# ⏩ 跳过 conjecture（已存在美音音频）  [979/1877]
# ⏩ 跳过 Hungarian（已存在美音音频）  [980/1877]
# ⏩ 跳过 polymath（已存在美音音频）  [981/1877]
# ⏩ 跳过 Budapest（已存在美音音频）  [982/1877]
# ⏩ 跳过 monastery（已存在美音音频）  [983/1877]
# ⏩ 跳过 monk（已存在美音音频）  [984/1877]
# ⏩ 跳过 pupil（已存在美音音频）  [985/1877]
# ⏩ 跳过 sceptic（已存在美音音频）  [986/1877]
# ⏩ 跳过 lean（已存在美音音频）  [987/1877]
# ⏩ 跳过 punitive（已存在美音音频）  [988/1877]
# ⏩ 跳过 rolling（已存在美音音频）  [989/1877]
# ⏩ 跳过 sin（已存在美音音频）  [990/1877]
# ⏩ 跳过 mercantilism（已存在美音音频）  [991/1877]
# ⏩ 跳过 sanction（已存在美音音频）  [992/1877]
# ⏩ 跳过 extraterritorial（已存在美音音频）  [993/1877]
# ⏩ 跳过 sever（已存在美音音频）  [994/1877]
# ⏩ 跳过 skirmish（已存在美音音频）  [995/1877]
# ⏩ 跳过 Himalayan（已存在美音音频）  [996/1877]
# ⏩ 跳过 trundle（已存在美音音频）  [997/1877]
# ⏩ 跳过 propulsion（已存在美音音频）  [998/1877]
# ⏩ 跳过 stipend（已存在美音音频）  [999/1877]
# ⏩ 跳过 studio（已存在美音音频）  [1000/1877]
# ⏩ 跳过 scouting（已存在美音音频）  [1001/1877]
# ⏩ 跳过 expressionist（已存在美音音频）  [1002/1877]
# ⏩ 跳过 groom（已存在美音音频）  [1003/1877]
# ⏩ 跳过 philanthropist（已存在美音音频）  [1004/1877]
# ⏩ 跳过 prosthetic（已存在美音音频）  [1005/1877]
# ⏩ 跳过 prestigious（已存在美音音频）  [1006/1877]
# ⏩ 跳过 mobilize（已存在美音音频）  [1007/1877]
# ⏩ 跳过 feat（已存在美音音频）  [1008/1877]
# ⏩ 跳过 deliberate（已存在美音音频）  [1009/1877]
# ⏩ 跳过 hasten（已存在美音音频）  [1010/1877]
# ⏩ 跳过 atheist（已存在美音音频）  [1011/1877]
# ⏩ 跳过 conjure something up（已存在美音音频）  [1012/1877]
# ⏩ 跳过 deity（已存在美音音频）  [1013/1877]
# ⏩ 跳过 gnaw（已存在美音音频）  [1014/1877]
# ⏩ 跳过 angsty（已存在美音音频）  [1015/1877]
# ⏩ 跳过 plow through something（已存在美音音频）  [1016/1877]
# ⏩ 跳过 penal colony（已存在美音音频）  [1017/1877]
# ⏩ 跳过 inaction（已存在美音音频）  [1018/1877]
# ⏩ 跳过 impending（已存在美音音频）  [1019/1877]
# ⏩ 跳过 jaunty（已存在美音音频）  [1020/1877]
# ⏩ 跳过 wry（已存在美音音频）  [1021/1877]
# ⏩ 跳过 dollop（已存在美音音频）  [1022/1877]
# ⏩ 跳过 droll（已存在美音音频）  [1023/1877]
# ⏩ 跳过 mien（已存在美音音频）  [1024/1877]
# ⏩ 跳过 spout（已存在美音音频）  [1025/1877]
# ⏩ 跳过 befuddled（已存在美音音频）  [1026/1877]
# ⏩ 跳过 howl（已存在美音音频）  [1027/1877]
# ⏩ 跳过 fascination（已存在美音音频）  [1028/1877]
# ⏩ 跳过 tantalize（已存在美音音频）  [1029/1877]
# ⏩ 跳过 pawn（已存在美音音频）  [1030/1877]
# ⏩ 跳过 bizarre（已存在美音音频）  [1031/1877]
# ⏩ 跳过 inexplicable（已存在美音音频）  [1032/1877]
# ⏩ 跳过 geek（已存在美音音频）  [1033/1877]
# ⏩ 跳过 referee（已存在美音音频）  [1034/1877]
# ⏩ 跳过 gentleness（已存在美音音频）  [1035/1877]
# ⏩ 跳过 dice（已存在美音音频）  [1036/1877]
# ⏩ 跳过 demeanor（已存在美音音频）  [1037/1877]
# ⏩ 跳过 tournament（已存在美音音频）  [1038/1877]
# ⏩ 跳过 hound（已存在美音音频）  [1039/1877]
# ⏩ 跳过 averse（已存在美音音频）  [1040/1877]
# ⏩ 跳过 ace（已存在美音音频）  [1041/1877]
# ⏩ 跳过 roulette（已存在美音音频）  [1042/1877]
# ⏩ 跳过 blackjack（已存在美音音频）  [1043/1877]
# ⏩ 跳过 arcade（已存在美音音频）  [1044/1877]
# ⏩ 跳过 flip out（已存在美音音频）  [1045/1877]
# ⏩ 跳过 unnerving（已存在美音音频）  [1046/1877]
# ⏩ 跳过 jovial（已存在美音音频）  [1047/1877]
# ⏩ 跳过 possess（已存在美音音频）  [1048/1877]
# ⏩ 跳过 dime（已存在美音音频）  [1049/1877]
# ⏩ 跳过 domination（已存在美音音频）  [1050/1877]
# ⏩ 跳过 understate（已存在美音音频）  [1051/1877]
# ⏩ 跳过 terror（已存在美音音频）  [1052/1877]
# ⏩ 跳过 upside（已存在美音音频）  [1053/1877]
#
# ❌ 未找到美音: nitric oxide  [1054/1877]
#
# ❌ 未找到美音: by rights  [1055/1877]
# ⏩ 跳过 militant（已存在美音音频）  [1056/1877]
#
# ❌ 未找到美音: informed sources  [1057/1877]
#
# ❌ 未找到美音: buy time for  [1058/1877]
#
# ❌ 未找到美音: gather pace  [1059/1877]
#
# ❌ 未找到美音: utility-scale electricity generation  [1060/1877]
#
# ❌ 未找到美音: gas turbine  [1061/1877]
#
# ❌ 未找到美音: sun-soaked  [1062/1877]
#
# ❌ 未找到美音: Individuals shift the frontier for all  [1063/1877]
#
# ❌ 未找到美音: look minor by comparison  [1064/1877]
#
# ❌ 未找到美音: performance venue  [1065/1877]
# ⏩ 跳过 wellspring（已存在美音音频）  [1066/1877]
#
# ❌ 未找到美音: hyperdrive  [1067/1877]
#
# ❌ 未找到美音: a space-faring species  [1068/1877]
#
# ❌ 未找到美音: nooks and crannies  [1069/1877]
#
# ❌ 未找到美音: unfathomability  [1070/1877]
#
# ❌ 未找到美音: tear out  [1071/1877]
#
# ❌ 未找到美音: hotwire  [1072/1877]
# ⏩ 跳过 brutality（已存在美音音频）  [1073/1877]
# ⏩ 跳过 wall something off（已存在美音音频）  [1074/1877]
# ⏩ 跳过 trade surplus（已存在美音音频）  [1075/1877]
# ⏩ 跳过 loss-making（已存在美音音频）  [1076/1877]
# ⏩ 跳过 prop something up（已存在美音音频）  [1077/1877]
# ⏩ 跳过 doom（已存在美音音频）  [1078/1877]
# ⏩ 跳过 containment（已存在美音音频）  [1079/1877]
# ⏩ 跳过 reprisal（已存在美音音频）  [1080/1877]
# ⏩ 跳过 embolden（已存在美音音频）  [1081/1877]
# ⏩ 跳过 airliner（已存在美音音频）  [1082/1877]
# ⏩ 跳过 prompt（已存在美音音频）  [1083/1877]
# ⏩ 跳过 diversified（已存在美音音频）  [1084/1877]
# ⏩ 跳过 intransigence（已存在美音音频）  [1085/1877]
# ⏩ 跳过 command（已存在美音音频）  [1086/1877]
# ⏩ 跳过 vindicate（已存在美音音频）  [1087/1877]
# ⏩ 跳过 intersperse（已存在美音音频）  [1088/1877]
# ⏩ 跳过 minimalist（已存在美音音频）  [1089/1877]
# ⏩ 跳过 futuristic（已存在美音音频）  [1090/1877]
# ⏩ 跳过 satnav（已存在美音音频）  [1091/1877]
# ⏩ 跳过 prosecution（已存在美音音频）  [1092/1877]
# ⏩ 跳过 fiddle（已存在美音音频）  [1093/1877]
# ⏩ 跳过 twiddle（已存在美音音频）  [1094/1877]
# ⏩ 跳过 dial（已存在美音音频）  [1095/1877]
# ⏩ 跳过 gaze（已存在美音音频）  [1096/1877]
# ⏩ 跳过 impair（已存在美音音频）  [1097/1877]
# ⏩ 跳过 revert（已存在美音音频）  [1098/1877]
# ⏩ 跳过 fiddly（已存在美音音频）  [1099/1877]
# ⏩ 跳过 innate（已存在美音音频）  [1100/1877]
# ⏩ 跳过 henchman（已存在美音音频）  [1101/1877]
# ⏩ 跳过 generalissimo（已存在美音音频）  [1102/1877]
# ⏩ 跳过 proliferate（已存在美音音频）  [1103/1877]
# ⏩ 跳过 tyrant（已存在美音音频）  [1104/1877]
# ⏩ 跳过 canal（已存在美音音频）  [1105/1877]
# ⏩ 跳过 gag（已存在美音音频）  [1106/1877]
# ⏩ 跳过 torturer（已存在美音音频）  [1107/1877]
# ⏩ 跳过 the gulag（已存在美音音频）  [1108/1877]
# ⏩ 跳过 stifle（已存在美音音频）  [1109/1877]
# ⏩ 跳过 menacing（已存在美音音频）  [1110/1877]
# ⏩ 跳过 mild（已存在美音音频）  [1111/1877]
# ⏩ 跳过 pretence（已存在美音音频）  [1112/1877]
# ⏩ 跳过 saviour（已存在美音音频）  [1113/1877]
# ⏩ 跳过 brute（已存在美音音频）  [1114/1877]
# ⏩ 跳过 purport（已存在美音音频）  [1115/1877]
# ⏩ 跳过 omnipotent（已存在美音音频）  [1116/1877]
# ⏩ 跳过 dismissive（已存在美音音频）  [1117/1877]
# ⏩ 跳过 hyperbole（已存在美音音频）  [1118/1877]
# ⏩ 跳过 dismissal（已存在美音音频）  [1119/1877]
# ⏩ 跳过 sequencing（已存在美音音频）  [1120/1877]
# ⏩ 跳过 amnesty（已存在美音音频）  [1121/1877]
# ⏩ 跳过 rehabilitation（已存在美音音频）  [1122/1877]
# ⏩ 跳过 ethnically（已存在美音音频）  [1123/1877]
# ⏩ 跳过 tacit（已存在美音音频）  [1124/1877]
# ⏩ 跳过 nihilistic（已存在美音音频）  [1125/1877]
# ⏩ 跳过 pivot（已存在美音音频）  [1126/1877]
# ⏩ 跳过 relinquish（已存在美音音频）  [1127/1877]
# ⏩ 跳过 sabotage（已存在美音音频）  [1128/1877]
# ⏩ 跳过 insincerely（已存在美音音频）  [1129/1877]
# ⏩ 跳过 overstay（已存在美音音频）  [1130/1877]
# ⏩ 跳过 interim（已存在美音音频）  [1131/1877]
# ⏩ 跳过 notwithstanding（已存在美音音频）  [1132/1877]
# ⏩ 跳过 proclamation（已存在美音音频）  [1133/1877]
# ⏩ 跳过 anarchy（已存在美音音频）  [1134/1877]
# ⏩ 跳过 extractive（已存在美音音频）  [1135/1877]
# ⏩ 跳过 monopoly（已存在美音音频）  [1136/1877]
# ⏩ 跳过 jeopardy（已存在美音音频）  [1137/1877]
# ⏩ 跳过 singularity（已存在美音音频）  [1138/1877]
# ⏩ 跳过 slop（已存在美音音频）  [1139/1877]
# ⏩ 跳过 outgrowth（已存在美音音频）  [1140/1877]
# ⏩ 跳过 mild-mannered（已存在美音音频）  [1141/1877]
# ⏩ 跳过 Welsh（已存在美音音频）  [1142/1877]
# ⏩ 跳过 emeritus（已存在美音音频）  [1143/1877]
# ⏩ 跳过 stout（已存在美音音频）  [1144/1877]
# ⏩ 跳过 greige（已存在美音音频）  [1145/1877]
# ⏩ 跳过 geese（已存在美音音频）  [1146/1877]
# ⏩ 跳过 honk（已存在美音音频）  [1147/1877]
# ⏩ 跳过 cicada（已存在美音音频）  [1148/1877]
# ⏩ 跳过 whine（已存在美音音频）  [1149/1877]
# ⏩ 跳过 portal（已存在美音音频）  [1150/1877]
# ⏩ 跳过 guardian（已存在美音音频）  [1151/1877]
# ⏩ 跳过 antique（已存在美音音频）  [1152/1877]
# ⏩ 跳过 expectantly（已存在美音音频）  [1153/1877]
# ⏩ 跳过 plaid（已存在美音音频）  [1154/1877]
# ⏩ 跳过 glance（已存在美音音频）  [1155/1877]
# ⏩ 跳过 glide（已存在美音音频）  [1156/1877]
# ⏩ 跳过 pond（已存在美音音频）  [1157/1877]
# ⏩ 跳过 faraway（已存在美音音频）  [1158/1877]
# ⏩ 跳过 wiry（已存在美音音频）  [1159/1877]
# ⏩ 跳过 wrinkle（已存在美音音频）  [1160/1877]
# ⏩ 跳过 underscore（已存在美音音频）  [1161/1877]
# ⏩ 跳过 recalcitrant（已存在美音音频）  [1162/1877]
# ⏩ 跳过 blonde（已存在美音音频）  [1163/1877]
# ⏩ 跳过 tuft（已存在美音音频）  [1164/1877]
# ⏩ 跳过 careworn（已存在美音音频）  [1165/1877]
# ⏩ 跳过 steward（已存在美音音频）  [1166/1877]
# ⏩ 跳过 ruminate（已存在美音音频）  [1167/1877]
# ⏩ 跳过 conundrum（已存在美音音频）  [1168/1877]
# ⏩ 跳过 twitchy（已存在美音音频）  [1169/1877]
# ⏩ 跳过 mutter（已存在美音音频）  [1170/1877]
# ⏩ 跳过 trail（已存在美音音频）  [1171/1877]
# ⏩ 跳过 dart（已存在美音音频）  [1172/1877]
# ⏩ 跳过 arrhythmia（已存在美音音频）  [1173/1877]
# ⏩ 跳过 demeanour（已存在美音音频）  [1174/1877]
# ⏩ 跳过 discipline（已存在美音音频）  [1175/1877]
# ⏩ 跳过 paddle（已存在美音音频）  [1176/1877]
# ⏩ 跳过 quorum（已存在美音音频）  [1177/1877]
# ⏩ 跳过 gazebo（已存在美音音频）  [1178/1877]
# ⏩ 跳过 clump（已存在美音音频）  [1179/1877]
# ⏩ 跳过 foliage（已存在美音音频）  [1180/1877]
# ⏩ 跳过 though（已存在美音音频）  [1181/1877]
# ⏩ 跳过 re-enactment（已存在美音音频）  [1182/1877]
# ⏩ 跳过 idolize（已存在美音音频）  [1183/1877]
# ⏩ 跳过 wring（已存在美音音频）  [1184/1877]
# ⏩ 跳过 mantle（已存在美音音频）  [1185/1877]
# ⏩ 跳过 knighthood（已存在美音音频）  [1186/1877]
# ⏩ 跳过 assume（已存在美音音频）  [1187/1877]
# ⏩ 跳过 memoir（已存在美音音频）  [1188/1877]
# ⏩ 跳过 victory lap（已存在美音音频）  [1189/1877]
# ⏩ 跳过 viral（已存在美音音频）  [1190/1877]
# ⏩ 跳过 lull（已存在美音音频）  [1191/1877]
# ⏩ 跳过 dependency（已存在美音音频）  [1192/1877]
# ⏩ 跳过 seal something off（已存在美音音频）  [1193/1877]
# ⏩ 跳过 escape hatch（已存在美音音频）  [1194/1877]
# ⏩ 跳过 sake（已存在美音音频）  [1195/1877]
# ⏩ 跳过 dock（已存在美音音频）  [1196/1877]
# ⏩ 跳过 crescendo（已存在美音音频）  [1197/1877]
# ⏩ 跳过 void（已存在美音音频）  [1198/1877]
# ⏩ 跳过 trickle（已存在美音音频）  [1199/1877]
# ⏩ 跳过 immortal（已存在美音音频）  [1200/1877]
# ⏩ 跳过 exaggerate（已存在美音音频）  [1201/1877]
# ⏩ 跳过 devise（已存在美音音频）  [1202/1877]
# ⏩ 跳过 yearn（已存在美音音频）  [1203/1877]
# ⏩ 跳过 modestly（已存在美音音频）  [1204/1877]
# ⏩ 跳过 upbringing（已存在美音音频）  [1205/1877]
# ⏩ 跳过 jet（已存在美音音频）  [1206/1877]
# ⏩ 跳过 sibling（已存在美音音频）  [1207/1877]
# ⏩ 跳过 perforated（已存在美音音频）  [1208/1877]
# ⏩ 跳过 wrap（已存在美音音频）  [1209/1877]
# ⏩ 跳过 cobble（已存在美音音频）  [1210/1877]
# ⏩ 跳过 fellowship（已存在美音音频）  [1211/1877]
# ⏩ 跳过 unglamorous（已存在美音音频）  [1212/1877]
# ⏩ 跳过 heir（已存在美音音频）  [1213/1877]
# ⏩ 跳过 boson（已存在美音音频）  [1214/1877]
# ⏩ 跳过 babel（已存在美音音频）  [1215/1877]
# ⏩ 跳过 collaboration（已存在美音音频）  [1216/1877]
# ⏩ 跳过 jot（已存在美音音频）  [1217/1877]
# ⏩ 跳过 vague（已存在美音音频）  [1218/1877]
# ⏩ 跳过 retrieval（已存在美音音频）  [1219/1877]
# ⏩ 跳过 initiative（已存在美音音频）  [1220/1877]
# ⏩ 跳过 customarily（已存在美音音频）  [1221/1877]
# ⏩ 跳过 screensaver（已存在美音音频）  [1222/1877]
# ⏩ 跳过 crowdsource（已存在美音音频）  [1223/1877]
# ⏩ 跳过 gospel（已存在美音音频）  [1224/1877]
# ⏩ 跳过 pore over something（已存在美音音频）  [1225/1877]
# ⏩ 跳过 tome（已存在美音音频）  [1226/1877]
# ⏩ 跳过 demur（已存在美音音频）  [1227/1877]
# ⏩ 跳过 leer（已存在美音音频）  [1228/1877]
# ⏩ 跳过 perch（已存在美音音频）  [1229/1877]
# ⏩ 跳过 throne（已存在美音音频）  [1230/1877]
# ⏩ 跳过 carbon monoxide（已存在美音音频）  [1231/1877]
# ⏩ 跳过 pique（已存在美音音频）  [1232/1877]
# ⏩ 跳过 markup（已存在美音音频）  [1233/1877]
# ⏩ 跳过 codify（已存在美音音频）  [1234/1877]
# ⏩ 跳过 flamboyant（已存在美音音频）  [1235/1877]
# ⏩ 跳过 jumble（已存在美音音频）  [1236/1877]
# ⏩ 跳过 consortium（已存在美音音频）  [1237/1877]
#
# ❌ 未找到美音: balkanization  [1238/1877]
# ⏩ 跳过 fiefdom（已存在美音音频）  [1239/1877]
# ⏩ 跳过 deficient（已存在美音音频）  [1240/1877]
# ⏩ 跳过 prickly（已存在美音音频）  [1241/1877]
# ⏩ 跳过 narcissistic（已存在美音音频）  [1242/1877]
# ⏩ 跳过 satirical（已存在美音音频）  [1243/1877]
# ⏩ 跳过 cast（已存在美音音频）  [1244/1877]
# ⏩ 跳过 collusive（已存在美音音频）  [1245/1877]
# ⏩ 跳过 launch pad（已存在美音音频）  [1246/1877]
# ⏩ 跳过 maximalist（已存在美音音频）  [1247/1877]
# ⏩ 跳过 intimate（已存在美音音频）  [1248/1877]
# ⏩ 跳过 spontaneous（已存在美音音频）  [1249/1877]
# ⏩ 跳过 ephemeral（已存在美音音频）  [1250/1877]
# ⏩ 跳过 wit（已存在美音音频）  [1251/1877]
# ⏩ 跳过 squish（已存在美音音频）  [1252/1877]
# ⏩ 跳过 wisecrack（已存在美音音频）  [1253/1877]
# ⏩ 跳过 discontent（已存在美音音频）  [1254/1877]
# ⏩ 跳过 cognac（已存在美音音频）  [1255/1877]
# ⏩ 跳过 riff（已存在美音音频）  [1256/1877]
# ⏩ 跳过 canny（已存在美音音频）  [1257/1877]
# ⏩ 跳过 scabrous（已存在美音音频）  [1258/1877]
# ⏩ 跳过 homage（已存在美音音频）  [1259/1877]
# ⏩ 跳过 homeopathic（已存在美音音频）  [1260/1877]
# ⏩ 跳过 plurality（已存在美音音频）  [1261/1877]
# ⏩ 跳过 intel（已存在美音音频）  [1262/1877]
# ⏩ 跳过 medieval（已存在美音音频）  [1263/1877]
# ⏩ 跳过 jester（已存在美音音频）  [1264/1877]
# ⏩ 跳过 commandeer（已存在美音音频）  [1265/1877]
# ⏩ 跳过 carnival（已存在美音音频）  [1266/1877]
# ⏩ 跳过 barker（已存在美音音频）  [1267/1877]
# ⏩ 跳过 taunt（已存在美音音频）  [1268/1877]
# ⏩ 跳过 one-liner（已存在美音音频）  [1269/1877]
# ⏩ 跳过 crackdown（已存在美音音频）  [1270/1877]
# ⏩ 跳过 blur（已存在美音音频）  [1271/1877]
# ⏩ 跳过 spectacle（已存在美音音频）  [1272/1877]
# ⏩ 跳过 ominous（已存在美音音频）  [1273/1877]
# ⏩ 跳过 parable（已存在美音音频）  [1274/1877]
# ⏩ 跳过 goon（已存在美音音频）  [1275/1877]
# ⏩ 跳过 hoot（已存在美音音频）  [1276/1877]
# ⏩ 跳过 the Statue of Liberty（已存在美音音频）  [1277/1877]
# ⏩ 跳过 tender（已存在美音音频）  [1278/1877]
# ⏩ 跳过 glamorous（已存在美音音频）  [1279/1877]
# ⏩ 跳过 shimmy（已存在美音音频）  [1280/1877]
# ⏩ 跳过 mascara（已存在美音音频）  [1281/1877]
# ⏩ 跳过 equity（已存在美音音频）  [1282/1877]
# ⏩ 跳过 net（已存在美音音频）  [1283/1877]
# ⏩ 跳过 strike（已存在美音音频）  [1284/1877]
# ⏩ 跳过 avert（已存在美音音频）  [1285/1877]
# ⏩ 跳过 arsenal（已存在美音音频）  [1286/1877]
# ⏩ 跳过 discourage（已存在美音音频）  [1287/1877]
# ⏩ 跳过 enforce（已存在美音音频）  [1288/1877]
# ⏩ 跳过 ramp something up（已存在美音音频）  [1289/1877]
# ⏩ 跳过 play something down（已存在美音音频）  [1290/1877]
# ⏩ 跳过 readout（已存在美音音频）  [1291/1877]
# ⏩ 跳过 denounce（已存在美音音频）  [1292/1877]
# ⏩ 跳过 grave（已存在美音音频）  [1293/1877]
# ⏩ 跳过 provocation（已存在美音音频）  [1294/1877]
# ⏩ 跳过 clash（已存在美音音频）  [1295/1877]
# ⏩ 跳过 nuke（已存在美音音频）  [1296/1877]
#
# ❌ 未找到美音: slimmer  [1297/1877]
# ⏩ 跳过 impartial（已存在美音音频）  [1298/1877]
# ⏩ 跳过 leverage（已存在美音音频）  [1299/1877]
# ⏩ 跳过 sway（已存在美音音频）  [1300/1877]
# ⏩ 跳过 shrug something off（已存在美音音频）  [1301/1877]
# ⏩ 跳过 deputy（已存在美音音频）  [1302/1877]
# ⏩ 跳过 liken someone/something to someone/something（已存在美音音频）  [1303/1877]
# ⏩ 跳过 reciprocate（已存在美音音频）  [1304/1877]
# ⏩ 跳过 effusive（已存在美音音频）  [1305/1877]
# ⏩ 跳过 lukewarm（已存在美音音频）  [1306/1877]
# ⏩ 跳过 coffers（已存在美音音频）  [1307/1877]
# ⏩ 跳过 weaponry（已存在美音音频）  [1308/1877]
# ⏩ 跳过 warhead（已存在美音音频）  [1309/1877]
# ⏩ 跳过 backtrack（已存在美音音频）  [1310/1877]
# ⏩ 跳过 pact（已存在美音音频）  [1311/1877]
# ⏩ 跳过 radar（已存在美音音频）  [1312/1877]
# ⏩ 跳过 encompass（已存在美音音频）  [1313/1877]
# ⏩ 跳过 deterrence（已存在美音音频）  [1314/1877]
# ⏩ 跳过 unrest（已存在美音音频）  [1315/1877]
# ...
# ⏩ 跳过 mafia（已存在美音音频）  [1436/1877]
# ⏩ 跳过 graft（已存在美音音频）  [1437/1877]
# ⏩ 跳过 renowned（已存在美音音频）  [1438/1877]
# ⏩ 跳过 splendour（已存在美音音频）  [1439/1877]
# ⏩ 跳过 traffic（已存在美音音频）  [1440/1877]
# ⏩ 跳过 lychee（已存在美音音频）  [1441/1877]
# ⏩ 跳过 vanilla（已存在美音音频）  [1442/1877]
# ⏩ 跳过 rosewood（已存在美音音频）  [1443/1877]
# ⏩ 跳过 endemic（已存在美音音频）  [1444/1877]
# ⏩ 跳过 lemur（已存在美音音频）  [1445/1877]
# ⏩ 跳过 solicit（已存在美音音频）  [1446/1877]
# ⏩ 跳过 bribe（已存在美音音频）  [1447/1877]
# ⏩ 跳过 plunder（已存在美音音频）  [1448/1877]
# ⏩ 跳过 put up with something/someone（已存在美音音频）  [1449/1877]
# ⏩ 跳过 lot（已存在美音音频）  [1450/1877]
# ⏩ 跳过 mete something out（已存在美音音频）  [1451/1877]
# ⏩ 跳过 herd（已存在美音音频）  [1452/1877]
# ⏩ 跳过 corpse（已存在美音音频）  [1453/1877]
# ⏩ 跳过 exhume（已存在美音音频）  [1454/1877]
# ⏩ 跳过 ritual（已存在美音音频）  [1455/1877]
# ⏩ 跳过 topple（已存在美音音频）  [1456/1877]
# ⏩ 跳过 bash（已存在美音音频）  [1457/1877]
# ⏩ 跳过 misdemeanour（已存在美音音频）  [1458/1877]
# ⏩ 跳过 repudiate（已存在美音音频）  [1459/1877]
# ⏩ 跳过 jargon（已存在美音音频）  [1460/1877]
# ⏩ 跳过 grandiose（已存在美音音频）  [1461/1877]
# ⏩ 跳过 OCD（已存在美音音频）  [1462/1877]
# ⏩ 跳过 Hawaii（已存在美音音频）  [1463/1877]
# ⏩ 跳过 sovereignty（已存在美音音频）  [1464/1877]
# ⏩ 跳过 enforcement（已存在美音音频）  [1465/1877]
# ⏩ 跳过 demilitarize（已存在美音音频）  [1466/1877]
# ⏩ 跳过 defund（已存在美音音频）  [1467/1877]
# ⏩ 跳过 sprightly（已存在美音音频）  [1468/1877]
# ⏩ 跳过 collective（已存在美音音频）  [1469/1877]
# ⏩ 跳过 heck（已存在美音音频）  [1470/1877]
# ⏩ 跳过 pamphlet（已存在美音音频）  [1471/1877]
# ⏩ 跳过 breeze（已存在美音音频）  [1472/1877]
# ⏩ 跳过 marketer（已存在美音音频）  [1473/1877]
#
# ❌ 未找到美音: addressable market  [1474/1877]
# ⏩ 跳过 abscond（已存在美音音频）  [1475/1877]
# ⏩ 跳过 astounding（已存在美音音频）  [1476/1877]
# ⏩ 跳过 nominee（已存在美音音频）  [1477/1877]
# ⏩ 跳过 impersonate（已存在美音音频）  [1478/1877]
# ⏩ 跳过 crook（已存在美音音频）  [1479/1877]
# ⏩ 跳过 crow（已存在美音音频）  [1480/1877]
# ⏩ 跳过 scammer（已存在美音音频）  [1481/1877]
# ⏩ 跳过 sweeping（已存在美音音频）  [1482/1877]
# ⏩ 跳过 racket（已存在美音音频）  [1483/1877]
# ⏩ 跳过 swindle（已存在美音音频）  [1484/1877]
# ⏩ 跳过 dupe（已存在美音音频）  [1485/1877]
# ⏩ 跳过 rife（已存在美音音频）  [1486/1877]
# ⏩ 跳过 feign（已存在美音音频）  [1487/1877]
# ⏩ 跳过 revive（已存在美音音频）  [1488/1877]
# ⏩ 跳过 con（已存在美音音频）  [1489/1877]
# ⏩ 跳过 gullible（已存在美音音频）  [1490/1877]
# ⏩ 跳过 swindler（已存在美音音频）  [1491/1877]
# ⏩ 跳过 hoodwink（已存在美音音频）  [1492/1877]
# ⏩ 跳过 underhand（已存在美音音频）  [1493/1877]
# ⏩ 跳过 expel（已存在美音音频）  [1494/1877]
# ⏩ 跳过 offence（已存在美音音频）  [1495/1877]
# ⏩ 跳过 allegedly（已存在美音音频）  [1496/1877]
# ⏩ 跳过 masquerade（已存在美音音频）  [1497/1877]
# ⏩ 跳过 fraudster（已存在美音音频）  [1498/1877]
# ⏩ 跳过 chum（已存在美音音频）  [1499/1877]
# ⏩ 跳过 murky（已存在美音音频）  [1500/1877]
# ⏩ 跳过 bank（已存在美音音频）  [1501/1877]
# ⏩ 跳过 buster（已存在美音音频）  [1502/1877]
# ⏩ 跳过 lifeline（已存在美音音频）  [1503/1877]
# ⏩ 跳过 wield（已存在美音音频）  [1504/1877]
# ⏩ 跳过 clout（已存在美音音频）  [1505/1877]
# ⏩ 跳过 volcanic（已存在美音音频）  [1506/1877]
# ⏩ 跳过 tectonics（已存在美音音频）  [1507/1877]
# ⏩ 跳过 meteorologist（已存在美音音频）  [1508/1877]
# ⏩ 跳过 piker（已存在美音音频）  [1509/1877]
# ⏩ 跳过 capricious（已存在美音音频）  [1510/1877]
# ⏩ 跳过 subversive（已存在美音音频）  [1511/1877]
# ⏩ 跳过 opprobrium（已存在美音音频）  [1512/1877]
# ⏩ 跳过 outsider（已存在美音音频）  [1513/1877]
# ⏩ 跳过 dethrone（已存在美音音频）  [1514/1877]
# ⏩ 跳过 keynote（已存在美音音频）  [1515/1877]
# ⏩ 跳过 praxis（已存在美音音频）  [1516/1877]
# ⏩ 跳过 evidently（已存在美音音频）  [1517/1877]
# ⏩ 跳过 grasp（已存在美音音频）  [1518/1877]
# ⏩ 跳过 sewer（已存在美音音频）  [1519/1877]
# ⏩ 跳过 precedent（已存在美音音频）  [1520/1877]
# ⏩ 跳过 town hall（已存在美音音频）  [1521/1877]
# ⏩ 跳过 reckon（已存在美音音频）  [1522/1877]
# ⏩ 跳过 landlord（已存在美音音频）  [1523/1877]
# ⏩ 跳过 hedge fund（已存在美音音频）  [1524/1877]
# ⏩ 跳过 call on/upon sb（已存在美音音频）  [1525/1877]
# ⏩ 跳过 flirt（已存在美音音频）  [1526/1877]
# ⏩ 跳过 tempt（已存在美音音频）  [1527/1877]
# ⏩ 跳过 heyday（已存在美音音频）  [1528/1877]
# ⏩ 跳过 dodgy（已存在美音音频）  [1529/1877]
# ⏩ 跳过 bar（已存在美音音频）  [1530/1877]
# ⏩ 跳过 unequivocally（已存在美音音频）  [1531/1877]
# ⏩ 跳过 harass（已存在美音音频）  [1532/1877]
# ⏩ 跳过 curtail（已存在美音音频）  [1533/1877]
# ⏩ 跳过 elude（已存在美音音频）  [1534/1877]
# ⏩ 跳过 messy（已存在美音音频）  [1535/1877]
# ⏩ 跳过 wonk（已存在美音音频）  [1536/1877]
# ⏩ 跳过 fall over（已存在美音音频）  [1537/1877]
# ⏩ 跳过 spur（已存在美音音频）  [1538/1877]
# ⏩ 跳过 intrigue（已存在美音音频）  [1539/1877]
# ⏩ 跳过 congregate（已存在美音音频）  [1540/1877]
# ⏩ 跳过 titanic（已存在美音音频）  [1541/1877]
# ⏩ 跳过 befit（已存在美音音频）  [1542/1877]
# ⏩ 跳过 bigwig（已存在美音音频）  [1543/1877]
# ⏩ 跳过 tricky（已存在美音音频）  [1544/1877]
# ⏩ 跳过 resilient（已存在美音音频）  [1545/1877]
# ⏩ 跳过 downturn（已存在美音音频）  [1546/1877]
# ⏩ 跳过 property（已存在美音音频）  [1547/1877]
# ⏩ 跳过 truce（已存在美音音频）  [1548/1877]
# ⏩ 跳过 machinery（已存在美音音频）  [1549/1877]
# ⏩ 跳过 outline（已存在美音音频）  [1550/1877]
# ⏩ 跳过 squarely（已存在美音音频）  [1551/1877]
# ⏩ 跳过 entail（已存在美音音频）  [1552/1877]
# ⏩ 跳过 precedence（已存在美音音频）  [1553/1877]
# ⏩ 跳过 bustling（已存在美音音频）  [1554/1877]
# ⏩ 跳过 hub（已存在美音音频）  [1555/1877]
# ⏩ 跳过 churn something out（已存在美音音频）  [1556/1877]
# ⏩ 跳过 mind-numbingly（已存在美音音频）  [1557/1877]
# ⏩ 跳过 odyssey（已存在美音音频）  [1558/1877]
# ⏩ 跳过 unattached（已存在美音音频）  [1559/1877]
# ⏩ 跳过 dim（已存在美音音频）  [1560/1877]
# ⏩ 跳过 malaise（已存在美音音频）  [1561/1877]
# ⏩ 跳过 make-or-break（已存在美音音频）  [1562/1877]
# ⏩ 跳过 retail（已存在美音音频）  [1563/1877]
# ⏩ 跳过 sentiment（已存在美音音频）  [1564/1877]
# ⏩ 跳过 freelance（已存在美音音频）  [1565/1877]
# ⏩ 跳过 scant（已存在美音音频）  [1566/1877]
# ⏩ 跳过 menial（已存在美音音频）  [1567/1877]
# ⏩ 跳过 sclerosis（已存在美音音频）  [1568/1877]
# ⏩ 跳过 diabetes（已存在美音音频）  [1569/1877]
# ⏩ 跳过 tweak（已存在美音音频）  [1570/1877]
# ⏩ 跳过 tone something down（已存在美音音频）  [1571/1877]
# ⏩ 跳过 fuel（已存在美音音频）  [1572/1877]
# ⏩ 跳过 extraction（已存在美音音频）  [1573/1877]
# ⏩ 跳过 cardiovascular（已存在美音音频）  [1574/1877]
# ⏩ 跳过 gung-ho（已存在美音音频）  [1575/1877]
# ⏩ 跳过 descent（已存在美音音频）  [1576/1877]
# ⏩ 跳过 evolutionarily（已存在美音音频）  [1577/1877]
# ⏩ 跳过 nevertheless（已存在美音音频）  [1578/1877]
# ⏩ 跳过 mellow（已存在美音音频）  [1579/1877]
# ⏩ 跳过 intentional（已存在美音音频）  [1580/1877]
# ⏩ 跳过 room and board（已存在美音音频）  [1581/1877]
# ⏩ 跳过 lounge（已存在美音音频）  [1582/1877]
# ⏩ 跳过 shiftless（已存在美音音频）  [1583/1877]
# ⏩ 跳过 attune（已存在美音音频）  [1584/1877]
# ⏩ 跳过 insidious（已存在美音音频）  [1585/1877]
# ⏩ 跳过 human capital（已存在美音音频）  [1586/1877]
# ⏩ 跳过 monotonous（已存在美音音频）  [1587/1877]
# ⏩ 跳过 affix（已存在美音音频）  [1588/1877]
# ⏩ 跳过 myriad（已存在美音音频）  [1589/1877]
# ⏩ 跳过 overpass（已存在美音音频）  [1590/1877]
# ⏩ 跳过 snooze（已存在美音音频）  [1591/1877]
# ⏩ 跳过 tow（已存在美音音频）  [1592/1877]
# ⏩ 跳过 intermediary（已存在美音音频）  [1593/1877]
# ⏩ 跳过 alcoholic（已存在美音音频）  [1594/1877]
# ⏩ 跳过 conducive（已存在美音音频）  [1595/1877]
# ⏩ 跳过 deferential（已存在美音音频）  [1596/1877]
# ⏩ 跳过 disgruntled（已存在美音音频）  [1597/1877]
# ⏩ 跳过 veneer（已存在美音音频）  [1598/1877]
# ⏩ 跳过 Munich（已存在美音音频）  [1599/1877]
# ⏩ 跳过 nautical（已存在美音音频）  [1600/1877]
# ⏩ 跳过 snarl（已存在美音音频）  [1601/1877]
# ⏩ 跳过 descend（已存在美音音频）  [1602/1877]
# ⏩ 跳过 ceremony（已存在美音音频）  [1603/1877]
# ⏩ 跳过 posturing（已存在美音音频）  [1604/1877]
# ⏩ 跳过 prevalent（已存在美音音频）  [1605/1877]
# ⏩ 跳过 confrontational（已存在美音音频）  [1606/1877]
# ⏩ 跳过 jingoistic（已存在美音音频）  [1607/1877]
# ⏩ 跳过 blockbuster（已存在美音音频）  [1608/1877]
# ⏩ 跳过 laxity（已存在美音音频）  [1609/1877]
# ⏩ 跳过 belligerence（已存在美音音频）  [1610/1877]
# ⏩ 跳过 rejoinder（已存在美音音频）  [1611/1877]
# ⏩ 跳过 cordiality（已存在美音音频）  [1612/1877]
# ⏩ 跳过 vitriol（已存在美音音频）  [1613/1877]
# ⏩ 跳过 chop（已存在美音音频）  [1614/1877]
# ⏩ 跳过 blowback（已存在美音音频）  [1615/1877]
# ⏩ 跳过 sour（已存在美音音频）  [1616/1877]
# ⏩ 跳过 tank（已存在美音音频）  [1617/1877]
# ⏩ 跳过 chair（已存在美音音频）  [1618/1877]
# ⏩ 跳过 session（已存在美音音频）  [1619/1877]
# ⏩ 跳过 masculinity（已存在美音音频）  [1620/1877]
# ⏩ 跳过 espouse（已存在美音音频）  [1621/1877]
# ⏩ 跳过 parse（已存在美音音频）  [1622/1877]
# ⏩ 跳过 correlation（已存在美音音频）  [1623/1877]
# ⏩ 跳过 causation（已存在美音音频）  [1624/1877]
# ⏩ 跳过 eat away at something（已存在美音音频）  [1625/1877]
# ⏩ 跳过 toil（已存在美音音频）  [1626/1877]
# ⏩ 跳过 attendee（已存在美音音频）  [1627/1877]
#
# ❌ 未找到美音: die hard  [1628/1877]
# ⏩ 跳过 wedlock（已存在美音音频）  [1629/1877]
# ⏩ 跳过 cattle（已存在美音音频）  [1630/1877]
# ⏩ 跳过 canopy（已存在美音音频）  [1631/1877]
# ⏩ 跳过 nuclear（已存在美音音频）  [1632/1877]
# ⏩ 跳过 affluent（已存在美音音频）  [1633/1877]
# ⏩ 跳过 aloof（已存在美音音频）  [1634/1877]
# ⏩ 跳过 puppet（已存在美音音频）  [1635/1877]
# ⏩ 跳过 triplet（已存在美音音频）  [1636/1877]
# ⏩ 跳过 undeterred（已存在美音音频）  [1637/1877]
# ⏩ 跳过 jest（已存在美音音频）  [1638/1877]
# ⏩ 跳过 like-minded（已存在美音音频）  [1639/1877]
# ⏩ 跳过 sphere（已存在美音音频）  [1640/1877]
#
# ❌ 未找到美音: be a far cry from something  [1641/1877]
# ⏩ 跳过 disenchantment（已存在美音音频）  [1642/1877]
# ⏩ 跳过 convene（已存在美音音频）  [1643/1877]
# ⏩ 跳过 shepherd（已存在美音音频）  [1644/1877]
# ⏩ 跳过 breach（已存在美音音频）  [1645/1877]
# ⏩ 跳过 deteriorate（已存在美音音频）  [1646/1877]
# ⏩ 跳过 goody（已存在美音音频）  [1647/1877]
# ⏩ 跳过 dish something out（已存在美音音频）  [1648/1877]
# ⏩ 跳过 rig（已存在美音音频）  [1649/1877]
# ⏩ 跳过 institutionalize（已存在美音音频）  [1650/1877]
# ⏩ 跳过 entrenched（已存在美音音频）  [1651/1877]
# ⏩ 跳过 rapaciously（已存在美音音频）  [1652/1877]
# ⏩ 跳过 junta（已存在美音音频）  [1653/1877]
# ⏩ 跳过 renege（已存在美音音频）  [1654/1877]
# ⏩ 跳过 scrap（已存在美音音频）  [1655/1877]
# ⏩ 跳过 messiah（已存在美音音频）  [1656/1877]
# ⏩ 跳过 prominence（已存在美音音频）  [1657/1877]
# ⏩ 跳过 devilish（已存在美音音频）  [1658/1877]
# ⏩ 跳过 boar（已存在美音音频）  [1659/1877]
# ⏩ 跳过 feral（已存在美音音频）  [1660/1877]
# ⏩ 跳过 stray（已存在美音音频）  [1661/1877]
# ⏩ 跳过 estrangement（已存在美音音频）  [1662/1877]
# ⏩ 跳过 jaunt（已存在美音音频）  [1663/1877]
#
# ❌ 未找到美音: the great and the good  [1664/1877]
# ⏩ 跳过 rabies（已存在美音音频）  [1665/1877]
# ⏩ 跳过 obstruct（已存在美音音频）  [1666/1877]
# ⏩ 跳过 lash out (something)（已存在美音音频）  [1667/1877]
# ⏩ 跳过 hatchling（已存在美音音频）  [1668/1877]
# ⏩ 跳过 rubble（已存在美音音频）  [1669/1877]
# ⏩ 跳过 assort（已存在美音音频）  [1670/1877]
# ⏩ 跳过 debris（已存在美音音频）  [1671/1877]
# ⏩ 跳过 pothole（已存在美音音频）  [1672/1877]
# ⏩ 跳过 refuse（已存在美音音频）  [1673/1877]
# ⏩ 跳过 municipal（已存在美音音频）  [1674/1877]
# ⏩ 跳过 flounder（已存在美音音频）  [1675/1877]
# ⏩ 跳过 neuter（已存在美音音频）  [1676/1877]
# ⏩ 跳过 drive sb/sth out (of sth)（已存在美音音频）  [1677/1877]
# ⏩ 跳过 canine（已存在美音音频）  [1678/1877]
# ⏩ 跳过 revere（已存在美音音频）  [1679/1877]
# ⏩ 跳过 impotence（已存在美音音频）  [1680/1877]
# ⏩ 跳过 hobble（已存在美音音频）  [1681/1877]
# ⏩ 跳过 abide（已存在美音音频）  [1682/1877]
# ⏩ 跳过 pacifist（已存在美音音频）  [1683/1877]
#
# ❌ 未找到美音: take up arms  [1684/1877]
# ⏩ 跳过 outrage（已存在美音音频）  [1685/1877]
# ⏩ 跳过 disposal（已存在美音音频）  [1686/1877]
# ⏩ 跳过 hospitable（已存在美音音频）  [1687/1877]
# ⏩ 跳过 founder（已存在美音音频）  [1688/1877]
# ⏩ 跳过 dumb（已存在美音音频）  [1689/1877]
# ⏩ 跳过 exodus（已存在美音音频）  [1690/1877]
# ⏩ 跳过 grim（已存在美音音频）  [1691/1877]
# ⏩ 跳过 rash（已存在美音音频）  [1692/1877]
# ⏩ 跳过 plight（已存在美音音频）  [1693/1877]
# ⏩ 跳过 dismantle（已存在美音音频）  [1694/1877]
#
# ❌ 未找到美音: on the ground  [1695/1877]
# ⏩ 跳过 anaemia（已存在美音音频）  [1696/1877]
# ⏩ 跳过 rickety（已存在美音音频）  [1697/1877]
# ⏩ 跳过 hut（已存在美音音频）  [1698/1877]
# ⏩ 跳过 influx（已存在美音音频）  [1699/1877]
# ⏩ 跳过 militia（已存在美音音频）  [1700/1877]
# ⏩ 跳过 jostle（已存在美音音频）  [1701/1877]
# ⏩ 跳过 caretaker（已存在美音音频）  [1702/1877]
# ⏩ 跳过 egg someone on（已存在美音音频）  [1703/1877]
# ⏩ 跳过 extortion（已存在美音音频）  [1704/1877]
# ⏩ 跳过 raid（已存在美音音频）  [1705/1877]
# ⏩ 跳过 squalor（已存在美音音频）  [1706/1877]
# ⏩ 跳过 salvation（已存在美音音频）  [1707/1877]
# ⏩ 跳过 perilous（已存在美音音频）  [1708/1877]
# ⏩ 跳过 capsize（已存在美音音频）  [1709/1877]
# ⏩ 跳过 quash（已存在美音音频）  [1710/1877]
# ⏩ 跳过 lenient（已存在美音音频）  [1711/1877]
# ⏩ 跳过 rein（已存在美音音频）  [1712/1877]
# ⏩ 跳过 baleful（已存在美音音频）  [1713/1877]
# ⏩ 跳过 carriage（已存在美音音频）  [1714/1877]
# ⏩ 跳过 ode（已存在美音音频）  [1715/1877]
# ⏩ 跳过 anthem（已存在美音音频）  [1716/1877]
# ⏩ 跳过 rolling stock（已存在美音音频）  [1717/1877]
# ⏩ 跳过 piddle（已存在美音音频）  [1718/1877]
# ⏩ 跳过 usher（已存在美音音频）  [1719/1877]
# ⏩ 跳过 win someone over（已存在美音音频）  [1720/1877]
# ⏩ 跳过 lift（已存在美音音频）  [1721/1877]
# ⏩ 跳过 slew（已存在美音音频）  [1722/1877]
# ⏩ 跳过 suffocating（已存在美音音频）  [1723/1877]
# ⏩ 跳过 trading（已存在美音音频）  [1724/1877]
# ⏩ 跳过 repeal（已存在美音音频）  [1725/1877]
# ⏩ 跳过 detractor（已存在美音音频）  [1726/1877]
# ⏩ 跳过 pack（已存在美音音频）  [1727/1877]
# ⏩ 跳过 glitzy（已存在美音音频）  [1728/1877]
# ⏩ 跳过 whereby（已存在美音音频）  [1729/1877]
#
# ❌ 未找到美音: road to Damascus  [1730/1877]
# ⏩ 跳过 bleak（已存在美音音频）  [1731/1877]
# ⏩ 跳过 inclusiveness（已存在美音音频）  [1732/1877]
# ⏩ 跳过 cronyism（已存在美音音频）  [1733/1877]
# ⏩ 跳过 whisper（已存在美音音频）  [1734/1877]
# ⏩ 跳过 farce（已存在美音音频）  [1735/1877]
# ⏩ 跳过 suffrage（已存在美音音频）  [1736/1877]
# ⏩ 跳过 electoral college（已存在美音音频）  [1737/1877]
# ⏩ 跳过 screen（已存在美音音频）  [1738/1877]
# ⏩ 跳过 sectarian（已存在美音音频）  [1739/1877]
# ⏩ 跳过 alienate（已存在美音音频）  [1740/1877]
# ⏩ 跳过 fizzle（已存在美音音频）  [1741/1877]
# ⏩ 跳过 podium（已存在美音音频）  [1742/1877]
# ⏩ 跳过 legitimacy（已存在美音音频）  [1743/1877]
# ⏩ 跳过 outgoing（已存在美音音频）  [1744/1877]
# ⏩ 跳过 mortality（已存在美音音频）  [1745/1877]
# ⏩ 跳过 stick（已存在美音音频）  [1746/1877]
# ⏩ 跳过 fatality（已存在美音音频）  [1747/1877]
# ⏩ 跳过 induce（已存在美音音频）  [1748/1877]
# ⏩ 跳过 uncover（已存在美音音频）  [1749/1877]
# ⏩ 跳过 insurgency（已存在美音音频）  [1750/1877]
# ⏩ 跳过 telecoms（已存在美音音频）  [1751/1877]
# ⏩ 跳过 ropy（已存在美音音频）  [1752/1877]
# ⏩ 跳过 patchy（已存在美音音频）  [1753/1877]
# ⏩ 跳过 cusp（已存在美音音频）  [1754/1877]
# ⏩ 跳过 jeopardize（已存在美音音频）  [1755/1877]
# ⏩ 跳过 shrunken（已存在美音音频）  [1756/1877]
# ⏩ 跳过 emerge（已存在美音音频）  [1757/1877]
# ⏩ 跳过 manoeuvre（已存在美音音频）  [1758/1877]
# ⏩ 跳过 hollow something out（已存在美音音频）  [1759/1877]
# ⏩ 跳过 jungle（已存在美音音频）  [1760/1877]
# ⏩ 跳过 infantry（已存在美音音频）  [1761/1877]
# ⏩ 跳过 understaffed（已存在美音音频）  [1762/1877]
# ⏩ 跳过 join up（已存在美音音频）  [1763/1877]
# ⏩ 跳过 fertilizer（已存在美音音频）  [1764/1877]
# ⏩ 跳过 deficit（已存在美音音频）  [1765/1877]
# ⏩ 跳过 clumsily（已存在美音音频）  [1766/1877]
# ⏩ 跳过 back down（已存在美音音频）  [1767/1877]
# ⏩ 跳过 slender（已存在美音音频）  [1768/1877]
# ⏩ 跳过 pretext（已存在美音音频）  [1769/1877]
# ⏩ 跳过 butt（已存在美音音频）  [1770/1877]
# ⏩ 跳过 resounding（已存在美音音频）  [1771/1877]
# ⏩ 跳过 obedient（已存在美音音频）  [1772/1877]
# ⏩ 跳过 craven（已存在美音音频）  [1773/1877]
# ⏩ 跳过 inexorably（已存在美音音频）  [1774/1877]
# ⏩ 跳过 cynical（已存在美音音频）  [1775/1877]
# ⏩ 跳过 tip（已存在美音音频）  [1776/1877]
# ⏩ 跳过 cow（已存在美音音频）  [1777/1877]
# ⏩ 跳过 unruly（已存在美音音频）  [1778/1877]
# ⏩ 跳过 opinionated（已存在美音音频）  [1779/1877]
# ⏩ 跳过 gripe（已存在美音音频）  [1780/1877]
# ⏩ 跳过 adulation（已存在美音音频）  [1781/1877]
# ⏩ 跳过 scoop（已存在美音音频）  [1782/1877]
# ⏩ 跳过 Iowa（已存在美音音频）  [1783/1877]
# ⏩ 跳过 feeble（已存在美音音频）  [1784/1877]
# ⏩ 跳过 chilling（已存在美音音频）  [1785/1877]
# ⏩ 跳过 bolster（已存在美音音频）  [1786/1877]
# ⏩ 跳过 settle（已存在美音音频）  [1787/1877]
# ⏩ 跳过 retribution（已存在美音音频）  [1788/1877]
#
# ❌ 未找到美音: at stake  [1789/1877]
#
# ❌ 未找到美音: fall in line  [1790/1877]
# ⏩ 跳过 conglomerate（已存在美音音频）  [1791/1877]
# ⏩ 跳过 reinstate（已存在美音音频）  [1792/1877]
# ⏩ 跳过 outraged（已存在美音音频）  [1793/1877]
# ⏩ 跳过 tough something out（已存在美音音频）  [1794/1877]
# ⏩ 跳过 nuisance（已存在美音音频）  [1795/1877]
# ⏩ 跳过 libel（已存在美音音频）  [1796/1877]
# ⏩ 跳过 proprietor（已存在美音音频）  [1797/1877]
# ⏩ 跳过 jurisdiction（已存在美音音频）  [1798/1877]
# ⏩ 跳过 mute（已存在美音音频）  [1799/1877]
# ⏩ 跳过 peck（已存在美音音频）  [1800/1877]
# ⏩ 跳过 asset（已存在美音音频）  [1801/1877]
#
# ❌ 未找到美音: get ( something ) off the ground  [1802/1877]
# ⏩ 跳过 apocalypse（已存在美音音频）  [1803/1877]
# ⏩ 跳过 overburden（已存在美音音频）  [1804/1877]
# ⏩ 跳过 placard（已存在美音音频）  [1805/1877]
# ⏩ 跳过 hubris（已存在美音音频）  [1806/1877]
# ⏩ 跳过 cult（已存在美音音频）  [1807/1877]
# ⏩ 跳过 bruiser（已存在美音音频）  [1808/1877]
# ⏩ 跳过 warrant（已存在美音音频）  [1809/1877]
# ⏩ 跳过 alter ego（已存在美音音频）  [1810/1877]
# ⏩ 跳过 lawfare（已存在美音音频）  [1811/1877]
# ⏩ 跳过 oversee（已存在美音音频）  [1812/1877]
# ⏩ 跳过 shakedown（已存在美音音频）  [1813/1877]
# ⏩ 跳过 industrialist（已存在美音音频）  [1814/1877]
# ⏩ 跳过 overreach（已存在美音音频）  [1815/1877]
# ⏩ 跳过 treason（已存在美音音频）  [1816/1877]
# ⏩ 跳过 snatch（已存在美音音频）  [1817/1877]
# ⏩ 跳过 scold（已存在美音音频）  [1818/1877]
# ⏩ 跳过 errant（已存在美音音频）  [1819/1877]
# ⏩ 跳过 acquiescence（已存在美音音频）  [1820/1877]
# ⏩ 跳过 contemplate（已存在美音音频）  [1821/1877]
#
# ❌ 未找到美音: foot the bill  [1822/1877]
# ⏩ 跳过 hamstring（已存在美音音频）  [1823/1877]
# ⏩ 跳过 bombardment（已存在美音音频）  [1824/1877]
# ⏩ 跳过 coterie（已存在美音音频）  [1825/1877]
# ⏩ 跳过 paradoxical（已存在美音音频）  [1826/1877]
# ⏩ 跳过 paymaster（已存在美音音频）  [1827/1877]
# ⏩ 跳过 backslide（已存在美音音频）  [1828/1877]
# ⏩ 跳过 weariness（已存在美音音频）  [1829/1877]
# ⏩ 跳过 bitter（已存在美音音频）  [1830/1877]
# ⏩ 跳过 coax（已存在美音音频）  [1831/1877]
# ⏩ 跳过 cajole（已存在美音音频）  [1832/1877]
# ⏩ 跳过 martial（已存在美音音频）  [1833/1877]
# ⏩ 跳过 dwindle（已存在美音音频）  [1834/1877]
# ⏩ 跳过 renewal（已存在美音音频）  [1835/1877]
# ⏩ 跳过 nasty（已存在美音音频）  [1836/1877]
# ⏩ 跳过 allure（已存在美音音频）  [1837/1877]
# ⏩ 跳过 in tray（已存在美音音频）  [1838/1877]
# ⏩ 跳过 theatrics（已存在美音音频）  [1839/1877]
# ⏩ 跳过 deadly（已存在美音音频）  [1840/1877]
# ⏩ 跳过 firing squad（已存在美音音频）  [1841/1877]
# ⏩ 跳过 outreach（已存在美音音频）  [1842/1877]
# ⏩ 跳过 guarantor（已存在美音音频）  [1843/1877]
# ⏩ 跳过 soap opera（已存在美音音频）  [1844/1877]
# ⏩ 跳过 treaty（已存在美音音频）  [1845/1877]
# ⏩ 跳过 draw something down（已存在美音音频）  [1846/1877]
# ⏩ 跳过 pocket（已存在美音音频）  [1847/1877]
# ⏩ 跳过 malevolence（已存在美音音频）  [1848/1877]
# ⏩ 跳过 subject（已存在美音音频）  [1849/1877]
#
# ❌ 未找到美音: dawn-to-dusk curfew  [1850/1877]
#
# ❌ 未找到美音: ox-cart  [1851/1877]
#
# ❌ 未找到美音: centreward  [1852/1877]
#
# ❌ 未找到美音: heteronormativity  [1853/1877]
#
# ❌ 未找到美音: spread one's sails  [1854/1877]
#
# ❌ 未找到美音: have a positive image of  [1855/1877]
#
# ❌ 未找到美音: shake-up  [1856/1877]
#
# ❌ 未找到美音: the means of production  [1857/1877]
#
# ❌ 未找到美音: gazillionaire  [1858/1877]
#
# ❌ 未找到美音: flex one's muscles  [1859/1877]
#
# ❌ 未找到美音: commenter  [1860/1877]
#
# ❌ 未找到美音: pre-school  [1861/1877]
#
# ❌ 未找到美音: tick up  [1862/1877]
#
# ❌ 未找到美音: is down to  [1863/1877]
#
# ❌ 未找到美音: It is not a stretch to  [1864/1877]
#
# ❌ 未找到美音: well up  [1865/1877]
#
# ❌ 未找到美音: eke out a living  [1866/1877]
#
# ❌ 未找到美音: pick up the pieces  [1867/1877]
#
# ❌ 未找到美音: turn up its nose  [1868/1877]
#
# ❌ 未找到美音: capybara  [1869/1877]
#
# ❌ 未找到美音: malnourished  [1870/1877]
#
# ❌ 未找到美音: vaudevillisation  [1871/1877]
#
# ❌ 未找到美音: a before and after  [1872/1877]
#
# ❌ 未找到美音: in a landslide  [1873/1877]
#
# ❌ 未找到美音: scarcely believable  [1874/1877]
#
# ❌ 未找到美音: megabank  [1875/1877]
#
# ❌ 未找到美音: under one's thumb  [1876/1877]
#
# ❌ 未找到美音: Mar-a-Lago  [1877/1877]
# 完成：已处理 1877/1877 个笔记（每 note 间隔 10.0–20.0 秒）
